# %%
# %run Combined_data.ipynb
# Out:
# Combined_data.ipynb:4: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 4 of the file Combined_data.ipynb. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   "cell_type": "markdown",
# Combined_data.ipynb:6: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 6 of the file Combined_data.ipynb. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   "source": [
# Combined_data.ipynb:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   "cells": [
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, Afghanistan to Zimbabwe
# Data columns (total 13 columns):
# Schizophrenia             148 non-null float64
# Eating_disorders          148 non-null float64
# Anxiety                   148 non-null float64
# Drug_use                  148 non-null float64
# Depression                148 non-null float64
# Alcohol_use               148 non-null float64
# Unem_rate                 148 non-null float64
# GDP                       148 non-null int64
# health_spend_perca        148 non-null float64
# Combined_suicide_rate     148 non-null float64
# urban_population          148 non-null float64
# Internet_access_percap    148 non-null float64
# Religious                 148 non-null object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 16.2+ KB
# RMSE = 3.7237785262479686, z_score = 0.6528359506725792, R_squared = 0.5738052215094298
# y = -40.77 + 133.96*Schizophrenia  +  20.41*Eating_disorders  -  7.3*Drug_use  +  13.12*Depression  +  6.71*Alcohol_use  +  4.92*Rel_High  +  45.19*Schizophrenia Drug_use  -  41.29*Schizophrenia Depression  -  18.44*Schizophrenia Alcohol_use  -  17.52*Eating_disorders Drug_use  -  2.92*Eating_disorders Rel_Medium  -  1.91*Anxiety Rel_High

# %%
final_table
# Out:
#                        Code  Schizophrenia  Eating_disorders   Anxiety  \
# Entity
# Afghanistan             AFG       0.159494          0.088103  5.023055
# Albania                 ALB       0.231592          0.113824  3.557997
# Algeria                 DZA       0.199488          0.181441  5.249815
# Angola                  AGO       0.198776          0.113965  3.272275
# Antigua and Barbuda     ATG       0.210017          0.210369  4.316763
# Argentina               ARG       0.206245          0.256648  6.368157
# Armenia                 ARM       0.221530          0.102840  2.762138
# Australia               AUS       0.373657          0.399329  6.607629
# Austria                 AUT       0.267903          0.531239  5.436622
# Azerbaijan              AZE       0.222934          0.124382  2.709179
# Bahrain                 BHR       0.208877          0.224310  4.813715
# Bangladesh              BGD       0.248877          0.086825  4.050596
# Barbados                BRB       0.231797          0.188412  4.317797
# Belarus                 BLR       0.214092          0.128906  2.975138
# Belgium                 BEL       0.270838          0.449202  5.358790
# Belize                  BLZ       0.197980          0.152740  4.251719
# Benin                   BEN       0.193936          0.075697  2.984719
# Bhutan                  BTN       0.260368          0.110452  3.766302
# Bosnia and Herzegovina  BIH       0.229122          0.107311  3.517572
# Botswana                BWA       0.205610          0.146186  3.602351
# Brazil                  BRA       0.211822          0.175387  6.139371
# Bulgaria                BGR       0.230454          0.127218  3.583943
# Burkina Faso            BFA       0.187297          0.070816  2.979538
# Cambodia                KHM       0.256246          0.074855  3.619646
# Cameroon                CMR       0.193407          0.085383  2.981661
# Canada                  CAN       0.332430          0.312063  5.549322
# Chile                   CHL       0.207539          0.256556  6.298440
# China                   CHN       0.451516          0.110938  3.195014
# Colombia                COL       0.211211          0.190575  2.575168
# Comoros                 COM       0.191525          0.069723  3.343035
# ...                     ...            ...               ...       ...
# Seychelles              SYC       0.292149          0.137201  3.555511
# Sierra Leone            SLE       0.189806          0.071189  2.977348
# Singapore               SGP       0.289308          0.344712  3.882426
# Slovakia                SVK       0.238319          0.149718  3.584652
# Slovenia                SVN       0.241746          0.154983  3.583973
# South Africa            ZAF       0.204531          0.135467  3.822722
# Spain                   ESP       0.295102          0.531810  5.602684
# Sri Lanka               LKA       0.289891          0.109666  3.687049
# Sudan                   SDN       0.175956          0.120337  5.091275
# Suriname                SUR       0.191568          0.182996  4.235133
# Sweden                  SWE       0.300906          0.440876  5.394455
# Switzerland             CHE       0.269762          0.461646  5.393056
# Tajikistan              TJK       0.204282          0.070605  2.657115
# Thailand                THA       0.289404          0.121607  3.648231
# Togo                    TGO       0.187566          0.068750  2.986726
# Tonga                   TON       0.312506          0.083923  3.531923
# Trinidad and Tobago     TTO       0.178289          0.228991  4.269200
# Tunisia                 TUN       0.199457          0.169400  5.273351
# Turkey                  TUR       0.203444          0.263491  4.553063
# Turkmenistan            TKM       0.219432          0.123068  2.726863
# Uganda                  UGA       0.182129          0.074651  3.221900
# Ukraine                 UKR       0.207141          0.103994  2.977524
# United Arab Emirates    ARE       0.215753          0.212661  4.420720
# United Kingdom          GBR       0.273478          0.406572  5.008141
# United States           USA       0.336158          0.369417  6.081070
# Uruguay                 URY       0.208505          0.254502  6.431614
# Uzbekistan              UZB       0.209652          0.091154  2.691824
# Vanuatu                 VUT       0.290606          0.070606  3.435329
# Zambia                  ZMB       0.187785          0.092035  3.350081
# Zimbabwe                ZWE       0.178645          0.077739  3.388782
#
#                         Drug_use  Depression  Alcohol_use  Unem_rate    GDP  \
# Entity
# Afghanistan             1.196912    4.404727     0.612712       23.9   2000
# Albania                 0.655556    2.450883     1.669982       14.0  12500
# Algeria                 0.880553    3.946200     0.605362       11.7  15200
# Angola                  0.467204    4.715467     1.456741        6.6   6800
# Antigua and Barbuda     0.719728    3.128054     1.947655       11.0  26300
# Argentina               1.322192    3.839975     1.796492        8.1  20900
# Armenia                 0.705029    3.068547     1.660420       18.9   9500
# Australia               2.406347    4.949714     1.397416        5.6  50300
# Austria                 1.001242    3.482648     1.827873        5.5  49900
# Azerbaijan              0.734581    2.854446     2.521425        6.0  17500
# Bahrain                 0.939098    4.159016     0.676549        3.8  48500
# Bangladesh              0.555565    4.439595     1.476278        4.0   4200
# Barbados                0.747603    3.324264     1.495446       10.5  18700
# Belarus                 0.976719    4.396417     4.126128        1.0  18900
# Belgium                 0.924855    4.469740     1.359563        7.3  46600
# Belize                  0.773577    3.398175     1.714838       10.1   8300
# Benin                   0.454059    4.163982     1.216588        1.0   2300
# Bhutan                  0.593925    3.720666     2.435247        3.2   8700
# Bosnia and Herzegovina  0.648991    2.564634     2.877315       20.5  12700
# Botswana                0.720993    4.402208     1.657688       20.0  17800
# Brazil                  0.976055    3.724393     2.754555       11.8  15600
# Bulgaria                0.721514    2.794418     1.665605        6.2  21700
# Burkina Faso            0.402001    4.213618     1.218398       77.0   1900
# Cambodia                0.745344    3.381689     0.848614        0.3   4000
# Cameroon                0.493422    4.319253     1.309680        4.3   3700
# Canada                  2.206116    3.998307     1.588419        6.5  48300
# Chile                   1.101855    4.219770     2.359608        7.0  24500
# China                   0.867693    3.680339     1.090205        3.9  16700
# Colombia                0.635882    2.378241     1.736956       10.5  14500
# Comoros                 0.463101    3.723400     1.459323        6.5   1600
# ...                          ...         ...          ...        ...    ...
# Seychelles              0.946771    3.074741     0.826445        4.1  28900
# Sierra Leone            0.445272    4.175993     1.184161        9.1   1600
# Singapore               1.050719    3.707904     0.479380        2.2  93900
# Slovakia                0.719156    2.647707     2.273115        8.1  33000
# Slovenia                0.819709    3.201502     2.068468        6.6  34400
# South Africa            0.660525    4.155648     1.508589       27.6  13500
# Spain                   1.362867    3.792970     0.907822       17.1  38300
# Sri Lanka               0.752341    3.641974     0.797424        4.5  12800
# Sudan                   0.814619    4.102929     0.596162       19.6   4600
# Suriname                0.677717    4.770261     1.664526        9.1  14600
# Sweden                  0.869224    4.966165     1.597182        6.6  51500
# Switzerland             1.093848    3.873037     1.302338        3.0  61400
# Tajikistan              0.707705    2.846063     1.875610        2.4   3200
# Thailand                0.905808    3.382812     0.835700        0.7  17900
# Togo                    0.461290    4.190313     1.199030        6.9   1700
# Tonga                   0.721567    3.200897     0.851819        1.1   5600
# Trinidad and Tobago     0.728085    3.926059     1.599344        4.5  31400
# Tunisia                 0.872277    4.211188     0.594131       15.9  11800
# Turkey                  0.831571    3.888138     0.893527       11.2  26900
# Turkmenistan            0.701932    3.134172     2.030835       11.0  18100
# Uganda                  0.468800    5.616770     1.254208        9.4   2400
# Ukraine                 0.902183    4.515834     4.199587        9.5   8700
# United Arab Emirates    1.062674    3.128079     0.688411        1.6  67700
# United Kingdom          1.479885    4.343298     1.419088        4.4  44100
# United States           3.314164    5.171768     2.153914        4.4  59500
# Uruguay                 1.055214    3.859131     1.006075        7.3  22400
# Uzbekistan              0.665748    3.176225     1.653140        4.9   6900
# Vanuatu                 0.696777    3.409264     0.880641        1.7   2700
# Zambia                  0.468239    4.163807     1.675675       15.0   4000
# Zimbabwe                0.652979    3.599630     1.667406       11.3   2300
#
#                        health_spend_perca  Combined_suicide_rate  \
# Entity
# Afghanistan                       57.2488                6.40000
# Albania                           271.543                5.60000
# Algeria                           260.413                3.30000
# Angola                            95.2208                8.90000
# Antigua and Barbuda               623.115                0.50000
# Argentina                         955.201                9.10000
# Armenia                           358.842                5.70000
# Australia                         5002.36               11.70000
# Austria                           4688.28               11.40000
# Azerbaijan                        268.156                2.60000
# Bahrain                           1099.36                5.70000
# Bangladesh                         34.218                6.10000
# Barbados                          1163.84                0.40000
# Belarus                           317.994               21.40000
# Belgium                           4149.39               15.70000
# Belize                            303.605                5.90000
# Benin                             30.4015               15.70000
# Bhutan                            91.3353               11.60000
# Bosnia and Herzegovina            443.784                6.40000
# Botswana                          379.923               11.50000
# Brazil                            1015.93                6.10000
# Bulgaria                          612.479                7.90000
# Burkina Faso                       40.941               14.80000
# Cambodia                          77.6737                5.90000
# Cameroon                          64.4673               19.50000
# Canada                            4458.21               10.40000
# Chile                             1190.55                9.70000
# China                             398.332                8.00000
# Colombia                          340.365                7.00000
# Comoros                           59.0004               11.10000
# ...                                   ...                    ...
# Seychelles                        596.923                8.30000
# Sierra Leone                      86.3082               16.10000
# Singapore                         2462.39                7.90000
# Slovakia                          1178.74               10.10000
# Slovenia                          1834.16               13.30000
# South Africa                      428.176               12.80000
# Spain                             2389.89                6.10000
# Sri Lanka                         153.097               14.20000
# Sudan                             152.022                9.50000
# Suriname                          356.051               23.20000
# Sweden                            5710.59               11.70000
# Switzerland                       9835.96               11.30000
# Tajikistan                         55.697                3.30000
# Thailand                          221.918               12.90000
# Togo                              38.7714               16.60000
# Tonga                             279.893                4.00000
# Trinidad and Tobago               1063.83               12.90000
# Tunisia                           256.502                3.20000
# Turkey                            468.647                7.20000
# Turkmenistan                      422.849                7.20000
# Uganda                             37.607               20.00000
# Ukraine                           141.826               18.50000
# United Arab Emirates              1323.12                2.70000
# United Kingdom                    3958.02                7.60000
# United States                     9869.74               13.70000
# Uruguay                            1379.1               16.50000
# Uzbekistan                        135.111                7.40000
# Vanuatu                           109.814                5.40000
# Zambia                            56.5442                8.44795
# Zimbabwe                          93.9422               13.40347
#
#                         Male Suicide Rate  Female Suicide Rate  \
# Entity
# Afghanistan                          10.6                  2.1
# Albania                               7.0                  4.3
# Algeria                               4.9                  1.8
# Angola                               14.0                  4.6
# Antigua and Barbuda                   0.0                  0.9
# Argentina                            15.0                  3.5
# Armenia                              10.1                  2.0
# Australia                            17.4                  6.0
# Austria                              17.5                  5.7
# Azerbaijan                            4.3                  1.0
# Bahrain                               7.9                  2.1
# Bangladesh                            5.5                  6.7
# Barbados                              0.8                  0.3
# Belarus                              39.3                  6.2
# Belgium                              22.2                  9.4
# Belize                                9.9                  2.0
# Benin                                22.6                  9.6
# Bhutan                               13.8                  8.9
# Bosnia and Herzegovina               10.6                  2.5
# Botswana                             18.3                  5.7
# Brazil                                9.7                  2.8
# Bulgaria                             13.1                  3.2
# Burkina Faso                         22.4                  9.1
# Cambodia                              9.0                  3.2
# Cameroon                             26.9                 12.5
# Canada                               15.1                  5.8
# Chile                                16.0                  3.8
# China                                 7.9                  8.3
# Colombia                             11.5                  2.8
# Comoros                              17.6                  5.4
# ...                                   ...                  ...
# Seychelles                           15.0                  2.1
# Sierra Leone                         18.2                 14.2
# Singapore                            11.1                  4.9
# Slovakia                             18.4                  2.6
# Slovenia                             22.4                  4.5
# South Africa                         21.7                  5.1
# Spain                                 9.3                  3.1
# Sri Lanka                            23.3                  6.2
# Sudan                                14.5                  4.6
# Suriname                             36.1                 10.9
# Sweden                               15.8                  7.4
# Switzerland                          15.8                  6.9
# Tajikistan                            5.0                  1.7
# Thailand                             21.4                  4.8
# Togo                                 22.7                 10.9
# Tonga                                 5.2                  2.9
# Trinidad and Tobago                  21.9                  4.3
# Tunisia                               4.4                  2.2
# Turkey                               11.3                  3.2
# Turkmenistan                         11.0                  3.7
# Uganda                               21.2                 18.7
# Ukraine                              34.5                  4.7
# United Arab Emirates                  3.5                  0.8
# United Kingdom                       11.9                  3.5
# United States                        21.1                  6.4
# Uruguay                              26.8                  7.1
# Uzbekistan                           10.3                  4.6
# Vanuatu                               8.1                  2.7
# Zambia                               17.5                  6.2
# Zimbabwe                             29.1                 11.1
#
#                         urban_population  Internet_access_percap  % Religious  \
# Entity
# Afghanistan                        15.56                    10.6         97.0
# Albania                             9.34                    66.4         32.5
# Algeria                            24.73                    42.9         93.0
# Angola                             19.97                    13.0         88.0
# Antigua and Barbuda                33.07                    65.2         50.0
# Argentina                          74.17                    70.2         66.0
# Armenia                            53.58                    62.0         72.5
# Australia                          71.69                    88.2         32.0
# Austria                            37.26                    84.3         55.0
# Azerbaijan                         23.27                    78.2         49.5
# Bahrain                            25.88                    98.0         95.5
# Bangladesh                          8.88                    18.2        100.0
# Barbados                            3.94                    79.5         50.0
# Belarus                            48.56                    71.1         33.0
# Belgium                            34.03                    86.5         33.0
# Belize                             25.02                    44.6         61.5
# Benin                              19.24                    12.0         92.5
# Bhutan                              2.62                    41.8         50.0
# Bosnia and Herzegovina             37.27                    69.3         66.0
# Botswana                           12.73                    39.4         77.0
# Brazil                             45.43                    59.7         86.5
# Bulgaria                           37.05                    59.8         33.5
# Burkina Faso                       14.11                    14.0         87.5
# Cambodia                            8.41                    25.6         96.0
# Cameroon                           27.33                    25.0         95.5
# Canada                             79.19                    89.8         42.0
# Chile                              56.60                    66.0         69.5
# China                              37.18                    53.2         50.0
# Colombia                           41.38                    58.1         82.5
# Comoros                             6.72                     7.9         96.0
# ...                                  ...                     ...          ...
# Seychelles                         28.70                    56.5         50.0
# Sierra Leone                       20.03                    11.8         98.0
# Singapore                          78.73                    81.0         70.0
# Slovakia                           17.12                    80.5         46.5
# Slovenia                           21.16                    75.5         47.0
# South Africa                       42.82                    54.0         84.5
# Spain                              41.57                    80.6         49.5
# Sri Lanka                           8.35                    32.1         98.5
# Sudan                              17.49                    28.0         94.0
# Suriname                           55.03                    45.4         50.0
# Sweden                             29.85                    91.5         16.5
# Switzerland                        42.30                    89.4         41.5
# Tajikistan                         11.00                    20.5         84.5
# Thailand                           16.14                    47.5         94.0
# Togo                               16.14                    11.3         80.0
# Tonga                              28.70                    40.0         50.0
# Trinidad and Tobago                 4.13                    69.2         92.0
# Tunisia                            29.97                    50.9         93.0
# Turkey                             60.51                    58.3         89.5
# Turkmenistan                       18.50                    18.0         50.0
# Uganda                              5.01                    45.9         93.0
# Ukraine                            41.55                    52.5         45.5
# United Arab Emirates               70.03                    90.6         91.0
# United Kingdom                     52.90                    94.8         26.5
# United States                      72.40                    76.2         50.0
# Uruguay                            44.40                    66.4         40.5
# Uzbekistan                         20.54                    46.8         51.0
# Vanuatu                            14.17                    24.0         50.0
# Zambia                             29.35                    25.5         97.0
# Zimbabwe                           25.85                    23.1         87.5
#
#                        Religious
# Entity
# Afghanistan                 High
# Albania                      Low
# Algeria                     High
# Angola                      High
# Antigua and Barbuda       Medium
# Argentina                   High
# Armenia                     High
# Australia                    Low
# Austria                   Medium
# Azerbaijan                Medium
# Bahrain                     High
# Bangladesh                  High
# Barbados                  Medium
# Belarus                      Low
# Belgium                      Low
# Belize                    Medium
# Benin                       High
# Bhutan                    Medium
# Bosnia and Herzegovina      High
# Botswana                    High
# Brazil                      High
# Bulgaria                  Medium
# Burkina Faso                High
# Cambodia                    High
# Cameroon                    High
# Canada                    Medium
# Chile                       High
# China                     Medium
# Colombia                    High
# Comoros                     High
# ...                          ...
# Seychelles                Medium
# Sierra Leone                High
# Singapore                   High
# Slovakia                  Medium
# Slovenia                  Medium
# South Africa                High
# Spain                     Medium
# Sri Lanka                   High
# Sudan                       High
# Suriname                  Medium
# Sweden                       Low
# Switzerland               Medium
# Tajikistan                  High
# Thailand                    High
# Togo                        High
# Tonga                     Medium
# Trinidad and Tobago         High
# Tunisia                     High
# Turkey                      High
# Turkmenistan              Medium
# Uganda                      High
# Ukraine                   Medium
# United Arab Emirates        High
# United Kingdom               Low
# United States             Medium
# Uruguay                   Medium
# Uzbekistan                Medium
# Vanuatu                   Medium
# Zambia                      High
# Zimbabwe                    High
#
# [148 rows x 17 columns]

# %%
final_table.shape
# Out:
# (148, 17)

# %%
test_table = final_table.drop(columns=['Code', "Male Suicide Rate", "Female Suicide Rate", "% Religious"])

# %%
test_table.head()
# Out:
#                      Schizophrenia  Eating_disorders   Anxiety  Drug_use  \
# Entity
# Afghanistan               0.159494          0.088103  5.023055  1.196912
# Albania                   0.231592          0.113824  3.557997  0.655556
# Algeria                   0.199488          0.181441  5.249815  0.880553
# Angola                    0.198776          0.113965  3.272275  0.467204
# Antigua and Barbuda       0.210017          0.210369  4.316763  0.719728
#
#                      Depression  Alcohol_use  Unem_rate    GDP  \
# Entity
# Afghanistan            4.404727     0.612712       23.9   2000
# Albania                2.450883     1.669982       14.0  12500
# Algeria                3.946200     0.605362       11.7  15200
# Angola                 4.715467     1.456741        6.6   6800
# Antigua and Barbuda    3.128054     1.947655       11.0  26300
#
#                     health_spend_perca  Combined_suicide_rate  \
# Entity
# Afghanistan                    57.2488                    6.4
# Albania                        271.543                    5.6
# Algeria                        260.413                    3.3
# Angola                         95.2208                    8.9
# Antigua and Barbuda            623.115                    0.5
#
#                      urban_population  Internet_access_percap Religious
# Entity
# Afghanistan                     15.56                    10.6      High
# Albania                          9.34                    66.4       Low
# Algeria                         24.73                    42.9      High
# Angola                          19.97                    13.0      High
# Antigua and Barbuda             33.07                    65.2    Medium

# %%
dummies = pd.get_dummies(test_table['Religious'], prefix="Rel")

# %%
test_table = pd.concat([test_table, dummies], axis=1)

# %%
test_table.health_spend_perca = test_table.health_spend_perca.map(lambda x: float(x))
test_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, Afghanistan to Zimbabwe
# Data columns (total 16 columns):
# Schizophrenia             148 non-null float64
# Eating_disorders          148 non-null float64
# Anxiety                   148 non-null float64
# Drug_use                  148 non-null float64
# Depression                148 non-null float64
# Alcohol_use               148 non-null float64
# Unem_rate                 148 non-null float64
# GDP                       148 non-null int64
# health_spend_perca        148 non-null float64
# Combined_suicide_rate     148 non-null float64
# urban_population          148 non-null float64
# Internet_access_percap    148 non-null float64
# Religious                 148 non-null object
# Rel_High                  148 non-null uint8
# Rel_Low                   148 non-null uint8
# Rel_Medium                148 non-null uint8
# dtypes: float64(11), int64(1), object(1), uint8(3)
# memory usage: 21.6+ KB

# %%
test_table.drop(columns=['Religious', ], inplace=True)

# %%
test_table.drop(columns=['Rel_Low'], inplace=True)
test_table.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-2a7968e45f6d> in <module>()
# ----> 1 test_table.drop(columns=['Rel_Low'], inplace=True)
#       2 test_table.shape
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['Rel_Low'] not found in axis"

# %%
target = test_table['Combined_suicide_rate']
test_table.drop(columns=['Combined_suicide_rate'], inplace=True)
test_table = pd.concat([test_table, target], axis=1)

# %%
final_africa = [item.replace(" ", "") for item in final_africa]
final_africa
no_africa = []
for item in test_table.index:
    if item in final_africa:
        no_africa.append(item)
no_africa
test_table = test_table.drop(no_africa)
test_table.shape
# Out:
# (113, 14)

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
variables = list(test_table.columns)[:-1]
variables
# Out:
# ['Schizophrenia',
#  'Eating_disorders',
#  'Anxiety',
#  'Drug_use',
#  'Depression',
#  'Alcohol_use',
#  'Unem_rate',
#  'GDP',
#  'health_spend_perca',
#  'urban_population',
#  'Internet_access_percap',
#  'Rel_High',
#  'Rel_Medium']

# %%
sns.pairplot(test_table, x_vars=variables[:7], y_vars=['Combined_suicide_rate'])
sns.pairplot(test_table, x_vars=variables[7:], y_vars=['Combined_suicide_rate'])

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
target= "Combined_suicide_rate"
prediction_variables = test_table.drop(columns=['Combined_suicide_rate'], axis=1)
pred = "+".join(prediction_variables.columns)
formula = target + "~" + pred
model = ols(formula="Combined_suicide_rate ~ Depression", data=test_table).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Combined_suicide_rate   R-squared:                       0.168
# Model:                               OLS   Adj. R-squared:                  0.160
# Method:                    Least Squares   F-statistic:                     22.39
# Date:                   Fri, 07 Dec 2018   Prob (F-statistic):           6.59e-06
# Time:                           09:29:20   Log-Likelihood:                -345.93
# No. Observations:                    113   AIC:                             695.9
# Df Residuals:                        111   BIC:                             701.3
# Df Model:                              1
# Covariance Type:               nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.5691      2.794     -1.277      0.204      -9.105       1.967
# Depression     3.5204      0.744      4.732      0.000       2.046       4.995
# ==============================================================================
# Omnibus:                       12.351   Durbin-Watson:                   1.764
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.072
# Skew:                           0.734   Prob(JB):                      0.00145
# Kurtosis:                       3.787   Cond. No.                         22.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
test_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113 entries, Afghanistan to Vanuatu
# Data columns (total 14 columns):
# Schizophrenia             113 non-null float64
# Eating_disorders          113 non-null float64
# Anxiety                   113 non-null float64
# Drug_use                  113 non-null float64
# Depression                113 non-null float64
# Alcohol_use               113 non-null float64
# Unem_rate                 113 non-null float64
# GDP                       113 non-null int64
# health_spend_perca        113 non-null float64
# urban_population          113 non-null float64
# Internet_access_percap    113 non-null float64
# Rel_High                  113 non-null uint8
# Rel_Medium                113 non-null uint8
# Combined_suicide_rate     113 non-null float64
# dtypes: float64(11), int64(1), uint8(2)
# memory usage: 11.7+ KB

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()

# %%
X = test_table.drop(columns=['Combined_suicide_rate'], axis=1)
y = test_table['Combined_suicide_rate']
linreg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
linreg.coef_
# Out:
# array([ 2.18306218e+00, -1.01529133e+01, -7.89439928e-01, -2.95158806e+00,
#         4.32800681e+00,  2.48844620e+00,  4.01916767e-02,  2.58644352e-05,
#         5.91476445e-04,  2.74942292e-02, -3.65419391e-03, -2.12323909e+00,
#        -3.86092099e-01])

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

linreg = LinearRegression()
selector = RFE(linreg, n_features_to_select = 4)
selector = selector.fit(X, y)
selected_columns = X.columns[selector.support_]
print(selected_columns)
# Out:
# Index(['Schizophrenia', 'Drug_use', 'Depression', 'Alcohol_use'], dtype='object')

# %%
linreg.fit(X[selected_columns], y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
linreg.coef_
# Out:
# array([10.62895833, -2.52565688,  3.92117594,  3.30472929])

# %%
yhat = linreg.predict(X[selected_columns])

# %%
SS_Residual = np.sum((y-yhat)**2)
SS_Total = np.sum((y-np.mean(y))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-X[selected_columns].shape[1]-1)

# %%
adjusted_r_squared
# Out:
# 0.43339363989035795

# %%
import statsmodels.api as sm
import numpy as np
def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.01, 
                       threshold_out = 0.05, 
                       verbose=True):
    """ Perform a forward-backward feature selection 
    based on p-value from statsmodels.api.OLS
    Arguments:
        X - pandas.DataFrame with candidate features
        y - list-like with the target
        initial_list - list of features to start with (column names of X)
        threshold_in - include a feature if its p-value < threshold_in
        threshold_out - exclude a feature if its p-value > threshold_out
        verbose - whether to print the sequence of inclusions and exclusions
    Returns: list of selected features 
    Always set threshold_in < threshold_out to avoid infinite looping.
    See https://en.wikipedia.org/wiki/Stepwise_regression for the details
    """
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.idxmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))

        # backward step
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.argmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
    return included

# %%
stepwise_selection(X, y)
# Out:
# Add  Alcohol_use                    with p-value 3.82945e-08
# Add  Depression                     with p-value 9.23813e-07
# ['Alcohol_use', 'Depression']

# %%
linreg.fit(X[['Alcohol_use', 'Depression', 'Anxiety', 'Rel_High']], y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
yhat = linreg.predict(X[['Alcohol_use', 'Depression', 'Anxiety', 'Rel_High']])

# %%
SS_Residual = np.sum((y-yhat)**2)
SS_Total = np.sum((y-np.mean(y))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-X[selected_columns].shape[1]-1)

# %%
r_squared
# Out:
# 0.44631918254037617

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import preprocessing, pipeline

# %%
poly = preprocessing.PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
features_poly = pd.DataFrame(poly.fit_transform(test_table.drop(columns=['Combined_suicide_rate'])), columns=poly.get_feature_names(test_table.drop(columns=['Combined_suicide_rate']).columns))

# %%
X_poly= features_poly
y= test_table['Combined_suicide_rate']

# %%
import seaborn as sns

sns.set(style="white")


# Compute the correlation matrix
corr = features_poly.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Create correlation matrix
corr_matrix = features_poly.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
X_poly.drop(columns=to_drop, inplace=True)

# %%
X_poly.shape
# Out:
# (113, 73)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge

X_poly = X_poly
y = test_table['Combined_suicide_rate']

linreg = LinearRegression()
selector = RFE(linreg, n_features_to_select = i)
selector = selector.fit(X_poly, y)
selected_columns = X_poly.columns[selector.support_]

def MSE_test(X_poly, y, random_state = 12):
    poly_RSME = []
    for i in range(1, len(X_poly.columns)):
        linreg = Ridge(alpha = 0.1, normalize = True)
        selector = RFE(linreg, n_features_to_select = i)
        selector = selector.fit(X_poly, y)
        selected_columns = X_poly.columns[selector.support_]
        selected_var = [column for column in selected_columns]
        X_train, X_test, y_train, y_test = train_test_split(X_poly[selected_columns], y, random_state = random_state,  test_size=.20)
        linreg.fit(X_train, y_train)
        cv_10_results = np.mean(cross_val_score(linreg, X_train, y_train, cv=50, scoring='neg_mean_squared_error'))
        cv_10_results= np.sqrt(abs(cv_10_results))
        poly_RSME.append(dict(variables = selected_var, RMSE = cv_10_results, nu_var = len( selected_var)))
    return poly_RSME

poly_model_list = MSE_test(X_poly, y)

def find_best_model(model_list):
    sorted_mse = sorted(model_list, key=lambda k: k['RMSE'])
    return sorted_mse[0]
    
find_best_model(poly_model_list)
# Out:
# {'variables': ['Depression',
#   'Alcohol_use',
#   'Schizophrenia Anxiety',
#   'Eating_disorders Rel_High'],
#  'RMSE': 4.679888862016026,
#  'nu_var': 4}

# %%
x_val = [item['nu_var'] for item in poly_model_list[:35]]
y_val = [item['RMSE'] for item in poly_model_list[:35]]
plt.plot(x_val, y_val)
plt.xlabel("number of independent variables")
plt.ylabel("RMSE")
# Out:
# Text(0,0.5,'RMSE')

# %%
selected_variables = find_best_model(poly_model_list)['variables']
selected_variables
X_train, X_test, y_train, y_test = train_test_split(X_poly[selected_variables], y, random_state = 12,  test_size=.20)
linreg = Ridge(alpha = 0.1, normalize = True)
linreg.fit(X_train[selected_variables], y_train)
yhat = linreg.predict(X_test[selected_variables])
# # Find ADjusted R2
# SS_Residual = np.sum((y_test-yhat)**2)
# SS_Total = np.sum((y_test-np.mean(y))**2)
# r_squared = 1 - (float(SS_Residual))/SS_Total
# r_squared
# adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-X_poly[selected_variables].shape[1]-1)
# adjusted_r_squared
len(yhat)
RMSE = np.sqrt(mean_squared_error(y_test, yhat))
z_score = RMSE/np.std(y_test)
R_squared = linreg.score(X_test, y_test)
print("RMSE = {}, z_score = {}, R_squared = {}".format(RMSE, z_score, R_squared))
# Out:
# RMSE = 3.442504451346394, z_score = 0.7045971894761355, R_squared = 0.503542800582331

# %%
x_val = yhat
y_val = y_test
plt.scatter(x_val, y_val)
plt.xlabel("Predicted Suicide Rate")
plt.ylabel("Actual Suicide Rate")
plt.plot(x_val, x_val, color = "red")

# %%
linreg.coef_, linreg.intercept_

test = list(zip(linreg.coef_, selected_variables))
print(f"y = {linreg.intercept_} ")
# Out:
# y = -4.672356554044487

# %% [markdown]
# ##### Print our final euqation to get a sense of individual variable relationships

# %%
test = list(zip(linreg.coef_, selected_variables))
combined = [str(round(item[0], 2)) + "*" +item[1] for item in test]
one_string = "  +  ".join(combined)
equation = one_string.replace("+  -", "-  ")

# %%
print("y = {} + {}".format(round(linreg.intercept_, 2), equation))
# Out:
# y = -4.67 + 3.61*Depression  +  2.28*Alcohol_use  -  1.95*Schizophrenia Anxiety  -  9.25*Eating_disorders Rel_High

# %%
countries = pd.read_excel('countries of the world.xls')

# %%
df = pd.DataFrame(countries)

# %%
african = df.iloc[:,:2]

# %%
african.dropna(inplace = True)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
africa = african[african['Unnamed: 1'].str.contains("AFRICA")]

# %%
africa.head()
list_africa = africa["Data is public domain from US government."]

# %%
final_africa = [str(item) for item in list_africa]

# %%
final_africa
# Out:
# ['Algeria ',
#  'Angola ',
#  'Benin ',
#  'Botswana ',
#  'Burkina Faso ',
#  'Burundi ',
#  'Cameroon ',
#  'Cape Verde ',
#  'Central African Rep. ',
#  'Chad ',
#  'Comoros ',
#  'Congo, Dem. Rep. ',
#  'Congo, Repub. of the ',
#  "Cote d'Ivoire ",
#  'Djibouti ',
#  'Egypt ',
#  'Equatorial Guinea ',
#  'Eritrea ',
#  'Ethiopia ',
#  'Gabon ',
#  'Gambia, The ',
#  'Ghana ',
#  'Guinea ',
#  'Guinea-Bissau ',
#  'Kenya ',
#  'Lesotho ',
#  'Liberia ',
#  'Libya ',
#  'Madagascar ',
#  'Malawi ',
#  'Mali ',
#  'Mauritania ',
#  'Mauritius ',
#  'Mayotte ',
#  'Morocco ',
#  'Mozambique ',
#  'Namibia ',
#  'Niger ',
#  'Nigeria ',
#  'Reunion ',
#  'Rwanda ',
#  'Saint Helena ',
#  'Sao Tome & Principe ',
#  'Senegal ',
#  'Seychelles ',
#  'Sierra Leone ',
#  'Somalia ',
#  'South Africa ',
#  'Sudan ',
#  'Swaziland ',
#  'Tanzania ',
#  'Togo ',
#  'Tunisia ',
#  'Uganda ',
#  'Western Sahara ',
#  'Zambia ',
#  'Zimbabwe ']
