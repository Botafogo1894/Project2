# %%
import requests
import json

# %%
r = requests.get('http://apps.who.int/gho/athena/api/GHO/.json?filter=Year:2016')
data = r.json()
data
# Out:
# {'copyright': '(c) World Health Organization',
#  'dataset': [],
#  'attribute': [{'label': 'CATEGORY', 'display': 'Category'},
#   {'label': 'RENDERER_ID', 'display': 'Renderer ID'},
#   {'label': 'DEFINITION_XML', 'display': 'Definition (XML)'},
#   {'label': 'IMR_ID', 'display': 'IMR identifier'},
#   {'label': 'DISPLAY_FR', 'display': 'Français'},
#   {'label': 'DISPLAY_ES', 'display': 'Español'}],
#  'dimension': [{'label': 'GHO',
#    'display': 'Indicator',
#    'isMeasure': True,
#    'code': [{'label': 'MDG_0000000001',
#      'display': 'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#      'display_sequence': 2,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=1',
#      'attr': [{'category': 'DISPLAY_FR',
#        'value': "Taux de mortalité des nourrissons (probabilité de décès avant l'âge d'un an pour 1000\xa0naissances vivantes"},
#       {'category': 'DISPLAY_ES',
#        'value': 'Tasa de mortalidad de menores de 1\xa0año (probabilidad de morir antes de cumplir un año por 1000\xa0nacidos vivos)'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=1'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'MDG_0000000003',
#      'display': 'Adolescent birth rate (per 1000 women aged 15-19 years)',
#      'display_sequence': 5,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=4669',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=3'},
#       {'category': 'CATEGORY', 'value': 'Sustainable development goals'}]},
#     {'label': 'MDG_0000000005',
#      'display': 'Contraceptive prevalence (%)',
#      'display_sequence': 10,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=5',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Millennium Development Goals (MDGs)'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=5'}]},
#     {'label': 'MDG_0000000006',
#      'display': 'Unmet need for family planning (%)',
#      'display_sequence': 5,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=6',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Millennium Development Goals (MDGs)'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=6'}]},
#     {'label': 'MDG_0000000007',
#      'display': 'Under-five mortality rate (probability of dying by age 5 per 1000 live births)',
#      'display_sequence': 5,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=7',
#      'attr': [{'category': 'DISPLAY_FR',
#        'value': "Taux de mortalité des <5 ans (probabilité de décès avant l'âge de 5\xa0ans pour 1000\xa0naissances vivantes)"},
#       {'category': 'DISPLAY_ES',
#        'value': 'Tasa de mortalidad de menores de 5\xa0años (probabilidad de morir antes de cumplir 5\xa0años por 1000\xa0nacidos vivos)'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=7'}]},
#     {'label': 'MDG_0000000010',
#      'display': 'Median availability of selected generic medicines (%) - Public',
#      'display_sequence': 30,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=10',
#      'attr': [{'category': 'CATEGORY', 'value': 'Health systems'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=10'}]},
#     {'label': 'MDG_0000000011',
#      'display': 'Median consumer price ratio of selected generic medicines - Public',
#      'display_sequence': 40,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=11',
#      'attr': [{'category': 'CATEGORY', 'value': 'Health systems'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=11'}]},
#     {'label': 'MDG_0000000012',
#      'display': 'Antiretroviral therapy coverage among people with advanced HIV infection (%)',
#      'display_sequence': 12,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=12',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Millennium Development Goals (MDGs)'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=12'}]},
#     {'label': 'MDG_0000000013',
#      'display': 'Children aged <5 years sleeping under insecticide-treated nets (%)',
#      'display_sequence': 230,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=13',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=13'},
#       {'category': 'CATEGORY', 'value': 'Malaria'}]},
#     {'label': 'MDG_0000000014',
#      'display': 'Children aged <5 years with fever who received treatment with any antimalarial (%)',
#      'display_sequence': 240,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=14',
#      'attr': [{'category': 'CATEGORY', 'value': 'Malaria'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=14'}]},
#     {'label': 'MDG_0000000015',
#      'display': 'Prevalence of condom use by adults during higher-risk sex (15-49) (%)',
#      'display_sequence': 15,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=15',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Millennium Development Goals (MDGs)'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=15'}]},
#     {'label': 'MDG_0000000016',
#      'display': 'Deaths due to malaria (per 100 000 population)',
#      'display_sequence': 16,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=16',
#      'attr': [{'category': 'IMR_ID', 'value': '16'},
#       {'category': 'CATEGORY', 'value': 'Millennium Development Goals (MDGs)'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=16'}]},
#     {'label': 'MDG_0000000017',
#      'display': 'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#      'display_sequence': 17,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=17',
#      'attr': [{'category': 'CATEGORY', 'value': 'Tuberculosis'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=17'}]},
#     {'label': 'MDG_0000000018',
#      'display': 'Deaths due to tuberculosis among HIV-positive people (per 100 000 population)',
#      'display_sequence': 18,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=17',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Millennium Development Goals (MDGs)'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=17'}]},
#     {'label': 'MDG_0000000019',
#      'display': 'Prevalence of HIV among adults aged >=15 years (per 100 000 population)',
#      'display_sequence': 19,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=19',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Millennium Development Goals (MDGs)'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=19'}]},
#     {'label': 'MDG_0000000020',
#      'display': 'Incidence of tuberculosis (per 100 000 population per year)',
#      'display_sequence': 20,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=20',
#      'attr': [{'category': 'CATEGORY', 'value': 'Tuberculosis'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=20'}]},
#     {'label': 'MDG_0000000021',
#      'display': 'Population aged 15-24 years with comprehensive correct knowledge of HIV/AIDS (%)',
#      'display_sequence': 21,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=21',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Millennium Development Goals (MDGs)'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=21'}]},
#     {'label': 'MDG_0000000022',
#      'display': 'Tuberculosis detection rate under DOTS (%)',
#      'display_sequence': 22,
#      'url': '',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Millennium Development Goals (MDGs)'},
#       {'category': 'IMR_ID', 'value': '22'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=22'}]},
#     {'label': 'MDG_0000000023',
#      'display': 'Prevalence of tuberculosis (per 100 000 population)',
#      'display_sequence': 23,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=23',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=23'},
#       {'category': 'CATEGORY', 'value': 'Tuberculosis'}]},
#     {'label': 'MDG_0000000024',
#      'display': 'Tuberculosis treatment success under DOTS (%)',
#      'display_sequence': 24,
#      'url': '',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=24'},
#       {'category': 'CATEGORY', 'value': 'Millennium Development Goals (MDGs)'},
#       {'category': 'IMR_ID', 'value': '24'}]},
#     {'label': 'MDG_0000000025',
#      'display': 'Births attended by skilled health personnel (%)',
#      'display_sequence': 130,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=25',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=25'},
#       {'category': 'CATEGORY', 'value': 'Sustainable development goals'}]},
#     {'label': 'MDG_0000000026',
#      'display': 'Maternal mortality ratio (per 100 000 live births)',
#      'display_sequence': 26,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=26',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=26'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'},
#       {'category': 'IMR_ID', 'value': '26'}]},
#     {'label': 'MDG_0000000027',
#      'display': 'Children aged <5 years stunted (%)',
#      'display_sequence': 27,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=72',
#      'attr': [{'category': 'CATEGORY', 'value': 'Child health'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=72'}]},
#     {'label': 'MDG_0000000028',
#      'display': 'Population below minimum level of dietary energy consumption',
#      'display_sequence': 28,
#      'url': '',
#      'attr': [{'category': 'DEFINITION_XML', 'value': '-'},
#       {'category': 'CATEGORY', 'value': 'Millennium Development Goals (MDGs)'},
#       {'category': 'IMR_ID', 'value': '28'}]},
#     {'label': 'LIFE_0000000029',
#      'display': 'nMx - age-specific death rate between ages x and x+n',
#      'display_sequence': 29,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=29',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=29'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'LIFE_0000000030',
#      'display': 'nqx - probability of dying between ages x and x+n',
#      'display_sequence': 30,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=30',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=30'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'LIFE_0000000031',
#      'display': 'lx - number of people left alive at age x',
#      'display_sequence': 31,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=31',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=31'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'LIFE_0000000032',
#      'display': 'ndx - number of people dying between ages x and x+n',
#      'display_sequence': 32,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=32',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=32'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'LIFE_0000000033',
#      'display': 'nLx - person-years lived between ages x and x+n',
#      'display_sequence': 33,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=33',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=33'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'LIFE_0000000034',
#      'display': 'Tx - person-years lived above age x',
#      'display_sequence': 34,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=34',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=34'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'LIFE_0000000035',
#      'display': 'ex - expectation of life at age x',
#      'display_sequence': 35,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=35',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=35'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'GBD_0000000036',
#      'display': 'Number of deaths',
#      'display_sequence': 100,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=3365',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=3365'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'GBD_0000000037',
#      'display': 'GBD - population',
#      'display_sequence': 37,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'GBD_0000000038',
#      'display': 'GBD - crude death rate',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=3367',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=3367'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'WHS3_40',
#      'display': 'Cholera - number of reported cases',
#      'display_sequence': 1,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=42',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=42'}]},
#     {'label': 'WHS3_41',
#      'display': 'Diphtheria - number of reported cases',
#      'display_sequence': 3,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=43',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=43'}]},
#     {'label': 'WHS3_42',
#      'display': 'Japanese encephalitis - number of reported cases',
#      'display_sequence': 5,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=44',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=44'}]},
#     {'label': 'WHS3_43',
#      'display': 'Pertussis - number of reported cases',
#      'display_sequence': 12,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=45',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=45'}]},
#     {'label': 'WHS3_45',
#      'display': 'Leprosy - number of reported cases',
#      'display_sequence': 6,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=47',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=47'}]},
#     {'label': 'WHS3_46',
#      'display': 'Total tetanus - number of reported cases',
#      'display_sequence': 16,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=48',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=48'}]},
#     {'label': 'WHS3_47',
#      'display': 'Meningitis - number of reported cases',
#      'display_sequence': 9,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=49',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=49'}]},
#     {'label': 'WHS3_48',
#      'display': 'Malaria - number of reported confirmed cases',
#      'display_sequence': 7,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=4635',
#      'attr': [{'category': 'IMR_ID', 'value': '4635'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=4635'},
#       {'category': 'CATEGORY', 'value': 'Malaria'}]},
#     {'label': 'WHS3_49',
#      'display': 'Poliomyelitis - number of reported cases',
#      'display_sequence': 14,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=51',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=51'}]},
#     {'label': 'WHS3_50',
#      'display': 'Yellow fever - number of reported cases',
#      'display_sequence': 18,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=52',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=52'}]},
#     {'label': 'WHS3_51',
#      'display': 'H5N1 influenza - number of reported cases',
#      'display_sequence': 4,
#      'url': '',
#      'attr': [{'category': 'IMR_ID', 'value': '53'},
#       {'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=53'}]},
#     {'label': 'WHS3_52',
#      'display': 'Plague - number of reported cases',
#      'display_sequence': 13,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=54',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=54'}]},
#     {'label': 'WHS3_53',
#      'display': 'Mumps - number of reported cases',
#      'display_sequence': 10,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=55',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=55'}]},
#     {'label': 'WHS3_54',
#      'display': 'Number of reported cases of tuberculosis (DOTS)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=56',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=56'}]},
#     {'label': 'WHS3_55',
#      'display': 'Congenital Rubella Syndrome - number of reported cases',
#      'display_sequence': 2,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=57',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=57'}]},
#     {'label': 'WHS3_56',
#      'display': 'Neonatal tetanus - number of reported cases',
#      'display_sequence': 11,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=58',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=58'}]},
#     {'label': 'WHS3_57',
#      'display': 'Rubella - number of reported cases',
#      'display_sequence': 15,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=59',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=59'}]},
#     {'label': 'MORT_58',
#      'display': 'Mortality - deaths (country)',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=39'},
#       {'category': 'IMR_ID', 'value': '39'}]},
#     {'label': 'MORT_59',
#      'display': 'Mortality - population (country)',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=40'},
#       {'category': 'IMR_ID', 'value': '40'}]},
#     {'label': 'MORT_61',
#      'display': 'Mortality - crude death rate per 100 000 population',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=41',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=41'}]},
#     {'label': 'WHS3_62',
#      'display': 'Measles - number of reported cases',
#      'display_sequence': 8,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=60',
#      'attr': [{'category': 'CATEGORY', 'value': 'Infectious diseases'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=60'}]},
#     {'label': 'MORT_63',
#      'display': 'Mortality - live births (country)',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'},
#       {'category': 'IMR_ID', 'value': '61'},
#       {'category': 'DEFINITION_XML', 'value': '-'}]},
#     {'label': 'WHOSIS_000001',
#      'display': 'Life expectancy at birth (years)',
#      'display_sequence': 10,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=65',
#      'attr': [{'category': 'DISPLAY_FR',
#        'value': 'Esperance de vie a la naissance (ans)'},
#       {'category': 'DISPLAY_ES', 'value': 'Esperanza de vida al nacer'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=65'},
#       {'category': 'CATEGORY', 'value': 'Sustainable development goals'},
#       {'category': 'RENDERER_ID', 'value': 'RENDER_2'}]},
#     {'label': 'WHOSIS_000002',
#      'display': 'Healthy life expectancy (HALE) at birth (years)',
#      'display_sequence': 30,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=66',
#      'attr': [{'category': 'DISPLAY_FR',
#        'value': 'Esperance de vie en bonne sante la naissance (ans)'},
#       {'category': 'DISPLAY_ES', 'value': 'Esperanza de vida sana al nacer'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=66'},
#       {'category': 'CATEGORY', 'value': 'Sustainable development goals'}]},
#     {'label': 'WHOSIS_000003',
#      'display': 'Neonatal mortality rate (per 1000 live births)',
#      'display_sequence': 4,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=67',
#      'attr': [{'category': 'DISPLAY_FR',
#        'value': 'Taux de mortalité néonatale (pour 1000 naissances vivantes)'},
#       {'category': 'DISPLAY_ES',
#        'value': 'Tasa de mortalidad neonatal (por 1000\xa0nacidos vivos)'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=67'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'WHOSIS_000004',
#      'display': 'Adult mortality rate (probability of dying between 15 and 60 years per 1000 population)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=64',
#      'attr': [{'category': 'DISPLAY_FR',
#        'value': 'Taux de mortalité adulte (probabilité de décès entre 15 et 60 ans pour 1000\xa0habitants)'},
#       {'category': 'DISPLAY_ES',
#        'value': 'Tasa de mortalidad de adultos (probabilidad de morir entre los 15 y los 60\xa0años por 1000\xa0habitantes)'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=64'},
#       {'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'}]},
#     {'label': 'WHOSIS_000005',
#      'display': 'Low-birth-weight newborns (%)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=76',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=76'},
#       {'category': 'CATEGORY', 'value': 'Child health'}]},
#     {'label': 'WHOSIS_000006',
#      'display': 'Infants exclusively breastfed for the first six months of life (%)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=130',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=130'},
#       {'category': 'CATEGORY', 'value': 'Child health'}]},
#     {'label': 'GBD_76',
#      'display': 'GBD - Disability-adjusted life years (DALYS)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=158',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=158'}]},
#     {'label': 'GBD_77',
#      'display': 'GBD - Years of life lost (YLL)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=159',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=159'}]},
#     {'label': 'GBD_78',
#      'display': 'GBD - Years lost due to disability (YLD)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=160',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Mortality and global health estimates'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=160'}]},
#     {'label': 'WHOSIS_000008',
#      'display': 'Children aged <5 years underweight (%)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=27',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=27'},
#       {'category': 'CATEGORY', 'value': 'Child health'}]},
#     {'label': 'WHOSIS_000013',
#      'display': 'Prevalence of current tobacco use among adolescents (13-15 years) (%)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=129',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=129'}]},
#     {'label': 'WHOSIS_000009',
#      'display': 'Children aged <5 years overweight (%)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=74',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=74'},
#       {'category': 'CATEGORY', 'value': 'Child health'}]},
#     {'label': 'WHOSIS_000010',
#      'display': 'Adults aged &#8805; 20 years who are obese (%)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2389',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2389'}]},
#     {'label': 'WHOSIS_000011',
#      'display': 'Alcohol consumption among adults aged &#8805; 15 years (litres of pure alcohol per person per year)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=462',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=462'}]},
#     {'label': 'WHOSIS_000012',
#      'display': 'Prevalence of smoking any tobacco product among adults (&#8805;15 years) (%)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=128',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=128'}]},
#     {'label': 'WHS9_85',
#      'display': 'Literacy rate among adults aged >= 15 years (%)',
#      'display_sequence': 150,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=77',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=77'}]},
#     {'label': 'WHS9_86',
#      'display': 'Population (in thousands) total',
#      'display_sequence': 10,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=113',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=113'}]},
#     {'label': 'WHS9_87',
#      'display': 'Net primary school enrolment ratio (%)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=99',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=99'}]},
#     {'label': 'WHS9_88',
#      'display': 'Population median age (years)',
#      'display_sequence': 40,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=116',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=116'}]},
#     {'label': 'WHS9_89',
#      'display': 'Population proportion under 15 (%)',
#      'display_sequence': 20,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=118',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=118'}]},
#     {'label': 'WHS9_90',
#      'display': 'Population living on <$1 (PPP int. $) a day (%)',
#      'display_sequence': 60,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=115',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=115'}]},
#     {'label': 'WHS9_91',
#      'display': 'Civil registration coverage of births (%)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=83',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=83'}]},
#     {'label': 'WHS9_92',
#      'display': 'Population proportion over 60 (%)',
#      'display_sequence': 30,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=117',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=117'},
#       {'category': 'CATEGORY', 'value': 'World Health Statistics'}]},
#     {'label': 'WHS9_93',
#      'display': 'Gross national income per capita (PPP int. $)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=94',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=94'}]},
#     {'label': 'WHS9_94',
#      'display': 'Civil registration coverage of causes of deaths (%)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=84',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=84'}]},
#     {'label': 'WHS9_95',
#      'display': 'Total fertility rate (per woman)',
#      'display_sequence': 70,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=123',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=123'}]},
#     {'label': 'WHS9_96',
#      'display': 'Population living in urban areas (%)',
#      'display_sequence': 50,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=114',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=114'}]},
#     {'label': 'WHS9_97',
#      'display': 'Annual population growth rate (%)',
#      'display_sequence': 40,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=79',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=79'}]},
#     {'label': 'WHS4_99',
#      'display': 'Antiretroviral therapy coverage among HIV-infected pregnant women for PMTCT (%)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=82',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=82'}]},
#     {'label': 'WHS4_100',
#      'display': 'Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)',
#      'display_sequence': 20,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=88',
#      'attr': [{'category': 'CATEGORY', 'value': 'Child health'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=88'}]},
#     {'label': 'WHS6_101',
#      'display': 'Median availability of selected generic medicines (%) - Private',
#      'display_sequence': 10,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=10',
#      'attr': [{'category': 'CATEGORY', 'value': 'Health systems'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=10'}]},
#     {'label': 'WHS6_102',
#      'display': 'Hospital beds (per 10 000 population)',
#      'display_sequence': 60,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=97',
#      'attr': [{'category': 'CATEGORY', 'value': 'World Health Statistics'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=97'}]},
#     {'label': 'WHS7_103',
#      'display': 'Private prepaid plans as a percentage of private expenditure on health',
#      'display_sequence': 80,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=120',
#      'attr': [{'category': 'CATEGORY', 'value': 'Health financing'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=120'}]},
#     {'label': 'WHS7_104',
#      'display': 'Per capita government expenditure on health at average exchange rate (US$)',
#      'display_sequence': 110,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=109',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=109'},
#       {'category': 'CATEGORY', 'value': 'Health financing'}]},
#     {'label': 'WHS7_105',
# ...
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2471',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2471'},
#       {'category': 'CATEGORY', 'value': 'Negelected tropical diseases'}]},
#     {'label': 'NTD_8',
#      'display': 'Number of people who received treatment with antibiotics for trachoma',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2469',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2469'},
#       {'category': 'CATEGORY', 'value': 'Negelected tropical diseases'}]},
#     {'label': 'MENING_3',
#      'display': 'Number of meningitis epidemic districts',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2475',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2475'},
#       {'category': 'CATEGORY', 'value': 'Infectious diseases'}]},
#     {'label': 'SA_0000001688',
#      'display': 'Total (recorded+unrecorded) alcohol per capita (15+) consumption',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/data/node.wrapper.imr?x-id=4759',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Substance use and mental health'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=4759'}]},
#     {'label': 'EQ_URBSLUM',
#      'display': 'Slum population in urban areas (% of total population)',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2476',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2476'},
#       {'category': 'CATEGORY', 'value': 'Health Equity Monitor'}]},
#     {'label': 'MDG_0000000005_AGE1519',
#      'display': 'Contraceptive prevalence, among girls aged 15-19 (%)',
#      'display_sequence': 2,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid= 2481',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2481'},
#       {'category': 'CATEGORY',
#        'value': 'Millennium Development Goals (MDGs)'}]},
#     {'label': 'MDG_0000000006_AGE1519',
#      'display': 'Unmet need for family planning, among girls aged 15-19 (%)',
#      'display_sequence': 1,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2480',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2480'},
#       {'category': 'CATEGORY',
#        'value': 'Millennium Development Goals (MDGs)'}]},
#     {'label': 'MDG_0000000025_AGE1519',
#      'display': 'Births attended by skilled health personnel, among girls aged 15-19 (%)',
#      'display_sequence': 4,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=25',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=25'},
#       {'category': 'CATEGORY',
#        'value': 'Millennium Development Goals (MDGs)'}]},
#     {'label': 'WHS4_111_AGE1519',
#      'display': 'Antenatal care coverage - at least one visit, among girls aged 15-19 (%)',
#      'display_sequence': 3,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2479',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2479'},
#       {'category': 'CATEGORY', 'value': 'Health systems'}]},
#     {'label': 'HWWS_2',
#      'display': "Handwashing with soap after cleaning child's stool (%)",
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Public health and environment'}]},
#     {'label': 'HWWS_1',
#      'display': 'Handwashing with soap after using the toilet (%)',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Public health and environment'}]},
#     {'label': 'RSUD_1',
#      'display': 'Point prevalence (%), alcohol use disorders, 15+ years',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2497',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2497'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_2',
#      'display': 'Point prevalence (%), drug use disorders, 15+ years',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2498',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2498'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_3',
#      'display': 'Age-standardized death rates, alcohol and drug use disorders, per 100 000',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2500',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2500'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_4',
#      'display': 'Age-standardized death rates, drug use disorders, per 100 000',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_5',
#      'display': 'Age-standardized DALYs, alcohol and drug use disorders, per 100 000',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2502',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2502'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_6',
#      'display': 'Age-standardized DALYs, drug use disorders, per 100 000',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_7',
#      'display': 'Psychoactive substance causing entry into treatment',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2503',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2503'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'SA_0000001689',
#      'display': 'Age-standardized DALYs, cerebrovascular disease, per 100,000',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/data/node.wrapper.imr?x-id=2377',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Substance use and mental health'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2377'}]},
#     {'label': 'SA_0000001690',
#      'display': 'Age-standardized death rates, cerebrovascular disease, per 100,000',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/data/node.wrapper.imr?x-id=2378',
#      'attr': [{'category': 'CATEGORY',
#        'value': 'Substance use and mental health'},
#       {'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2378'}]},
#     {'label': 'RSUD_8',
#      'display': 'Epidemiological data collection system for substance use disorders',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2504',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2504'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_9',
#      'display': 'Service delivery data collection system for substance use disorders',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2505',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2505'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_10',
#      'display': 'National survey on substance use among children and adolescents',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2506',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2506'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_11',
#      'display': 'Data on substance use disorders disseminated in national annual reports',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2507',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2507'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_12',
#      'display': 'Substance use policy at the national level',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2508',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2508'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_13',
#      'display': 'Substance use policy at the national level, level of integration',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2509',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2509'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_14',
#      'display': 'Policy documents on the pharmacological treatment of substance use disorders',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2510',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2510'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_15',
#      'display': 'Guidelines on the pharmacological treatment of substance use disorders',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2511',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2511'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_16',
#      'display': 'Legislative provision for treatment and rehabilitation of substance use disorders',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2512',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2512'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_17',
#      'display': 'Legislative provision for compulsory treatment',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2513',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2513'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_18',
#      'display': 'Drug courts',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2514',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2514'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     {'label': 'RSUD_19',
#      'display': 'Programmes diverting clients from the justice system towards treatment',
#      'display_sequence': 0,
#      'url': 'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid=2515',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=2515'},
#       {'category': 'CATEGORY', 'value': 'Substance use and mental health'}]},
#     ...]}],
#  'fact': []}

# %%
import pandas as pd
suicide_rates = pd.DataFrame(columns=['Country Code', 'Male Suicide Rate', 'Female Suicide Rate', 'Combined Suicide Rate'])

# %%
list_of_data = []
for fact in data['fact']:
    for category in fact['Dim']:
        if category['category'] == 'COUNTRY':
            country_code = category['code']
        elif category['category'] == "SEX":
            sex = category['code']
    suicide_rate = fact['value']['numeric']
    list_of_data.append({'Country Code': country_code, 'Sex': sex, "Suicide Rate": suicide_rate})

# %%
list_of_data
# Out:
# [{'Country Code': 'AFG', 'Sex': 'BTSX', 'Suicide Rate': 6.4},
#  {'Country Code': 'AGO', 'Sex': 'FMLE', 'Suicide Rate': 4.6},
#  {'Country Code': 'ARE', 'Sex': 'BTSX', 'Suicide Rate': 2.7},
#  {'Country Code': 'BGR', 'Sex': 'BTSX', 'Suicide Rate': 7.9},
#  {'Country Code': 'BHS', 'Sex': 'FMLE', 'Suicide Rate': 0.5},
#  {'Country Code': 'BHS', 'Sex': 'MLE', 'Suicide Rate': 2.8},
#  {'Country Code': 'BLZ', 'Sex': 'FMLE', 'Suicide Rate': 2.0},
#  {'Country Code': 'BWA', 'Sex': 'BTSX', 'Suicide Rate': 11.5},
#  {'Country Code': 'CAN', 'Sex': 'MLE', 'Suicide Rate': 15.1},
#  {'Country Code': 'CHE', 'Sex': 'BTSX', 'Suicide Rate': 11.3},
#  {'Country Code': 'CHN', 'Sex': 'FMLE', 'Suicide Rate': 8.3},
#  {'Country Code': 'CHN', 'Sex': 'MLE', 'Suicide Rate': 7.9},
#  {'Country Code': 'COD', 'Sex': 'FMLE', 'Suicide Rate': 4.9},
#  {'Country Code': 'CUB', 'Sex': 'BTSX', 'Suicide Rate': 10.1},
#  {'Country Code': 'CZE', 'Sex': 'MLE', 'Suicide Rate': 17.2},
#  {'Country Code': 'DNK', 'Sex': 'FMLE', 'Suicide Rate': 5.2},
#  {'Country Code': 'ESP', 'Sex': 'BTSX', 'Suicide Rate': 6.1},
#  {'Country Code': 'FIN', 'Sex': 'BTSX', 'Suicide Rate': 13.8},
#  {'Country Code': 'FRA', 'Sex': 'FMLE', 'Suicide Rate': 6.5},
#  {'Country Code': 'FRA', 'Sex': 'MLE', 'Suicide Rate': 17.9},
#  {'Country Code': 'GBR', 'Sex': 'FMLE', 'Suicide Rate': 3.5},
#  {'Country Code': 'GNQ', 'Sex': 'BTSX', 'Suicide Rate': 22.0},
#  {'Country Code': 'GTM', 'Sex': 'FMLE', 'Suicide Rate': 1.7},
#  {'Country Code': 'GTM', 'Sex': 'MLE', 'Suicide Rate': 4.4},
#  {'Country Code': 'HND', 'Sex': 'BTSX', 'Suicide Rate': 3.4},
#  {'Country Code': 'HRV', 'Sex': 'FMLE', 'Suicide Rate': 5.1},
#  {'Country Code': 'HUN', 'Sex': 'BTSX', 'Suicide Rate': 13.6},
#  {'Country Code': 'ISL', 'Sex': 'MLE', 'Suicide Rate': 21.7},
#  {'Country Code': 'JAM', 'Sex': 'FMLE', 'Suicide Rate': 0.9},
#  {'Country Code': 'JPN', 'Sex': 'BTSX', 'Suicide Rate': 14.3},
#  {'Country Code': 'KOR', 'Sex': 'MLE', 'Suicide Rate': 29.6},
#  {'Country Code': 'LBN', 'Sex': 'FMLE', 'Suicide Rate': 2.2},
#  {'Country Code': 'LBN', 'Sex': 'MLE', 'Suicide Rate': 4.2},
#  {'Country Code': 'LBY', 'Sex': 'BTSX', 'Suicide Rate': 5.5},
#  {'Country Code': 'LCA', 'Sex': 'FMLE', 'Suicide Rate': 2.1},
#  {'Country Code': 'LSO', 'Sex': 'BTSX', 'Suicide Rate': 28.9},
#  {'Country Code': 'MDG', 'Sex': 'MLE', 'Suicide Rate': 10.5},
#  {'Country Code': 'MKD', 'Sex': 'FMLE', 'Suicide Rate': 3.0},
#  {'Country Code': 'MKD', 'Sex': 'MLE', 'Suicide Rate': 9.7},
#  {'Country Code': 'MLT', 'Sex': 'BTSX', 'Suicide Rate': 6.5},
#  {'Country Code': 'MMR', 'Sex': 'FMLE', 'Suicide Rate': 9.8},
#  {'Country Code': 'MNG', 'Sex': 'BTSX', 'Suicide Rate': 13.3},
#  {'Country Code': 'NAM', 'Sex': 'MLE', 'Suicide Rate': 19.4},
#  {'Country Code': 'NIC', 'Sex': 'FMLE', 'Suicide Rate': 5.0},
#  {'Country Code': 'NOR', 'Sex': 'BTSX', 'Suicide Rate': 10.1},
#  {'Country Code': 'PER', 'Sex': 'MLE', 'Suicide Rate': 7.6},
#  {'Country Code': 'POL', 'Sex': 'FMLE', 'Suicide Rate': 3.4},
#  {'Country Code': 'POL', 'Sex': 'MLE', 'Suicide Rate': 23.9},
#  {'Country Code': 'PRT', 'Sex': 'BTSX', 'Suicide Rate': 8.6},
#  {'Country Code': 'PRY', 'Sex': 'FMLE', 'Suicide Rate': 6.2},
#  {'Country Code': 'ROU', 'Sex': 'BTSX', 'Suicide Rate': 8.0},
#  {'Country Code': 'SGP', 'Sex': 'MLE', 'Suicide Rate': 11.1},
#  {'Country Code': 'SLV', 'Sex': 'FMLE', 'Suicide Rate': 4.3},
#  {'Country Code': 'SLV', 'Sex': 'MLE', 'Suicide Rate': 24.8},
#  {'Country Code': 'SRB', 'Sex': 'BTSX', 'Suicide Rate': 10.9},
#  {'Country Code': 'SSD', 'Sex': 'FMLE', 'Suicide Rate': 4.1},
#  {'Country Code': 'SUR', 'Sex': 'BTSX', 'Suicide Rate': 23.2},
#  {'Country Code': 'SYR', 'Sex': 'MLE', 'Suicide Rate': 3.8},
#  {'Country Code': 'THA', 'Sex': 'FMLE', 'Suicide Rate': 4.8},
#  {'Country Code': 'TKM', 'Sex': 'BTSX', 'Suicide Rate': 7.2},
#  {'Country Code': 'TZA', 'Sex': 'MLE', 'Suicide Rate': 14.3},
#  {'Country Code': 'URY', 'Sex': 'FMLE', 'Suicide Rate': 7.1},
#  {'Country Code': 'URY', 'Sex': 'MLE', 'Suicide Rate': 26.8},
#  {'Country Code': 'UZB', 'Sex': 'BTSX', 'Suicide Rate': 7.4},
#  {'Country Code': 'VCT', 'Sex': 'FMLE', 'Suicide Rate': 0.9},
#  {'Country Code': 'VNM', 'Sex': 'BTSX', 'Suicide Rate': 7.0},
#  {'Country Code': 'ZWE', 'Sex': 'MLE', 'Suicide Rate': 29.1},
#  {'Country Code': 'AFG', 'Sex': 'FMLE', 'Suicide Rate': 2.1},
#  {'Country Code': 'ARE', 'Sex': 'FMLE', 'Suicide Rate': 0.8},
#  {'Country Code': 'ARM', 'Sex': 'BTSX', 'Suicide Rate': 5.7},
#  {'Country Code': 'AUT', 'Sex': 'FMLE', 'Suicide Rate': 5.7},
#  {'Country Code': 'BDI', 'Sex': 'BTSX', 'Suicide Rate': 15.0},
#  {'Country Code': 'BEL', 'Sex': 'FMLE', 'Suicide Rate': 9.4},
#  {'Country Code': 'BEN', 'Sex': 'MLE', 'Suicide Rate': 22.6},
#  {'Country Code': 'BFA', 'Sex': 'BTSX', 'Suicide Rate': 14.8},
#  {'Country Code': 'BGR', 'Sex': 'MLE', 'Suicide Rate': 13.1},
#  {'Country Code': 'BRA', 'Sex': 'FMLE', 'Suicide Rate': 2.8},
#  {'Country Code': 'BRN', 'Sex': 'BTSX', 'Suicide Rate': 4.5},
#  {'Country Code': 'BWA', 'Sex': 'MLE', 'Suicide Rate': 18.3},
#  {'Country Code': 'CMR', 'Sex': 'FMLE', 'Suicide Rate': 12.5},
#  {'Country Code': 'COG', 'Sex': 'BTSX', 'Suicide Rate': 9.3},
#  {'Country Code': 'COL', 'Sex': 'FMLE', 'Suicide Rate': 2.8},
#  {'Country Code': 'COM', 'Sex': 'MLE', 'Suicide Rate': 17.6},
#  {'Country Code': 'CPV', 'Sex': 'BTSX', 'Suicide Rate': 15.1},
#  {'Country Code': 'CUB', 'Sex': 'MLE', 'Suicide Rate': 16.4},
#  {'Country Code': 'DZA', 'Sex': 'FMLE', 'Suicide Rate': 1.8},
#  {'Country Code': 'EGY', 'Sex': 'BTSX', 'Suicide Rate': 4.4},
#  {'Country Code': 'ERI', 'Sex': 'FMLE', 'Suicide Rate': 6.1},
#  {'Country Code': 'ESP', 'Sex': 'MLE', 'Suicide Rate': 9.3},
#  {'Country Code': 'EST', 'Sex': 'BTSX', 'Suicide Rate': 14.4},
#  {'Country Code': 'FIN', 'Sex': 'MLE', 'Suicide Rate': 20.8},
#  {'Country Code': 'GHA', 'Sex': 'FMLE', 'Suicide Rate': 2.9},
#  {'Country Code': 'GMB', 'Sex': 'BTSX', 'Suicide Rate': 10.0},
#  {'Country Code': 'GNQ', 'Sex': 'MLE', 'Suicide Rate': 31.3},
#  {'Country Code': 'HND', 'Sex': 'FMLE', 'Suicide Rate': 1.7},
#  {'Country Code': 'HTI', 'Sex': 'BTSX', 'Suicide Rate': 12.2},
#  {'Country Code': 'HUN', 'Sex': 'FMLE', 'Suicide Rate': 6.2},
#  {'Country Code': 'IDN', 'Sex': 'MLE', 'Suicide Rate': 5.2},
#  {'Country Code': 'IND', 'Sex': 'BTSX', 'Suicide Rate': 16.5},
#  {'Country Code': 'IRN', 'Sex': 'MLE', 'Suicide Rate': 4.9},
#  {'Country Code': 'JPN', 'Sex': 'FMLE', 'Suicide Rate': 8.1},
#  {'Country Code': 'KEN', 'Sex': 'BTSX', 'Suicide Rate': 5.6},
#  {'Country Code': 'KGZ', 'Sex': 'FMLE', 'Suicide Rate': 3.7},
#  {'Country Code': 'KHM', 'Sex': 'MLE', 'Suicide Rate': 9.0},
#  {'Country Code': 'KIR', 'Sex': 'BTSX', 'Suicide Rate': 15.2},
#  {'Country Code': 'KWT', 'Sex': 'MLE', 'Suicide Rate': 2.5},
#  {'Country Code': 'LSO', 'Sex': 'FMLE', 'Suicide Rate': 32.6},
#  {'Country Code': 'LUX', 'Sex': 'BTSX', 'Suicide Rate': 10.4},
#  {'Country Code': 'MAR', 'Sex': 'MLE', 'Suicide Rate': 2.5},
#  {'Country Code': 'MLT', 'Sex': 'FMLE', 'Suicide Rate': 2.8},
#  {'Country Code': 'MNE', 'Sex': 'BTSX', 'Suicide Rate': 7.9},
#  {'Country Code': 'MNG', 'Sex': 'FMLE', 'Suicide Rate': 3.8},
#  {'Country Code': 'MOZ', 'Sex': 'MLE', 'Suicide Rate': 14.0},
#  {'Country Code': 'MRT', 'Sex': 'BTSX', 'Suicide Rate': 7.5},
#  {'Country Code': 'MWI', 'Sex': 'MLE', 'Suicide Rate': 13.7},
#  {'Country Code': 'NOR', 'Sex': 'FMLE', 'Suicide Rate': 6.5},
#  {'Country Code': 'NZL', 'Sex': 'BTSX', 'Suicide Rate': 11.6},
#  {'Country Code': 'OMN', 'Sex': 'FMLE', 'Suicide Rate': 0.9},
#  {'Country Code': 'PAK', 'Sex': 'MLE', 'Suicide Rate': 3.0},
#  {'Country Code': 'PAN', 'Sex': 'BTSX', 'Suicide Rate': 4.4},
#  {'Country Code': 'PHL', 'Sex': 'MLE', 'Suicide Rate': 5.2},
#  {'Country Code': 'ROU', 'Sex': 'FMLE', 'Suicide Rate': 2.4},
#  {'Country Code': 'RWA', 'Sex': 'BTSX', 'Suicide Rate': 11.0},
#  {'Country Code': 'SDN', 'Sex': 'MLE', 'Suicide Rate': 14.5},
#  {'Country Code': 'SRB', 'Sex': 'FMLE', 'Suicide Rate': 5.2},
#  {'Country Code': 'STP', 'Sex': 'BTSX', 'Suicide Rate': 3.1},
#  {'Country Code': 'SUR', 'Sex': 'FMLE', 'Suicide Rate': 10.9},
#  {'Country Code': 'SVK', 'Sex': 'MLE', 'Suicide Rate': 18.4},
#  {'Country Code': 'SVN', 'Sex': 'BTSX', 'Suicide Rate': 13.3},
#  {'Country Code': 'SWZ', 'Sex': 'MLE', 'Suicide Rate': 25.4},
#  {'Country Code': 'TKM', 'Sex': 'FMLE', 'Suicide Rate': 3.7},
#  {'Country Code': 'TON', 'Sex': 'BTSX', 'Suicide Rate': 4.0},
#  {'Country Code': 'TTO', 'Sex': 'FMLE', 'Suicide Rate': 4.3},
#  {'Country Code': 'TUN', 'Sex': 'MLE', 'Suicide Rate': 4.4},
#  {'Country Code': 'TUR', 'Sex': 'BTSX', 'Suicide Rate': 7.2},
#  {'Country Code': 'UGA', 'Sex': 'MLE', 'Suicide Rate': 21.2},
#  {'Country Code': 'VNM', 'Sex': 'FMLE', 'Suicide Rate': 3.4},
#  {'Country Code': 'WSM', 'Sex': 'BTSX', 'Suicide Rate': 5.4},
#  {'Country Code': 'ZAF', 'Sex': 'MLE', 'Suicide Rate': 21.7},
#  {'Country Code': 'ALB', 'Sex': 'BTSX', 'Suicide Rate': 5.6},
#  {'Country Code': 'ATG', 'Sex': 'BTSX', 'Suicide Rate': 0.5},
#  {'Country Code': 'AZE', 'Sex': 'MLE', 'Suicide Rate': 4.3},
#  {'Country Code': 'BHR', 'Sex': 'FMLE', 'Suicide Rate': 2.1},
#  {'Country Code': 'BHR', 'Sex': 'BTSX', 'Suicide Rate': 5.7},
#  {'Country Code': 'BLR', 'Sex': 'FMLE', 'Suicide Rate': 6.2},
#  {'Country Code': 'BLZ', 'Sex': 'MLE', 'Suicide Rate': 9.9},
#  {'Country Code': 'BRB', 'Sex': 'MLE', 'Suicide Rate': 0.8},
#  {'Country Code': 'CAF', 'Sex': 'BTSX', 'Suicide Rate': 11.6},
#  {'Country Code': 'CHL', 'Sex': 'FMLE', 'Suicide Rate': 3.8},
#  {'Country Code': 'CHL', 'Sex': 'BTSX', 'Suicide Rate': 9.7},
#  {'Country Code': 'COD', 'Sex': 'MLE', 'Suicide Rate': 15.0},
#  {'Country Code': 'CYP', 'Sex': 'FMLE', 'Suicide Rate': 1.9},
#  {'Country Code': 'CYP', 'Sex': 'BTSX', 'Suicide Rate': 4.5},
#  {'Country Code': 'DJI', 'Sex': 'FMLE', 'Suicide Rate': 5.3},
#  {'Country Code': 'DJI', 'Sex': 'BTSX', 'Suicide Rate': 8.5},
#  {'Country Code': 'DNK', 'Sex': 'MLE', 'Suicide Rate': 13.2},
#  {'Country Code': 'ECU', 'Sex': 'MLE', 'Suicide Rate': 10.7},
#  {'Country Code': 'FJI', 'Sex': 'FMLE', 'Suicide Rate': 2.5},
#  {'Country Code': 'FJI', 'Sex': 'BTSX', 'Suicide Rate': 5.5},
#  {'Country Code': 'GAB', 'Sex': 'FMLE', 'Suicide Rate': 4.3},
#  {'Country Code': 'GBR', 'Sex': 'MLE', 'Suicide Rate': 11.9},
#  {'Country Code': 'GIN', 'Sex': 'MLE', 'Suicide Rate': 12.7},
#  {'Country Code': 'GRC', 'Sex': 'BTSX', 'Suicide Rate': 3.8},
#  {'Country Code': 'GUY', 'Sex': 'BTSX', 'Suicide Rate': 30.2},
#  {'Country Code': 'GUY', 'Sex': 'MLE', 'Suicide Rate': 46.6},
#  {'Country Code': 'IRL', 'Sex': 'FMLE', 'Suicide Rate': 4.2},
#  {'Country Code': 'ISL', 'Sex': 'FMLE', 'Suicide Rate': 4.7},
#  {'Country Code': 'ISR', 'Sex': 'BTSX', 'Suicide Rate': 5.2},
#  {'Country Code': 'ISR', 'Sex': 'MLE', 'Suicide Rate': 8.2},
#  {'Country Code': 'JOR', 'Sex': 'BTSX', 'Suicide Rate': 3.7},
#  {'Country Code': 'JOR', 'Sex': 'MLE', 'Suicide Rate': 4.7},
#  {'Country Code': 'KOR', 'Sex': 'FMLE', 'Suicide Rate': 11.6},
#  {'Country Code': 'LBR', 'Sex': 'BTSX', 'Suicide Rate': 13.4},
#  {'Country Code': 'LBR', 'Sex': 'MLE', 'Suicide Rate': 13.8},
#  {'Country Code': 'LKA', 'Sex': 'BTSX', 'Suicide Rate': 14.2},
#  {'Country Code': 'LVA', 'Sex': 'FMLE', 'Suicide Rate': 5.1},
#  {'Country Code': 'MDG', 'Sex': 'FMLE', 'Suicide Rate': 3.6},
#  {'Country Code': 'MDV', 'Sex': 'MLE', 'Suicide Rate': 3.6},
#  {'Country Code': 'MLI', 'Sex': 'BTSX', 'Suicide Rate': 8.9},
#  {'Country Code': 'MLI', 'Sex': 'MLE', 'Suicide Rate': 13.5},
#  {'Country Code': 'MUS', 'Sex': 'FMLE', 'Suicide Rate': 2.2},
#  {'Country Code': 'NAM', 'Sex': 'FMLE', 'Suicide Rate': 4.9},
#  {'Country Code': 'NER', 'Sex': 'BTSX', 'Suicide Rate': 9.0},
#  {'Country Code': 'NER', 'Sex': 'MLE', 'Suicide Rate': 11.5},
#  {'Country Code': 'NLD', 'Sex': 'BTSX', 'Suicide Rate': 9.6},
#  {'Country Code': 'NLD', 'Sex': 'MLE', 'Suicide Rate': 12.9},
#  {'Country Code': 'PER', 'Sex': 'FMLE', 'Suicide Rate': 2.7},
#  {'Country Code': 'PRK', 'Sex': 'BTSX', 'Suicide Rate': 10.6},
#  {'Country Code': 'PRK', 'Sex': 'MLE', 'Suicide Rate': 14.8},
#  {'Country Code': 'QAT', 'Sex': 'BTSX', 'Suicide Rate': 5.8},
#  {'Country Code': 'SAU', 'Sex': 'FMLE', 'Suicide Rate': 1.7},
#  {'Country Code': 'SGP', 'Sex': 'FMLE', 'Suicide Rate': 4.9},
#  {'Country Code': 'SLB', 'Sex': 'MLE', 'Suicide Rate': 8.5},
#  {'Country Code': 'SOM', 'Sex': 'BTSX', 'Suicide Rate': 8.3},
#  {'Country Code': 'SOM', 'Sex': 'MLE', 'Suicide Rate': 11.5},
#  {'Country Code': 'SWE', 'Sex': 'FMLE', 'Suicide Rate': 7.4},
#  {'Country Code': 'SYR', 'Sex': 'FMLE', 'Suicide Rate': 1.1},
#  {'Country Code': 'TCD', 'Sex': 'BTSX', 'Suicide Rate': 15.5},
#  {'Country Code': 'TCD', 'Sex': 'MLE', 'Suicide Rate': 17.1},
#  {'Country Code': 'TJK', 'Sex': 'BTSX', 'Suicide Rate': 3.3},
#  {'Country Code': 'TJK', 'Sex': 'MLE', 'Suicide Rate': 5.0},
#  {'Country Code': 'TZA', 'Sex': 'FMLE', 'Suicide Rate': 5.4},
#  {'Country Code': 'USA', 'Sex': 'BTSX', 'Suicide Rate': 13.7},
#  {'Country Code': 'USA', 'Sex': 'MLE', 'Suicide Rate': 21.1},
#  {'Country Code': 'VEN', 'Sex': 'BTSX', 'Suicide Rate': 3.8},
#  {'Country Code': 'YEM', 'Sex': 'FMLE', 'Suicide Rate': 6.2},
#  {'Country Code': 'ZWE', 'Sex': 'FMLE', 'Suicide Rate': 11.1},
#  {'Country Code': 'ZWE', 'Sex': 'BTSX', 'Suicide Rate': 10.5328},
#  {'Country Code': 'ZWE', 'Sex': 'BTSX', 'Suicide Rate': 13.40347},
#  {'Country Code': 'ALB', 'Sex': 'MLE', 'Suicide Rate': 7.0},
#  {'Country Code': 'ARM', 'Sex': 'FMLE', 'Suicide Rate': 2.0},
#  {'Country Code': 'ARM', 'Sex': 'MLE', 'Suicide Rate': 10.1},
#  {'Country Code': 'AUT', 'Sex': 'BTSX', 'Suicide Rate': 11.4},
#  {'Country Code': 'BDI', 'Sex': 'FMLE', 'Suicide Rate': 7.7},
#  {'Country Code': 'BDI', 'Sex': 'MLE', 'Suicide Rate': 23.1},
#  {'Country Code': 'BFA', 'Sex': 'FMLE', 'Suicide Rate': 9.1},
#  {'Country Code': 'BLR', 'Sex': 'BTSX', 'Suicide Rate': 21.4},
#  {'Country Code': 'BOL', 'Sex': 'MLE', 'Suicide Rate': 16.9},
#  {'Country Code': 'BRA', 'Sex': 'BTSX', 'Suicide Rate': 6.1},
#  {'Country Code': 'BRN', 'Sex': 'FMLE', 'Suicide Rate': 2.8},
#  {'Country Code': 'BRN', 'Sex': 'MLE', 'Suicide Rate': 6.2},
#  {'Country Code': 'CAF', 'Sex': 'FMLE', 'Suicide Rate': 6.0},
#  {'Country Code': 'CMR', 'Sex': 'BTSX', 'Suicide Rate': 19.5},
#  {'Country Code': 'COG', 'Sex': 'MLE', 'Suicide Rate': 13.9},
#  {'Country Code': 'COL', 'Sex': 'BTSX', 'Suicide Rate': 7.0},
#  {'Country Code': 'CPV', 'Sex': 'FMLE', 'Suicide Rate': 7.7},
#  {'Country Code': 'CPV', 'Sex': 'MLE', 'Suicide Rate': 24.1},
#  {'Country Code': 'DZA', 'Sex': 'BTSX', 'Suicide Rate': 3.3},
#  {'Country Code': 'EGY', 'Sex': 'FMLE', 'Suicide Rate': 1.7},
#  {'Country Code': 'EGY', 'Sex': 'MLE', 'Suicide Rate': 7.2},
#  {'Country Code': 'EST', 'Sex': 'FMLE', 'Suicide Rate': 4.4},
#  {'Country Code': 'GAB', 'Sex': 'BTSX', 'Suicide Rate': 9.6},
#  {'Country Code': 'GEO', 'Sex': 'MLE', 'Suicide Rate': 12.3},
#  {'Country Code': 'GHA', 'Sex': 'BTSX', 'Suicide Rate': 8.7},
#  {'Country Code': 'GMB', 'Sex': 'FMLE', 'Suicide Rate': 7.3},
#  {'Country Code': 'GMB', 'Sex': 'MLE', 'Suicide Rate': 12.8},
#  {'Country Code': 'GRC', 'Sex': 'FMLE', 'Suicide Rate': 1.5},
#  {'Country Code': 'HTI', 'Sex': 'MLE', 'Suicide Rate': 18.3},
#  {'Country Code': 'IND', 'Sex': 'FMLE', 'Suicide Rate': 14.5},
#  {'Country Code': 'IND', 'Sex': 'MLE', 'Suicide Rate': 18.5},
#  {'Country Code': 'IRN', 'Sex': 'BTSX', 'Suicide Rate': 4.0},
#  {'Country Code': 'KEN', 'Sex': 'FMLE', 'Suicide Rate': 2.1},
#  {'Country Code': 'KEN', 'Sex': 'MLE', 'Suicide Rate': 9.7},
#  {'Country Code': 'KHM', 'Sex': 'BTSX', 'Suicide Rate': 5.9},
#  {'Country Code': 'KIR', 'Sex': 'FMLE', 'Suicide Rate': 5.4},
#  {'Country Code': 'KWT', 'Sex': 'BTSX', 'Suicide Rate': 2.2},
#  {'Country Code': 'LKA', 'Sex': 'MLE', 'Suicide Rate': 23.3},
#  {'Country Code': 'LUX', 'Sex': 'FMLE', 'Suicide Rate': 5.8},
#  {'Country Code': 'LUX', 'Sex': 'MLE', 'Suicide Rate': 15.0},
#  {'Country Code': 'MAR', 'Sex': 'BTSX', 'Suicide Rate': 3.1},
#  {'Country Code': 'MDA', 'Sex': 'FMLE', 'Suicide Rate': 3.8},
#  {'Country Code': 'MDV', 'Sex': 'BTSX', 'Suicide Rate': 2.7},
#  {'Country Code': 'MNE', 'Sex': 'MLE', 'Suicide Rate': 12.6},
#  {'Country Code': 'MRT', 'Sex': 'FMLE', 'Suicide Rate': 3.6},
#  {'Country Code': 'MRT', 'Sex': 'MLE', 'Suicide Rate': 12.1},
#  {'Country Code': 'MWI', 'Sex': 'BTSX', 'Suicide Rate': 7.8},
#  {'Country Code': 'NZL', 'Sex': 'FMLE', 'Suicide Rate': 6.2},
#  {'Country Code': 'NZL', 'Sex': 'MLE', 'Suicide Rate': 17.3},
#  {'Country Code': 'PAK', 'Sex': 'BTSX', 'Suicide Rate': 3.1},
#  {'Country Code': 'PAN', 'Sex': 'FMLE', 'Suicide Rate': 1.2},
#  {'Country Code': 'PHL', 'Sex': 'BTSX', 'Suicide Rate': 3.7},
#  {'Country Code': 'QAT', 'Sex': 'MLE', 'Suicide Rate': 7.3},
#  {'Country Code': 'RWA', 'Sex': 'FMLE', 'Suicide Rate': 6.0},
#  {'Country Code': 'RWA', 'Sex': 'MLE', 'Suicide Rate': 16.9},
#  {'Country Code': 'SDN', 'Sex': 'BTSX', 'Suicide Rate': 9.5},
#  {'Country Code': 'SEN', 'Sex': 'FMLE', 'Suicide Rate': 5.2},
#  {'Country Code': 'SLB', 'Sex': 'BTSX', 'Suicide Rate': 5.9},
#  {'Country Code': 'STP', 'Sex': 'MLE', 'Suicide Rate': 4.2},
#  {'Country Code': 'SVN', 'Sex': 'FMLE', 'Suicide Rate': 4.5},
#  {'Country Code': 'SVN', 'Sex': 'MLE', 'Suicide Rate': 22.4},
#  {'Country Code': 'SWZ', 'Sex': 'BTSX', 'Suicide Rate': 16.7},
#  {'Country Code': 'TON', 'Sex': 'FMLE', 'Suicide Rate': 2.9},
#  {'Country Code': 'TON', 'Sex': 'MLE', 'Suicide Rate': 5.2},
#  {'Country Code': 'TUN', 'Sex': 'BTSX', 'Suicide Rate': 3.2},
#  {'Country Code': 'TUR', 'Sex': 'FMLE', 'Suicide Rate': 3.2},
#  {'Country Code': 'UGA', 'Sex': 'BTSX', 'Suicide Rate': 20.0},
#  {'Country Code': 'VEN', 'Sex': 'MLE', 'Suicide Rate': 6.6},
#  {'Country Code': 'WSM', 'Sex': 'FMLE', 'Suicide Rate': 2.2},
#  {'Country Code': 'WSM', 'Sex': 'MLE', 'Suicide Rate': 8.7},
#  {'Country Code': 'ZAF', 'Sex': 'BTSX', 'Suicide Rate': 12.8},
#  {'Country Code': 'ZMB', 'Sex': 'FMLE', 'Suicide Rate': 6.2},
#  {'Country Code': 'ZMB', 'Sex': 'BTSX', 'Suicide Rate': 12.85462},
#  {'Country Code': 'ZMB', 'Sex': 'BTSX', 'Suicide Rate': 8.44795},
#  {'Country Code': 'AGO', 'Sex': 'MLE', 'Suicide Rate': 14.0},
#  {'Country Code': 'ARG', 'Sex': 'FMLE', 'Suicide Rate': 3.5},
#  {'Country Code': 'ARG', 'Sex': 'MLE', 'Suicide Rate': 15.0},
#  {'Country Code': 'AUS', 'Sex': 'BTSX', 'Suicide Rate': 11.7},
#  {'Country Code': 'BEL', 'Sex': 'MLE', 'Suicide Rate': 22.2},
#  {'Country Code': 'BGD', 'Sex': 'FMLE', 'Suicide Rate': 6.7},
#  {'Country Code': 'BGD', 'Sex': 'MLE', 'Suicide Rate': 5.5},
#  {'Country Code': 'BIH', 'Sex': 'BTSX', 'Suicide Rate': 6.4},
#  {'Country Code': 'BOL', 'Sex': 'BTSX', 'Suicide Rate': 12.9},
#  {'Country Code': 'BTN', 'Sex': 'FMLE', 'Suicide Rate': 8.9},
#  {'Country Code': 'BTN', 'Sex': 'MLE', 'Suicide Rate': 13.8},
#  {'Country Code': 'CAN', 'Sex': 'FMLE', 'Suicide Rate': 5.8},
#  {'Country Code': 'CIV', 'Sex': 'BTSX', 'Suicide Rate': 23.0},
#  {'Country Code': 'COL', 'Sex': 'MLE', 'Suicide Rate': 11.5},
#  {'Country Code': 'CRI', 'Sex': 'FMLE', 'Suicide Rate': 2.3},
#  {'Country Code': 'CRI', 'Sex': 'MLE', 'Suicide Rate': 12.8},
#  {'Country Code': 'CZE', 'Sex': 'FMLE', 'Suicide Rate': 4.2},
#  {'Country Code': 'DEU', 'Sex': 'BTSX', 'Suicide Rate': 9.1},
#  {'Country Code': 'DOM', 'Sex': 'BTSX', 'Suicide Rate': 10.5},
#  {'Country Code': 'ERI', 'Sex': 'MLE', 'Suicide Rate': 22.4},
#  {'Country Code': 'ETH', 'Sex': 'FMLE', 'Suicide Rate': 4.7},
#  {'Country Code': 'ETH', 'Sex': 'MLE', 'Suicide Rate': 18.7},
#  {'Country Code': 'FSM', 'Sex': 'BTSX', 'Suicide Rate': 11.3},
#  {'Country Code': 'GEO', 'Sex': 'BTSX', 'Suicide Rate': 6.7},
#  {'Country Code': 'GNB', 'Sex': 'FMLE', 'Suicide Rate': 6.1},
#  {'Country Code': 'GNB', 'Sex': 'MLE', 'Suicide Rate': 8.9},
#  {'Country Code': 'GRD', 'Sex': 'BTSX', 'Suicide Rate': 1.7},
#  {'Country Code': 'HRV', 'Sex': 'MLE', 'Suicide Rate': 18.8},
#  {'Country Code': 'IDN', 'Sex': 'FMLE', 'Suicide Rate': 2.2},
#  {'Country Code': 'IRQ', 'Sex': 'BTSX', 'Suicide Rate': 4.1},
#  {'Country Code': 'ITA', 'Sex': 'BTSX', 'Suicide Rate': 5.5},
#  {'Country Code': 'JAM', 'Sex': 'MLE', 'Suicide Rate': 3.2},
#  {'Country Code': 'KAZ', 'Sex': 'FMLE', 'Suicide Rate': 7.7},
#  {'Country Code': 'KAZ', 'Sex': 'MLE', 'Suicide Rate': 40.1},
#  {'Country Code': 'KHM', 'Sex': 'FMLE', 'Suicide Rate': 3.2},
#  {'Country Code': 'LAO', 'Sex': 'BTSX', 'Suicide Rate': 9.3},
#  {'Country Code': 'LCA', 'Sex': 'MLE', 'Suicide Rate': 12.7},
#  {'Country Code': 'LTU', 'Sex': 'FMLE', 'Suicide Rate': 6.7},
#  {'Country Code': 'LTU', 'Sex': 'MLE', 'Suicide Rate': 47.5},
#  {'Country Code': 'MDA', 'Sex': 'BTSX', 'Suicide Rate': 13.4},
#  {'Country Code': 'MEX', 'Sex': 'BTSX', 'Suicide Rate': 5.2},
#  {'Country Code': 'MMR', 'Sex': 'MLE', 'Suicide Rate': 6.3},
#  {'Country Code': 'MOZ', 'Sex': 'FMLE', 'Suicide Rate': 4.1},
#  {'Country Code': 'MYS', 'Sex': 'BTSX', 'Suicide Rate': 6.2},
#  {'Country Code': 'NGA', 'Sex': 'BTSX', 'Suicide Rate': 17.3},
#  {'Country Code': 'NIC', 'Sex': 'MLE', 'Suicide Rate': 19.2},
#  {'Country Code': 'NPL', 'Sex': 'FMLE', 'Suicide Rate': 8.0},
#  {'Country Code': 'NPL', 'Sex': 'MLE', 'Suicide Rate': 11.4},
#  {'Country Code': 'PAK', 'Sex': 'FMLE', 'Suicide Rate': 3.1},
#  {'Country Code': 'PNG', 'Sex': 'BTSX', 'Suicide Rate': 7.0},
#  {'Country Code': 'PRY', 'Sex': 'MLE', 'Suicide Rate': 12.3},
#  {'Country Code': 'RUS', 'Sex': 'FMLE', 'Suicide Rate': 7.5},
#  {'Country Code': 'RUS', 'Sex': 'MLE', 'Suicide Rate': 48.3},
#  {'Country Code': 'SEN', 'Sex': 'BTSX', 'Suicide Rate': 11.8},
#  {'Country Code': 'SLE', 'Sex': 'BTSX', 'Suicide Rate': 16.1},
#  {'Country Code': 'SSD', 'Sex': 'MLE', 'Suicide Rate': 8.3},
#  {'Country Code': 'SVK', 'Sex': 'FMLE', 'Suicide Rate': 2.6},
#  {'Country Code': 'SYC', 'Sex': 'BTSX', 'Suicide Rate': 8.3},
#  {'Country Code': 'TGO', 'Sex': 'BTSX', 'Suicide Rate': 16.6},
#  {'Country Code': 'THA', 'Sex': 'MLE', 'Suicide Rate': 21.4},
#  {'Country Code': 'TLS', 'Sex': 'FMLE', 'Suicide Rate': 3.7},
#  {'Country Code': 'TLS', 'Sex': 'MLE', 'Suicide Rate': 9.0},
#  {'Country Code': 'TUN', 'Sex': 'FMLE', 'Suicide Rate': 2.2},
#  {'Country Code': 'UKR', 'Sex': 'BTSX', 'Suicide Rate': 18.5},
#  {'Country Code': 'VCT', 'Sex': 'MLE', 'Suicide Rate': 3.9},
#  {'Country Code': 'VUT', 'Sex': 'FMLE', 'Suicide Rate': 2.7},
#  {'Country Code': 'VUT', 'Sex': 'MLE', 'Suicide Rate': 8.1},
#  {'Country Code': 'ZMB', 'Sex': 'BTSX', 'Suicide Rate': 11.3},
#  {'Country Code': 'AGO', 'Sex': 'BTSX', 'Suicide Rate': 8.9},
#  {'Country Code': 'ARG', 'Sex': 'BTSX', 'Suicide Rate': 9.1},
#  {'Country Code': 'AUS', 'Sex': 'FMLE', 'Suicide Rate': 6.0},
#  {'Country Code': 'AUS', 'Sex': 'MLE', 'Suicide Rate': 17.4},
#  {'Country Code': 'BEL', 'Sex': 'BTSX', 'Suicide Rate': 15.7},
#  {'Country Code': 'BGD', 'Sex': 'BTSX', 'Suicide Rate': 6.1},
#  {'Country Code': 'BIH', 'Sex': 'MLE', 'Suicide Rate': 10.6},
#  {'Country Code': 'BOL', 'Sex': 'FMLE', 'Suicide Rate': 8.9},
#  {'Country Code': 'BTN', 'Sex': 'BTSX', 'Suicide Rate': 11.6},
#  {'Country Code': 'CAN', 'Sex': 'BTSX', 'Suicide Rate': 10.4},
#  {'Country Code': 'CHE', 'Sex': 'MLE', 'Suicide Rate': 15.8},
#  {'Country Code': 'CIV', 'Sex': 'FMLE', 'Suicide Rate': 13.0},
#  {'Country Code': 'CIV', 'Sex': 'MLE', 'Suicide Rate': 32.0},
#  {'Country Code': 'COG', 'Sex': 'FMLE', 'Suicide Rate': 5.0},
#  {'Country Code': 'CRI', 'Sex': 'BTSX', 'Suicide Rate': 7.5},
#  {'Country Code': 'DEU', 'Sex': 'MLE', 'Suicide Rate': 13.6},
#  {'Country Code': 'DOM', 'Sex': 'FMLE', 'Suicide Rate': 3.2},
#  {'Country Code': 'DOM', 'Sex': 'MLE', 'Suicide Rate': 17.9},
#  {'Country Code': 'ERI', 'Sex': 'BTSX', 'Suicide Rate': 13.8},
#  {'Country Code': 'ETH', 'Sex': 'BTSX', 'Suicide Rate': 11.4},
#  {'Country Code': 'FSM', 'Sex': 'MLE', 'Suicide Rate': 16.2},
#  {'Country Code': 'GEO', 'Sex': 'FMLE', 'Suicide Rate': 1.9},
#  {'Country Code': 'GNB', 'Sex': 'BTSX', 'Suicide Rate': 7.4},
#  {'Country Code': 'GRD', 'Sex': 'FMLE', 'Suicide Rate': 1.0},
#  {'Country Code': 'GRD', 'Sex': 'MLE', 'Suicide Rate': 2.1},
#  {'Country Code': 'HRV', 'Sex': 'BTSX', 'Suicide Rate': 11.5},
#  {'Country Code': 'IDN', 'Sex': 'BTSX', 'Suicide Rate': 3.7},
#  {'Country Code': 'IRQ', 'Sex': 'FMLE', 'Suicide Rate': 3.4},
#  {'Country Code': 'IRQ', 'Sex': 'MLE', 'Suicide Rate': 4.7},
#  {'Country Code': 'ITA', 'Sex': 'FMLE', 'Suicide Rate': 2.6},
#  {'Country Code': 'KAZ', 'Sex': 'BTSX', 'Suicide Rate': 22.8},
#  {'Country Code': 'KIR', 'Sex': 'MLE', 'Suicide Rate': 25.9},
#  {'Country Code': 'LAO', 'Sex': 'FMLE', 'Suicide Rate': 6.1},
#  {'Country Code': 'LAO', 'Sex': 'MLE', 'Suicide Rate': 12.9},
#  {'Country Code': 'LBY', 'Sex': 'FMLE', 'Suicide Rate': 2.3},
#  {'Country Code': 'LCA', 'Sex': 'BTSX', 'Suicide Rate': 7.3},
#  {'Country Code': 'LTU', 'Sex': 'BTSX', 'Suicide Rate': 25.7},
#  {'Country Code': 'MDA', 'Sex': 'MLE', 'Suicide Rate': 24.1},
#  {'Country Code': 'MEX', 'Sex': 'FMLE', 'Suicide Rate': 2.3},
#  {'Country Code': 'MEX', 'Sex': 'MLE', 'Suicide Rate': 8.2},
#  {'Country Code': 'MMR', 'Sex': 'BTSX', 'Suicide Rate': 8.1},
#  {'Country Code': 'MOZ', 'Sex': 'BTSX', 'Suicide Rate': 8.4},
#  {'Country Code': 'MYS', 'Sex': 'FMLE', 'Suicide Rate': 3.6},
#  {'Country Code': 'MYS', 'Sex': 'MLE', 'Suicide Rate': 8.7},
#  {'Country Code': 'NGA', 'Sex': 'FMLE', 'Suicide Rate': 17.1},
#  {'Country Code': 'NPL', 'Sex': 'BTSX', 'Suicide Rate': 9.6},
#  {'Country Code': 'PAN', 'Sex': 'MLE', 'Suicide Rate': 7.6},
#  {'Country Code': 'PNG', 'Sex': 'FMLE', 'Suicide Rate': 3.8},
#  {'Country Code': 'PNG', 'Sex': 'MLE', 'Suicide Rate': 10.2},
#  {'Country Code': 'PRT', 'Sex': 'FMLE', 'Suicide Rate': 3.8},
#  {'Country Code': 'PRY', 'Sex': 'BTSX', 'Suicide Rate': 9.3},
#  {'Country Code': 'RUS', 'Sex': 'BTSX', 'Suicide Rate': 26.5},
#  {'Country Code': 'SEN', 'Sex': 'MLE', 'Suicide Rate': 20.3},
#  {'Country Code': 'SLE', 'Sex': 'FMLE', 'Suicide Rate': 14.2},
#  {'Country Code': 'SLE', 'Sex': 'MLE', 'Suicide Rate': 18.2},
#  {'Country Code': 'SSD', 'Sex': 'BTSX', 'Suicide Rate': 6.1},
#  {'Country Code': 'SVK', 'Sex': 'BTSX', 'Suicide Rate': 10.1},
#  {'Country Code': 'SYC', 'Sex': 'FMLE', 'Suicide Rate': 2.1},
#  {'Country Code': 'SYC', 'Sex': 'MLE', 'Suicide Rate': 15.0},
#  {'Country Code': 'TGO', 'Sex': 'FMLE', 'Suicide Rate': 10.9},
#  {'Country Code': 'TLS', 'Sex': 'BTSX', 'Suicide Rate': 6.4},
#  {'Country Code': 'TUR', 'Sex': 'MLE', 'Suicide Rate': 11.3},
#  {'Country Code': 'UKR', 'Sex': 'FMLE', 'Suicide Rate': 4.7},
#  {'Country Code': 'UKR', 'Sex': 'MLE', 'Suicide Rate': 34.5},
#  {'Country Code': 'UZB', 'Sex': 'FMLE', 'Suicide Rate': 4.6},
#  {'Country Code': 'VCT', 'Sex': 'BTSX', 'Suicide Rate': 2.4},
#  {'Country Code': 'VUT', 'Sex': 'BTSX', 'Suicide Rate': 5.4},
#  {'Country Code': 'ZMB', 'Sex': 'MLE', 'Suicide Rate': 17.5},
#  {'Country Code': 'ALB', 'Sex': 'FMLE', 'Suicide Rate': 4.3},
#  {'Country Code': 'ARE', 'Sex': 'MLE', 'Suicide Rate': 3.5},
#  {'Country Code': 'AZE', 'Sex': 'FMLE', 'Suicide Rate': 1.0},
#  {'Country Code': 'AZE', 'Sex': 'BTSX', 'Suicide Rate': 2.6},
#  {'Country Code': 'BEN', 'Sex': 'FMLE', 'Suicide Rate': 9.6},
#  {'Country Code': 'BEN', 'Sex': 'BTSX', 'Suicide Rate': 15.7},
#  {'Country Code': 'BFA', 'Sex': 'MLE', 'Suicide Rate': 22.4},
#  {'Country Code': 'BHR', 'Sex': 'MLE', 'Suicide Rate': 7.9},
#  {'Country Code': 'BRB', 'Sex': 'FMLE', 'Suicide Rate': 0.3},
#  {'Country Code': 'BRB', 'Sex': 'BTSX', 'Suicide Rate': 0.4},
#  {'Country Code': 'BWA', 'Sex': 'FMLE', 'Suicide Rate': 5.7},
#  {'Country Code': 'CAF', 'Sex': 'MLE', 'Suicide Rate': 18.0},
#  {'Country Code': 'CHL', 'Sex': 'MLE', 'Suicide Rate': 16.0},
#  {'Country Code': 'COD', 'Sex': 'BTSX', 'Suicide Rate': 9.7},
#  {'Country Code': 'COM', 'Sex': 'FMLE', 'Suicide Rate': 5.4},
#  {'Country Code': 'COM', 'Sex': 'BTSX', 'Suicide Rate': 11.1},
#  {'Country Code': 'CYP', 'Sex': 'MLE', 'Suicide Rate': 7.2},
#  {'Country Code': 'ECU', 'Sex': 'FMLE', 'Suicide Rate': 3.8},
#  {'Country Code': 'ECU', 'Sex': 'BTSX', 'Suicide Rate': 7.2},
#  {'Country Code': 'ESP', 'Sex': 'FMLE', 'Suicide Rate': 3.1},
#  {'Country Code': 'EST', 'Sex': 'MLE', 'Suicide Rate': 25.6},
#  {'Country Code': 'FJI', 'Sex': 'MLE', 'Suicide Rate': 8.8},
#  {'Country Code': 'GIN', 'Sex': 'FMLE', 'Suicide Rate': 8.4},
#  {'Country Code': 'GIN', 'Sex': 'BTSX', 'Suicide Rate': 10.5},
#  {'Country Code': 'GNQ', 'Sex': 'FMLE', 'Suicide Rate': 10.8},
#  {'Country Code': 'GRC', 'Sex': 'MLE', 'Suicide Rate': 6.1},
#  {'Country Code': 'GUY', 'Sex': 'FMLE', 'Suicide Rate': 14.2},
#  {'Country Code': 'HTI', 'Sex': 'FMLE', 'Suicide Rate': 6.4},
#  {'Country Code': 'HUN', 'Sex': 'MLE', 'Suicide Rate': 22.2},
#  {'Country Code': 'IRL', 'Sex': 'BTSX', 'Suicide Rate': 10.9},
#  {'Country Code': 'IRL', 'Sex': 'MLE', 'Suicide Rate': 17.6},
#  {'Country Code': 'JOR', 'Sex': 'FMLE', 'Suicide Rate': 2.7},
#  {'Country Code': 'KGZ', 'Sex': 'BTSX', 'Suicide Rate': 9.1},
#  {'Country Code': 'KGZ', 'Sex': 'MLE', 'Suicide Rate': 14.8},
#  {'Country Code': 'KOR', 'Sex': 'BTSX', 'Suicide Rate': 20.2},
#  {'Country Code': 'LBR', 'Sex': 'FMLE', 'Suicide Rate': 13.0},
#  {'Country Code': 'LKA', 'Sex': 'FMLE', 'Suicide Rate': 6.2},
#  {'Country Code': 'LVA', 'Sex': 'BTSX', 'Suicide Rate': 17.2},
#  {'Country Code': 'LVA', 'Sex': 'MLE', 'Suicide Rate': 31.0},
#  {'Country Code': 'MDG', 'Sex': 'BTSX', 'Suicide Rate': 6.9},
#  {'Country Code': 'MLI', 'Sex': 'FMLE', 'Suicide Rate': 4.7},
#  {'Country Code': 'MNE', 'Sex': 'FMLE', 'Suicide Rate': 3.6},
#  {'Country Code': 'MNG', 'Sex': 'MLE', 'Suicide Rate': 23.3},
#  {'Country Code': 'MUS', 'Sex': 'BTSX', 'Suicide Rate': 7.3},
#  {'Country Code': 'MUS', 'Sex': 'MLE', 'Suicide Rate': 12.5},
#  {'Country Code': 'NLD', 'Sex': 'FMLE', 'Suicide Rate': 6.4},
#  {'Country Code': 'OMN', 'Sex': 'BTSX', 'Suicide Rate': 3.5},
#  {'Country Code': 'OMN', 'Sex': 'MLE', 'Suicide Rate': 4.8},
#  {'Country Code': 'PER', 'Sex': 'BTSX', 'Suicide Rate': 5.1},
#  {'Country Code': 'PRK', 'Sex': 'FMLE', 'Suicide Rate': 8.0},
#  {'Country Code': 'QAT', 'Sex': 'FMLE', 'Suicide Rate': 1.1},
#  {'Country Code': 'ROU', 'Sex': 'MLE', 'Suicide Rate': 13.9},
#  {'Country Code': 'SAU', 'Sex': 'BTSX', 'Suicide Rate': 3.4},
#  {'Country Code': 'SAU', 'Sex': 'MLE', 'Suicide Rate': 4.6},
#  {'Country Code': 'SOM', 'Sex': 'FMLE', 'Suicide Rate': 5.4},
#  {'Country Code': 'STP', 'Sex': 'FMLE', 'Suicide Rate': 2.1},
#  {'Country Code': 'SUR', 'Sex': 'MLE', 'Suicide Rate': 36.1},
#  {'Country Code': 'SWE', 'Sex': 'BTSX', 'Suicide Rate': 11.7},
#  {'Country Code': 'SWE', 'Sex': 'MLE', 'Suicide Rate': 15.8},
#  {'Country Code': 'TJK', 'Sex': 'FMLE', 'Suicide Rate': 1.7},
#  {'Country Code': 'TTO', 'Sex': 'BTSX', 'Suicide Rate': 12.9},
#  {'Country Code': 'TTO', 'Sex': 'MLE', 'Suicide Rate': 21.9},
#  {'Country Code': 'TZA', 'Sex': 'BTSX', 'Suicide Rate': 9.6},
#  {'Country Code': 'USA', 'Sex': 'FMLE', 'Suicide Rate': 6.4},
#  {'Country Code': 'VEN', 'Sex': 'FMLE', 'Suicide Rate': 1.2},
#  {'Country Code': 'VNM', 'Sex': 'MLE', 'Suicide Rate': 10.8},
#  {'Country Code': 'YEM', 'Sex': 'BTSX', 'Suicide Rate': 9.8},
#  {'Country Code': 'YEM', 'Sex': 'MLE', 'Suicide Rate': 13.4},
#  {'Country Code': 'YEM', 'Sex': 'BTSX', 'Suicide Rate': 11.95732},
#  {'Country Code': 'YEM', 'Sex': 'BTSX', 'Suicide Rate': 9.25494},
#  {'Country Code': 'AFG', 'Sex': 'MLE', 'Suicide Rate': 10.6},
#  {'Country Code': 'ATG', 'Sex': 'FMLE', 'Suicide Rate': 0.9},
#  {'Country Code': 'AUT', 'Sex': 'MLE', 'Suicide Rate': 17.5},
#  {'Country Code': 'BGR', 'Sex': 'FMLE', 'Suicide Rate': 3.2},
#  {'Country Code': 'BHS', 'Sex': 'BTSX', 'Suicide Rate': 1.6},
#  {'Country Code': 'BIH', 'Sex': 'FMLE', 'Suicide Rate': 2.5},
#  {'Country Code': 'BLR', 'Sex': 'MLE', 'Suicide Rate': 39.3},
#  {'Country Code': 'BLZ', 'Sex': 'BTSX', 'Suicide Rate': 5.9},
#  {'Country Code': 'BRA', 'Sex': 'MLE', 'Suicide Rate': 9.7},
#  {'Country Code': 'CHE', 'Sex': 'FMLE', 'Suicide Rate': 6.9},
#  {'Country Code': 'CHN', 'Sex': 'BTSX', 'Suicide Rate': 8.0},
#  {'Country Code': 'CMR', 'Sex': 'MLE', 'Suicide Rate': 26.9},
#  {'Country Code': 'CUB', 'Sex': 'FMLE', 'Suicide Rate': 4.1},
#  {'Country Code': 'CZE', 'Sex': 'BTSX', 'Suicide Rate': 10.5},
#  {'Country Code': 'DEU', 'Sex': 'FMLE', 'Suicide Rate': 4.8},
#  {'Country Code': 'DJI', 'Sex': 'MLE', 'Suicide Rate': 11.9},
#  {'Country Code': 'DNK', 'Sex': 'BTSX', 'Suicide Rate': 9.2},
#  {'Country Code': 'DZA', 'Sex': 'MLE', 'Suicide Rate': 4.9},
#  {'Country Code': 'FIN', 'Sex': 'FMLE', 'Suicide Rate': 6.8},
#  {'Country Code': 'FRA', 'Sex': 'BTSX', 'Suicide Rate': 12.1},
#  {'Country Code': 'FSM', 'Sex': 'FMLE', 'Suicide Rate': 6.2},
#  {'Country Code': 'GAB', 'Sex': 'MLE', 'Suicide Rate': 15.0},
#  {'Country Code': 'GBR', 'Sex': 'BTSX', 'Suicide Rate': 7.6},
#  {'Country Code': 'GHA', 'Sex': 'MLE', 'Suicide Rate': 15.8},
#  {'Country Code': 'GTM', 'Sex': 'BTSX', 'Suicide Rate': 2.9},
#  {'Country Code': 'HND', 'Sex': 'MLE', 'Suicide Rate': 5.3},
#  {'Country Code': 'IRN', 'Sex': 'FMLE', 'Suicide Rate': 3.1},
#  {'Country Code': 'ISL', 'Sex': 'BTSX', 'Suicide Rate': 13.3},
#  {'Country Code': 'ISR', 'Sex': 'FMLE', 'Suicide Rate': 2.4},
#  {'Country Code': 'ITA', 'Sex': 'MLE', 'Suicide Rate': 8.4},
#  {'Country Code': 'JAM', 'Sex': 'BTSX', 'Suicide Rate': 2.0},
#  {'Country Code': 'JPN', 'Sex': 'MLE', 'Suicide Rate': 20.5},
#  {'Country Code': 'KWT', 'Sex': 'FMLE', 'Suicide Rate': 1.7},
#  {'Country Code': 'LBN', 'Sex': 'BTSX', 'Suicide Rate': 3.2},
#  {'Country Code': 'LBY', 'Sex': 'MLE', 'Suicide Rate': 8.7},
#  {'Country Code': 'LSO', 'Sex': 'MLE', 'Suicide Rate': 22.7},
#  {'Country Code': 'MAR', 'Sex': 'FMLE', 'Suicide Rate': 3.6},
#  {'Country Code': 'MDV', 'Sex': 'FMLE', 'Suicide Rate': 1.6},
#  {'Country Code': 'MKD', 'Sex': 'BTSX', 'Suicide Rate': 6.2},
#  {'Country Code': 'MLT', 'Sex': 'MLE', 'Suicide Rate': 10.3},
#  {'Country Code': 'MWI', 'Sex': 'FMLE', 'Suicide Rate': 3.2},
#  {'Country Code': 'NAM', 'Sex': 'BTSX', 'Suicide Rate': 11.5},
#  {'Country Code': 'NER', 'Sex': 'FMLE', 'Suicide Rate': 6.7},
#  {'Country Code': 'NGA', 'Sex': 'MLE', 'Suicide Rate': 17.5},
#  {'Country Code': 'NIC', 'Sex': 'BTSX', 'Suicide Rate': 11.9},
#  {'Country Code': 'NOR', 'Sex': 'MLE', 'Suicide Rate': 13.6},
#  {'Country Code': 'PHL', 'Sex': 'FMLE', 'Suicide Rate': 2.3},
#  {'Country Code': 'POL', 'Sex': 'BTSX', 'Suicide Rate': 13.4},
#  {'Country Code': 'PRT', 'Sex': 'MLE', 'Suicide Rate': 14.3},
#  {'Country Code': 'SDN', 'Sex': 'FMLE', 'Suicide Rate': 4.6},
#  {'Country Code': 'SGP', 'Sex': 'BTSX', 'Suicide Rate': 7.9},
#  {'Country Code': 'SLB', 'Sex': 'FMLE', 'Suicide Rate': 3.2},
#  {'Country Code': 'SLV', 'Sex': 'BTSX', 'Suicide Rate': 13.5},
#  {'Country Code': 'SRB', 'Sex': 'MLE', 'Suicide Rate': 17.3},
#  {'Country Code': 'SWZ', 'Sex': 'FMLE', 'Suicide Rate': 9.6},
#  {'Country Code': 'SYR', 'Sex': 'BTSX', 'Suicide Rate': 2.4},
#  {'Country Code': 'TCD', 'Sex': 'FMLE', 'Suicide Rate': 13.8},
#  {'Country Code': 'TGO', 'Sex': 'MLE', 'Suicide Rate': 22.7},
#  {'Country Code': 'THA', 'Sex': 'BTSX', 'Suicide Rate': 12.9},
#  {'Country Code': 'TKM', 'Sex': 'MLE', 'Suicide Rate': 11.0},
#  {'Country Code': 'UGA', 'Sex': 'FMLE', 'Suicide Rate': 18.7},
#  {'Country Code': 'URY', 'Sex': 'BTSX', 'Suicide Rate': 16.5},
#  {'Country Code': 'UZB', 'Sex': 'MLE', 'Suicide Rate': 10.3},
#  {'Country Code': 'ZAF', 'Sex': 'FMLE', 'Suicide Rate': 5.1},
#  {'Country Code': 'ZWE', 'Sex': 'BTSX', 'Suicide Rate': 19.1},
#  {'Country Code': 'ATG', 'Sex': 'MLE', 'Suicide Rate': 0.0},
#  {'Country Code': 'ATG', 'Sex': 'BTSX', 'Suicide Rate': 4.30386}]

# %%
country_codes = []
for country in list_of_data:
    country_codes.append(country['Country Code'])

# %%
country_codes = set(country_codes)

# %%
len(country_codes)
# Out:
# 183

# %%
data_dictionary = []
for country in country_codes:
    data_dictionary.append({'Country Code': country, 'Male Suicide Rate':'', 'Female Suicide Rate':'', 'Combined Suicide Rate':''})

# %%
len(data_dictionary)
# Out:
# 183

# %%
for data in list_of_data:
    for country in data_dictionary:
        if data['Country Code'] == country['Country Code']:
            if data['Sex'] == 'MLE':
                country['Male Suicide Rate'] = data['Suicide Rate']
            elif data['Sex'] == "FMLE":
                country['Female Suicide Rate'] = data['Suicide Rate']
            elif data['Sex'] == 'BTSX':
                country['Combined Suicide Rate'] = data['Suicide Rate']

# %%
data_dictionary
# Out:
# [{'Country Code': 'PER',
#   'Male Suicide Rate': 7.6,
#   'Female Suicide Rate': 2.7,
#   'Combined Suicide Rate': 5.1},
#  {'Country Code': 'VNM',
#   'Male Suicide Rate': 10.8,
#   'Female Suicide Rate': 3.4,
#   'Combined Suicide Rate': 7.0},
#  {'Country Code': 'BGR',
#   'Male Suicide Rate': 13.1,
#   'Female Suicide Rate': 3.2,
#   'Combined Suicide Rate': 7.9},
#  {'Country Code': 'BDI',
#   'Male Suicide Rate': 23.1,
#   'Female Suicide Rate': 7.7,
#   'Combined Suicide Rate': 15.0},
#  {'Country Code': 'BHS',
#   'Male Suicide Rate': 2.8,
#   'Female Suicide Rate': 0.5,
#   'Combined Suicide Rate': 1.6},
#  {'Country Code': 'MLI',
#   'Male Suicide Rate': 13.5,
#   'Female Suicide Rate': 4.7,
#   'Combined Suicide Rate': 8.9},
#  {'Country Code': 'ALB',
#   'Male Suicide Rate': 7.0,
#   'Female Suicide Rate': 4.3,
#   'Combined Suicide Rate': 5.6},
#  {'Country Code': 'DOM',
#   'Male Suicide Rate': 17.9,
#   'Female Suicide Rate': 3.2,
#   'Combined Suicide Rate': 10.5},
#  {'Country Code': 'HRV',
#   'Male Suicide Rate': 18.8,
#   'Female Suicide Rate': 5.1,
#   'Combined Suicide Rate': 11.5},
#  {'Country Code': 'BRN',
#   'Male Suicide Rate': 6.2,
#   'Female Suicide Rate': 2.8,
#   'Combined Suicide Rate': 4.5},
#  {'Country Code': 'DZA',
#   'Male Suicide Rate': 4.9,
#   'Female Suicide Rate': 1.8,
#   'Combined Suicide Rate': 3.3},
#  {'Country Code': 'GNQ',
#   'Male Suicide Rate': 31.3,
#   'Female Suicide Rate': 10.8,
#   'Combined Suicide Rate': 22.0},
#  {'Country Code': 'COM',
#   'Male Suicide Rate': 17.6,
#   'Female Suicide Rate': 5.4,
#   'Combined Suicide Rate': 11.1},
#  {'Country Code': 'BGD',
#   'Male Suicide Rate': 5.5,
#   'Female Suicide Rate': 6.7,
#   'Combined Suicide Rate': 6.1},
#  {'Country Code': 'HTI',
#   'Male Suicide Rate': 18.3,
#   'Female Suicide Rate': 6.4,
#   'Combined Suicide Rate': 12.2},
#  {'Country Code': 'MMR',
#   'Male Suicide Rate': 6.3,
#   'Female Suicide Rate': 9.8,
#   'Combined Suicide Rate': 8.1},
#  {'Country Code': 'POL',
#   'Male Suicide Rate': 23.9,
#   'Female Suicide Rate': 3.4,
#   'Combined Suicide Rate': 13.4},
#  {'Country Code': 'TCD',
#   'Male Suicide Rate': 17.1,
#   'Female Suicide Rate': 13.8,
#   'Combined Suicide Rate': 15.5},
#  {'Country Code': 'BTN',
#   'Male Suicide Rate': 13.8,
#   'Female Suicide Rate': 8.9,
#   'Combined Suicide Rate': 11.6},
#  {'Country Code': 'CPV',
#   'Male Suicide Rate': 24.1,
#   'Female Suicide Rate': 7.7,
#   'Combined Suicide Rate': 15.1},
#  {'Country Code': 'HND',
#   'Male Suicide Rate': 5.3,
#   'Female Suicide Rate': 1.7,
#   'Combined Suicide Rate': 3.4},
#  {'Country Code': 'GRC',
#   'Male Suicide Rate': 6.1,
#   'Female Suicide Rate': 1.5,
#   'Combined Suicide Rate': 3.8},
#  {'Country Code': 'FRA',
#   'Male Suicide Rate': 17.9,
#   'Female Suicide Rate': 6.5,
#   'Combined Suicide Rate': 12.1},
#  {'Country Code': 'USA',
#   'Male Suicide Rate': 21.1,
#   'Female Suicide Rate': 6.4,
#   'Combined Suicide Rate': 13.7},
#  {'Country Code': 'STP',
#   'Male Suicide Rate': 4.2,
#   'Female Suicide Rate': 2.1,
#   'Combined Suicide Rate': 3.1},
#  {'Country Code': 'GRD',
#   'Male Suicide Rate': 2.1,
#   'Female Suicide Rate': 1.0,
#   'Combined Suicide Rate': 1.7},
#  {'Country Code': 'GUY',
#   'Male Suicide Rate': 46.6,
#   'Female Suicide Rate': 14.2,
#   'Combined Suicide Rate': 30.2},
#  {'Country Code': 'JAM',
#   'Male Suicide Rate': 3.2,
#   'Female Suicide Rate': 0.9,
#   'Combined Suicide Rate': 2.0},
#  {'Country Code': 'FJI',
#   'Male Suicide Rate': 8.8,
#   'Female Suicide Rate': 2.5,
#   'Combined Suicide Rate': 5.5},
#  {'Country Code': 'CHL',
#   'Male Suicide Rate': 16.0,
#   'Female Suicide Rate': 3.8,
#   'Combined Suicide Rate': 9.7},
#  {'Country Code': 'ECU',
#   'Male Suicide Rate': 10.7,
#   'Female Suicide Rate': 3.8,
#   'Combined Suicide Rate': 7.2},
#  {'Country Code': 'ERI',
#   'Male Suicide Rate': 22.4,
#   'Female Suicide Rate': 6.1,
#   'Combined Suicide Rate': 13.8},
#  {'Country Code': 'NGA',
#   'Male Suicide Rate': 17.5,
#   'Female Suicide Rate': 17.1,
#   'Combined Suicide Rate': 17.3},
#  {'Country Code': 'ARG',
#   'Male Suicide Rate': 15.0,
#   'Female Suicide Rate': 3.5,
#   'Combined Suicide Rate': 9.1},
#  {'Country Code': 'UZB',
#   'Male Suicide Rate': 10.3,
#   'Female Suicide Rate': 4.6,
#   'Combined Suicide Rate': 7.4},
#  {'Country Code': 'ZWE',
#   'Male Suicide Rate': 29.1,
#   'Female Suicide Rate': 11.1,
#   'Combined Suicide Rate': 19.1},
#  {'Country Code': 'GEO',
#   'Male Suicide Rate': 12.3,
#   'Female Suicide Rate': 1.9,
#   'Combined Suicide Rate': 6.7},
#  {'Country Code': 'PNG',
#   'Male Suicide Rate': 10.2,
#   'Female Suicide Rate': 3.8,
#   'Combined Suicide Rate': 7.0},
#  {'Country Code': 'TTO',
#   'Male Suicide Rate': 21.9,
#   'Female Suicide Rate': 4.3,
#   'Combined Suicide Rate': 12.9},
#  {'Country Code': 'RWA',
#   'Male Suicide Rate': 16.9,
#   'Female Suicide Rate': 6.0,
#   'Combined Suicide Rate': 11.0},
#  {'Country Code': 'IRN',
#   'Male Suicide Rate': 4.9,
#   'Female Suicide Rate': 3.1,
#   'Combined Suicide Rate': 4.0},
#  {'Country Code': 'MEX',
#   'Male Suicide Rate': 8.2,
#   'Female Suicide Rate': 2.3,
#   'Combined Suicide Rate': 5.2},
#  {'Country Code': 'MWI',
#   'Male Suicide Rate': 13.7,
#   'Female Suicide Rate': 3.2,
#   'Combined Suicide Rate': 7.8},
#  {'Country Code': 'COD',
#   'Male Suicide Rate': 15.0,
#   'Female Suicide Rate': 4.9,
#   'Combined Suicide Rate': 9.7},
#  {'Country Code': 'PAN',
#   'Male Suicide Rate': 7.6,
#   'Female Suicide Rate': 1.2,
#   'Combined Suicide Rate': 4.4},
#  {'Country Code': 'SVK',
#   'Male Suicide Rate': 18.4,
#   'Female Suicide Rate': 2.6,
#   'Combined Suicide Rate': 10.1},
#  {'Country Code': 'COL',
#   'Male Suicide Rate': 11.5,
#   'Female Suicide Rate': 2.8,
#   'Combined Suicide Rate': 7.0},
#  {'Country Code': 'CUB',
#   'Male Suicide Rate': 16.4,
#   'Female Suicide Rate': 4.1,
#   'Combined Suicide Rate': 10.1},
#  {'Country Code': 'SLB',
#   'Male Suicide Rate': 8.5,
#   'Female Suicide Rate': 3.2,
#   'Combined Suicide Rate': 5.9},
#  {'Country Code': 'YEM',
#   'Male Suicide Rate': 13.4,
#   'Female Suicide Rate': 6.2,
#   'Combined Suicide Rate': 9.25494},
#  {'Country Code': 'SUR',
#   'Male Suicide Rate': 36.1,
#   'Female Suicide Rate': 10.9,
#   'Combined Suicide Rate': 23.2},
#  {'Country Code': 'MNG',
#   'Male Suicide Rate': 23.3,
#   'Female Suicide Rate': 3.8,
#   'Combined Suicide Rate': 13.3},
#  {'Country Code': 'SYC',
#   'Male Suicide Rate': 15.0,
#   'Female Suicide Rate': 2.1,
#   'Combined Suicide Rate': 8.3},
#  {'Country Code': 'ARE',
#   'Male Suicide Rate': 3.5,
#   'Female Suicide Rate': 0.8,
#   'Combined Suicide Rate': 2.7},
#  {'Country Code': 'ARM',
#   'Male Suicide Rate': 10.1,
#   'Female Suicide Rate': 2.0,
#   'Combined Suicide Rate': 5.7},
#  {'Country Code': 'GNB',
#   'Male Suicide Rate': 8.9,
#   'Female Suicide Rate': 6.1,
#   'Combined Suicide Rate': 7.4},
#  {'Country Code': 'MDA',
#   'Male Suicide Rate': 24.1,
#   'Female Suicide Rate': 3.8,
#   'Combined Suicide Rate': 13.4},
#  {'Country Code': 'AUT',
#   'Male Suicide Rate': 17.5,
#   'Female Suicide Rate': 5.7,
#   'Combined Suicide Rate': 11.4},
#  {'Country Code': 'SWE',
#   'Male Suicide Rate': 15.8,
#   'Female Suicide Rate': 7.4,
#   'Combined Suicide Rate': 11.7},
#  {'Country Code': 'MDG',
#   'Male Suicide Rate': 10.5,
#   'Female Suicide Rate': 3.6,
#   'Combined Suicide Rate': 6.9},
#  {'Country Code': 'MAR',
#   'Male Suicide Rate': 2.5,
#   'Female Suicide Rate': 3.6,
#   'Combined Suicide Rate': 3.1},
#  {'Country Code': 'IRL',
#   'Male Suicide Rate': 17.6,
#   'Female Suicide Rate': 4.2,
#   'Combined Suicide Rate': 10.9},
#  {'Country Code': 'ROU',
#   'Male Suicide Rate': 13.9,
#   'Female Suicide Rate': 2.4,
#   'Combined Suicide Rate': 8.0},
#  {'Country Code': 'NAM',
#   'Male Suicide Rate': 19.4,
#   'Female Suicide Rate': 4.9,
#   'Combined Suicide Rate': 11.5},
#  {'Country Code': 'DJI',
#   'Male Suicide Rate': 11.9,
#   'Female Suicide Rate': 5.3,
#   'Combined Suicide Rate': 8.5},
#  {'Country Code': 'AFG',
#   'Male Suicide Rate': 10.6,
#   'Female Suicide Rate': 2.1,
#   'Combined Suicide Rate': 6.4},
#  {'Country Code': 'SGP',
#   'Male Suicide Rate': 11.1,
#   'Female Suicide Rate': 4.9,
#   'Combined Suicide Rate': 7.9},
#  {'Country Code': 'BEN',
#   'Male Suicide Rate': 22.6,
#   'Female Suicide Rate': 9.6,
#   'Combined Suicide Rate': 15.7},
#  {'Country Code': 'SRB',
#   'Male Suicide Rate': 17.3,
#   'Female Suicide Rate': 5.2,
#   'Combined Suicide Rate': 10.9},
#  {'Country Code': 'CAF',
#   'Male Suicide Rate': 18.0,
#   'Female Suicide Rate': 6.0,
#   'Combined Suicide Rate': 11.6},
#  {'Country Code': 'SYR',
#   'Male Suicide Rate': 3.8,
#   'Female Suicide Rate': 1.1,
#   'Combined Suicide Rate': 2.4},
#  {'Country Code': 'FSM',
#   'Male Suicide Rate': 16.2,
#   'Female Suicide Rate': 6.2,
#   'Combined Suicide Rate': 11.3},
#  {'Country Code': 'IND',
#   'Male Suicide Rate': 18.5,
#   'Female Suicide Rate': 14.5,
#   'Combined Suicide Rate': 16.5},
#  {'Country Code': 'NLD',
#   'Male Suicide Rate': 12.9,
#   'Female Suicide Rate': 6.4,
#   'Combined Suicide Rate': 9.6},
#  {'Country Code': 'TLS',
#   'Male Suicide Rate': 9.0,
#   'Female Suicide Rate': 3.7,
#   'Combined Suicide Rate': 6.4},
#  {'Country Code': 'BHR',
#   'Male Suicide Rate': 7.9,
#   'Female Suicide Rate': 2.1,
#   'Combined Suicide Rate': 5.7},
#  {'Country Code': 'EGY',
#   'Male Suicide Rate': 7.2,
#   'Female Suicide Rate': 1.7,
#   'Combined Suicide Rate': 4.4},
#  {'Country Code': 'WSM',
#   'Male Suicide Rate': 8.7,
#   'Female Suicide Rate': 2.2,
#   'Combined Suicide Rate': 5.4},
#  {'Country Code': 'HUN',
#   'Male Suicide Rate': 22.2,
#   'Female Suicide Rate': 6.2,
#   'Combined Suicide Rate': 13.6},
#  {'Country Code': 'LTU',
#   'Male Suicide Rate': 47.5,
#   'Female Suicide Rate': 6.7,
#   'Combined Suicide Rate': 25.7},
#  {'Country Code': 'SWZ',
#   'Male Suicide Rate': 25.4,
#   'Female Suicide Rate': 9.6,
#   'Combined Suicide Rate': 16.7},
#  {'Country Code': 'IDN',
#   'Male Suicide Rate': 5.2,
#   'Female Suicide Rate': 2.2,
#   'Combined Suicide Rate': 3.7},
#  {'Country Code': 'TUN',
#   'Male Suicide Rate': 4.4,
#   'Female Suicide Rate': 2.2,
#   'Combined Suicide Rate': 3.2},
#  {'Country Code': 'MLT',
#   'Male Suicide Rate': 10.3,
#   'Female Suicide Rate': 2.8,
#   'Combined Suicide Rate': 6.5},
#  {'Country Code': 'BLZ',
#   'Male Suicide Rate': 9.9,
#   'Female Suicide Rate': 2.0,
#   'Combined Suicide Rate': 5.9},
#  {'Country Code': 'LBY',
#   'Male Suicide Rate': 8.7,
#   'Female Suicide Rate': 2.3,
#   'Combined Suicide Rate': 5.5},
#  {'Country Code': 'UGA',
#   'Male Suicide Rate': 21.2,
#   'Female Suicide Rate': 18.7,
#   'Combined Suicide Rate': 20.0},
#  {'Country Code': 'LVA',
#   'Male Suicide Rate': 31.0,
#   'Female Suicide Rate': 5.1,
#   'Combined Suicide Rate': 17.2},
#  {'Country Code': 'TON',
#   'Male Suicide Rate': 5.2,
#   'Female Suicide Rate': 2.9,
#   'Combined Suicide Rate': 4.0},
#  {'Country Code': 'DEU',
#   'Male Suicide Rate': 13.6,
#   'Female Suicide Rate': 4.8,
#   'Combined Suicide Rate': 9.1},
#  {'Country Code': 'KEN',
#   'Male Suicide Rate': 9.7,
#   'Female Suicide Rate': 2.1,
#   'Combined Suicide Rate': 5.6},
#  {'Country Code': 'DNK',
#   'Male Suicide Rate': 13.2,
#   'Female Suicide Rate': 5.2,
#   'Combined Suicide Rate': 9.2},
#  {'Country Code': 'MNE',
#   'Male Suicide Rate': 12.6,
#   'Female Suicide Rate': 3.6,
#   'Combined Suicide Rate': 7.9},
#  {'Country Code': 'BLR',
#   'Male Suicide Rate': 39.3,
#   'Female Suicide Rate': 6.2,
#   'Combined Suicide Rate': 21.4},
#  {'Country Code': 'KAZ',
#   'Male Suicide Rate': 40.1,
#   'Female Suicide Rate': 7.7,
#   'Combined Suicide Rate': 22.8},
#  {'Country Code': 'MDV',
#   'Male Suicide Rate': 3.6,
#   'Female Suicide Rate': 1.6,
#   'Combined Suicide Rate': 2.7},
#  {'Country Code': 'VCT',
#   'Male Suicide Rate': 3.9,
#   'Female Suicide Rate': 0.9,
#   'Combined Suicide Rate': 2.4},
#  {'Country Code': 'KGZ',
#   'Male Suicide Rate': 14.8,
#   'Female Suicide Rate': 3.7,
#   'Combined Suicide Rate': 9.1},
#  {'Country Code': 'LSO',
#   'Male Suicide Rate': 22.7,
#   'Female Suicide Rate': 32.6,
#   'Combined Suicide Rate': 28.9},
#  {'Country Code': 'LBN',
#   'Male Suicide Rate': 4.2,
#   'Female Suicide Rate': 2.2,
#   'Combined Suicide Rate': 3.2},
#  {'Country Code': 'CZE',
#   'Male Suicide Rate': 17.2,
#   'Female Suicide Rate': 4.2,
#   'Combined Suicide Rate': 10.5},
#  {'Country Code': 'GBR',
#   'Male Suicide Rate': 11.9,
#   'Female Suicide Rate': 3.5,
#   'Combined Suicide Rate': 7.6},
#  {'Country Code': 'MKD',
#   'Male Suicide Rate': 9.7,
#   'Female Suicide Rate': 3.0,
#   'Combined Suicide Rate': 6.2},
#  {'Country Code': 'SLE',
#   'Male Suicide Rate': 18.2,
#   'Female Suicide Rate': 14.2,
#   'Combined Suicide Rate': 16.1},
#  {'Country Code': 'ESP',
#   'Male Suicide Rate': 9.3,
#   'Female Suicide Rate': 3.1,
#   'Combined Suicide Rate': 6.1},
#  {'Country Code': 'SDN',
#   'Male Suicide Rate': 14.5,
#   'Female Suicide Rate': 4.6,
#   'Combined Suicide Rate': 9.5},
#  {'Country Code': 'OMN',
#   'Male Suicide Rate': 4.8,
#   'Female Suicide Rate': 0.9,
#   'Combined Suicide Rate': 3.5},
#  {'Country Code': 'MYS',
#   'Male Suicide Rate': 8.7,
#   'Female Suicide Rate': 3.6,
#   'Combined Suicide Rate': 6.2},
#  {'Country Code': 'SSD',
#   'Male Suicide Rate': 8.3,
#   'Female Suicide Rate': 4.1,
#   'Combined Suicide Rate': 6.1},
#  {'Country Code': 'NER',
#   'Male Suicide Rate': 11.5,
#   'Female Suicide Rate': 6.7,
#   'Combined Suicide Rate': 9.0},
#  {'Country Code': 'MOZ',
#   'Male Suicide Rate': 14.0,
#   'Female Suicide Rate': 4.1,
#   'Combined Suicide Rate': 8.4},
#  {'Country Code': 'LKA',
#   'Male Suicide Rate': 23.3,
#   'Female Suicide Rate': 6.2,
#   'Combined Suicide Rate': 14.2},
#  {'Country Code': 'BRA',
#   'Male Suicide Rate': 9.7,
#   'Female Suicide Rate': 2.8,
#   'Combined Suicide Rate': 6.1},
#  {'Country Code': 'CHE',
#   'Male Suicide Rate': 15.8,
#   'Female Suicide Rate': 6.9,
#   'Combined Suicide Rate': 11.3},
#  {'Country Code': 'GAB',
#   'Male Suicide Rate': 15.0,
#   'Female Suicide Rate': 4.3,
#   'Combined Suicide Rate': 9.6},
#  {'Country Code': 'CRI',
#   'Male Suicide Rate': 12.8,
#   'Female Suicide Rate': 2.3,
#   'Combined Suicide Rate': 7.5},
#  {'Country Code': 'RUS',
#   'Male Suicide Rate': 48.3,
#   'Female Suicide Rate': 7.5,
#   'Combined Suicide Rate': 26.5},
#  {'Country Code': 'JPN',
#   'Male Suicide Rate': 20.5,
#   'Female Suicide Rate': 8.1,
#   'Combined Suicide Rate': 14.3},
#  {'Country Code': 'KWT',
#   'Male Suicide Rate': 2.5,
#   'Female Suicide Rate': 1.7,
#   'Combined Suicide Rate': 2.2},
#  {'Country Code': 'SOM',
#   'Male Suicide Rate': 11.5,
#   'Female Suicide Rate': 5.4,
#   'Combined Suicide Rate': 8.3},
#  {'Country Code': 'TJK',
#   'Male Suicide Rate': 5.0,
#   'Female Suicide Rate': 1.7,
#   'Combined Suicide Rate': 3.3},
#  {'Country Code': 'FIN',
#   'Male Suicide Rate': 20.8,
#   'Female Suicide Rate': 6.8,
#   'Combined Suicide Rate': 13.8},
#  {'Country Code': 'ITA',
#   'Male Suicide Rate': 8.4,
#   'Female Suicide Rate': 2.6,
#   'Combined Suicide Rate': 5.5},
#  {'Country Code': 'TGO',
#   'Male Suicide Rate': 22.7,
#   'Female Suicide Rate': 10.9,
#   'Combined Suicide Rate': 16.6},
#  {'Country Code': 'LCA',
#   'Male Suicide Rate': 12.7,
#   'Female Suicide Rate': 2.1,
#   'Combined Suicide Rate': 7.3},
#  {'Country Code': 'SLV',
#   'Male Suicide Rate': 24.8,
#   'Female Suicide Rate': 4.3,
#   'Combined Suicide Rate': 13.5},
#  {'Country Code': 'KHM',
#   'Male Suicide Rate': 9.0,
#   'Female Suicide Rate': 3.2,
#   'Combined Suicide Rate': 5.9},
#  {'Country Code': 'LAO',
#   'Male Suicide Rate': 12.9,
#   'Female Suicide Rate': 6.1,
#   'Combined Suicide Rate': 9.3},
#  {'Country Code': 'VEN',
#   'Male Suicide Rate': 6.6,
#   'Female Suicide Rate': 1.2,
#   'Combined Suicide Rate': 3.8},
#  {'Country Code': 'NIC',
#   'Male Suicide Rate': 19.2,
#   'Female Suicide Rate': 5.0,
#   'Combined Suicide Rate': 11.9},
#  {'Country Code': 'GHA',
#   'Male Suicide Rate': 15.8,
#   'Female Suicide Rate': 2.9,
#   'Combined Suicide Rate': 8.7},
#  {'Country Code': 'PRK',
#   'Male Suicide Rate': 14.8,
#   'Female Suicide Rate': 8.0,
#   'Combined Suicide Rate': 10.6},
#  {'Country Code': 'ISL',
#   'Male Suicide Rate': 21.7,
#   'Female Suicide Rate': 4.7,
#   'Combined Suicide Rate': 13.3},
#  {'Country Code': 'CHN',
#   'Male Suicide Rate': 7.9,
#   'Female Suicide Rate': 8.3,
#   'Combined Suicide Rate': 8.0},
#  {'Country Code': 'SAU',
#   'Male Suicide Rate': 4.6,
#   'Female Suicide Rate': 1.7,
#   'Combined Suicide Rate': 3.4},
#  {'Country Code': 'ZAF',
#   'Male Suicide Rate': 21.7,
#   'Female Suicide Rate': 5.1,
#   'Combined Suicide Rate': 12.8},
#  {'Country Code': 'JOR',
#   'Male Suicide Rate': 4.7,
#   'Female Suicide Rate': 2.7,
#   'Combined Suicide Rate': 3.7},
#  {'Country Code': 'BOL',
#   'Male Suicide Rate': 16.9,
#   'Female Suicide Rate': 8.9,
#   'Combined Suicide Rate': 12.9},
#  {'Country Code': 'EST',
#   'Male Suicide Rate': 25.6,
#   'Female Suicide Rate': 4.4,
#   'Combined Suicide Rate': 14.4},
#  {'Country Code': 'KOR',
#   'Male Suicide Rate': 29.6,
#   'Female Suicide Rate': 11.6,
#   'Combined Suicide Rate': 20.2},
#  {'Country Code': 'GTM',
#   'Male Suicide Rate': 4.4,
#   'Female Suicide Rate': 1.7,
#   'Combined Suicide Rate': 2.9},
#  {'Country Code': 'CYP',
#   'Male Suicide Rate': 7.2,
#   'Female Suicide Rate': 1.9,
#   'Combined Suicide Rate': 4.5},
#  {'Country Code': 'UKR',
#   'Male Suicide Rate': 34.5,
#   'Female Suicide Rate': 4.7,
#   'Combined Suicide Rate': 18.5},
#  {'Country Code': 'MRT',
#   'Male Suicide Rate': 12.1,
#   'Female Suicide Rate': 3.6,
#   'Combined Suicide Rate': 7.5},
#  {'Country Code': 'MUS',
#   'Male Suicide Rate': 12.5,
#   'Female Suicide Rate': 2.2,
#   'Combined Suicide Rate': 7.3},
#  {'Country Code': 'SEN',
#   'Male Suicide Rate': 20.3,
#   'Female Suicide Rate': 5.2,
#   'Combined Suicide Rate': 11.8},
#  {'Country Code': 'ISR',
#   'Male Suicide Rate': 8.2,
#   'Female Suicide Rate': 2.4,
#   'Combined Suicide Rate': 5.2},
#  {'Country Code': 'BEL',
#   'Male Suicide Rate': 22.2,
#   'Female Suicide Rate': 9.4,
#   'Combined Suicide Rate': 15.7},
#  {'Country Code': 'PRT',
#   'Male Suicide Rate': 14.3,
#   'Female Suicide Rate': 3.8,
#   'Combined Suicide Rate': 8.6},
#  {'Country Code': 'AZE',
#   'Male Suicide Rate': 4.3,
#   'Female Suicide Rate': 1.0,
#   'Combined Suicide Rate': 2.6},
#  {'Country Code': 'ZMB',
#   'Male Suicide Rate': 17.5,
#   'Female Suicide Rate': 6.2,
#   'Combined Suicide Rate': 11.3},
#  {'Country Code': 'ETH',
#   'Male Suicide Rate': 18.7,
#   'Female Suicide Rate': 4.7,
#   'Combined Suicide Rate': 11.4},
#  {'Country Code': 'ATG',
#   'Male Suicide Rate': 0.0,
#   'Female Suicide Rate': 0.9,
#   'Combined Suicide Rate': 4.30386},
#  {'Country Code': 'CMR',
#   'Male Suicide Rate': 26.9,
#   'Female Suicide Rate': 12.5,
#   'Combined Suicide Rate': 19.5},
#  {'Country Code': 'NPL',
#   'Male Suicide Rate': 11.4,
#   'Female Suicide Rate': 8.0,
#   'Combined Suicide Rate': 9.6},
#  {'Country Code': 'LUX',
#   'Male Suicide Rate': 15.0,
#   'Female Suicide Rate': 5.8,
#   'Combined Suicide Rate': 10.4},
#  {'Country Code': 'GMB',
#   'Male Suicide Rate': 12.8,
#   'Female Suicide Rate': 7.3,
#   'Combined Suicide Rate': 10.0},
#  {'Country Code': 'TKM',
#   'Male Suicide Rate': 11.0,
#   'Female Suicide Rate': 3.7,
#   'Combined Suicide Rate': 7.2},
#  {'Country Code': 'CIV',
#   'Male Suicide Rate': 32.0,
#   'Female Suicide Rate': 13.0,
#   'Combined Suicide Rate': 23.0},
#  {'Country Code': 'TZA',
#   'Male Suicide Rate': 14.3,
#   'Female Suicide Rate': 5.4,
#   'Combined Suicide Rate': 9.6},
#  {'Country Code': 'TUR',
#   'Male Suicide Rate': 11.3,
#   'Female Suicide Rate': 3.2,
#   'Combined Suicide Rate': 7.2},
#  {'Country Code': 'GIN',
#   'Male Suicide Rate': 12.7,
#   'Female Suicide Rate': 8.4,
#   'Combined Suicide Rate': 10.5},
#  {'Country Code': 'NOR',
#   'Male Suicide Rate': 13.6,
#   'Female Suicide Rate': 6.5,
#   'Combined Suicide Rate': 10.1},
#  {'Country Code': 'URY',
#   'Male Suicide Rate': 26.8,
#   'Female Suicide Rate': 7.1,
#   'Combined Suicide Rate': 16.5},
#  {'Country Code': 'BWA',
#   'Male Suicide Rate': 18.3,
#   'Female Suicide Rate': 5.7,
#   'Combined Suicide Rate': 11.5},
#  {'Country Code': 'BIH',
#   'Male Suicide Rate': 10.6,
#   'Female Suicide Rate': 2.5,
#   'Combined Suicide Rate': 6.4},
#  {'Country Code': 'SVN',
#   'Male Suicide Rate': 22.4,
#   'Female Suicide Rate': 4.5,
#   'Combined Suicide Rate': 13.3},
#  {'Country Code': 'CAN',
#   'Male Suicide Rate': 15.1,
#   'Female Suicide Rate': 5.8,
#   'Combined Suicide Rate': 10.4},
#  {'Country Code': 'IRQ',
#   'Male Suicide Rate': 4.7,
#   'Female Suicide Rate': 3.4,
#   'Combined Suicide Rate': 4.1},
#  {'Country Code': 'KIR',
#   'Male Suicide Rate': 25.9,
#   'Female Suicide Rate': 5.4,
#   'Combined Suicide Rate': 15.2},
#  {'Country Code': 'LBR',
#   'Male Suicide Rate': 13.8,
#   'Female Suicide Rate': 13.0,
#   'Combined Suicide Rate': 13.4},
#  {'Country Code': 'QAT',
#   'Male Suicide Rate': 7.3,
#   'Female Suicide Rate': 1.1,
#   'Combined Suicide Rate': 5.8},
#  {'Country Code': 'AGO',
#   'Male Suicide Rate': 14.0,
#   'Female Suicide Rate': 4.6,
#   'Combined Suicide Rate': 8.9},
#  {'Country Code': 'PRY',
#   'Male Suicide Rate': 12.3,
#   'Female Suicide Rate': 6.2,
#   'Combined Suicide Rate': 9.3},
#  {'Country Code': 'AUS',
#   'Male Suicide Rate': 17.4,
#   'Female Suicide Rate': 6.0,
#   'Combined Suicide Rate': 11.7},
#  {'Country Code': 'NZL',
#   'Male Suicide Rate': 17.3,
#   'Female Suicide Rate': 6.2,
#   'Combined Suicide Rate': 11.6},
#  {'Country Code': 'BRB',
#   'Male Suicide Rate': 0.8,
#   'Female Suicide Rate': 0.3,
#   'Combined Suicide Rate': 0.4},
#  {'Country Code': 'THA',
#   'Male Suicide Rate': 21.4,
#   'Female Suicide Rate': 4.8,
#   'Combined Suicide Rate': 12.9},
#  {'Country Code': 'COG',
#   'Male Suicide Rate': 13.9,
#   'Female Suicide Rate': 5.0,
#   'Combined Suicide Rate': 9.3},
#  {'Country Code': 'BFA',
#   'Male Suicide Rate': 22.4,
#   'Female Suicide Rate': 9.1,
#   'Combined Suicide Rate': 14.8},
#  {'Country Code': 'PHL',
#   'Male Suicide Rate': 5.2,
#   'Female Suicide Rate': 2.3,
#   'Combined Suicide Rate': 3.7},
#  {'Country Code': 'PAK',
#   'Male Suicide Rate': 3.0,
#   'Female Suicide Rate': 3.1,
#   'Combined Suicide Rate': 3.1},
#  {'Country Code': 'VUT',
#   'Male Suicide Rate': 8.1,
#   'Female Suicide Rate': 2.7,
#   'Combined Suicide Rate': 5.4}]

# %%
suicide_rates = pd.DataFrame.from_dict(data_dictionary,)

# %%
suicide_rates.set_index(['Country Code'], inplace=True)

# %%
suicide_rates.sort_index(inplace=True)

# %%
suicide_rates
# Out:
#               Combined Suicide Rate  Female Suicide Rate  Male Suicide Rate
# Country Code
# AFG                         6.40000                  2.1               10.6
# AGO                         8.90000                  4.6               14.0
# ALB                         5.60000                  4.3                7.0
# ARE                         2.70000                  0.8                3.5
# ARG                         9.10000                  3.5               15.0
# ARM                         5.70000                  2.0               10.1
# ATG                         4.30386                  0.9                0.0
# AUS                        11.70000                  6.0               17.4
# AUT                        11.40000                  5.7               17.5
# AZE                         2.60000                  1.0                4.3
# BDI                        15.00000                  7.7               23.1
# BEL                        15.70000                  9.4               22.2
# BEN                        15.70000                  9.6               22.6
# BFA                        14.80000                  9.1               22.4
# BGD                         6.10000                  6.7                5.5
# BGR                         7.90000                  3.2               13.1
# BHR                         5.70000                  2.1                7.9
# BHS                         1.60000                  0.5                2.8
# BIH                         6.40000                  2.5               10.6
# BLR                        21.40000                  6.2               39.3
# BLZ                         5.90000                  2.0                9.9
# BOL                        12.90000                  8.9               16.9
# BRA                         6.10000                  2.8                9.7
# BRB                         0.40000                  0.3                0.8
# BRN                         4.50000                  2.8                6.2
# BTN                        11.60000                  8.9               13.8
# BWA                        11.50000                  5.7               18.3
# CAF                        11.60000                  6.0               18.0
# CAN                        10.40000                  5.8               15.1
# CHE                        11.30000                  6.9               15.8
# ...                             ...                  ...                ...
# SVN                        13.30000                  4.5               22.4
# SWE                        11.70000                  7.4               15.8
# SWZ                        16.70000                  9.6               25.4
# SYC                         8.30000                  2.1               15.0
# SYR                         2.40000                  1.1                3.8
# TCD                        15.50000                 13.8               17.1
# TGO                        16.60000                 10.9               22.7
# THA                        12.90000                  4.8               21.4
# TJK                         3.30000                  1.7                5.0
# TKM                         7.20000                  3.7               11.0
# TLS                         6.40000                  3.7                9.0
# TON                         4.00000                  2.9                5.2
# TTO                        12.90000                  4.3               21.9
# TUN                         3.20000                  2.2                4.4
# TUR                         7.20000                  3.2               11.3
# TZA                         9.60000                  5.4               14.3
# UGA                        20.00000                 18.7               21.2
# UKR                        18.50000                  4.7               34.5
# URY                        16.50000                  7.1               26.8
# USA                        13.70000                  6.4               21.1
# UZB                         7.40000                  4.6               10.3
# VCT                         2.40000                  0.9                3.9
# VEN                         3.80000                  1.2                6.6
# VNM                         7.00000                  3.4               10.8
# VUT                         5.40000                  2.7                8.1
# WSM                         5.40000                  2.2                8.7
# YEM                         9.25494                  6.2               13.4
# ZAF                        12.80000                  5.1               21.7
# ZMB                        11.30000                  6.2               17.5
# ZWE                        19.10000                 11.1               29.1
#
# [183 rows x 3 columns]

# %%
data['dimension'][4]['code'][0]
# Out:
# {'label': 'AFG',
#  'display': 'Afghanistan',
#  'display_sequence': 10,
#  'url': '',
#  'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#    'value': '2017'},
#   {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#   {'category': 'WHO_REGION', 'value': 'Eastern Mediterranean'},
#   {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Low income'},
#   {'category': 'WHO_REGION_CODE', 'value': 'EMR'},
#   {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LI'},
#   {'category': 'DS', 'value': 'AFG'},
#   {'category': 'FIPS', 'value': 'AF'},
#   {'category': 'IOC', 'value': 'AFG'},
#   {'category': 'ISO2', 'value': 'AF'},
#   {'category': 'ISO', 'value': 'AFG'},
#   {'category': 'ITU', 'value': 'AFG'},
#   {'category': 'MARC', 'value': 'af'},
#   {'category': 'WHO', 'value': 'AFG'},
#   {'category': 'WMO', 'value': 'AF'},
#   {'category': 'GEOMETRY', 'value': 'AFG'},
#   {'category': 'MORT', 'value': '3010'},
#   {'category': 'LAND_AREA_KMSQ_2012', 'value': '652,230'},
#   {'category': 'LANGUAGES_EN_2012',
#    'value': 'Dari, Pashto, Turkic languages, 30 minor languages'},
#   {'category': 'SHORTNAMEES', 'value': 'Afganistan'},
#   {'category': 'SHORTNAMEFR', 'value': 'Afghanistan'},
#   {'category': 'WHOLEGALSTATUS', 'value': 'M'}]}

# %%
country_names = []
for country in data['dimension'][4]['code']:
    country_names.append({'Country Code': country['label'], 'Country Name': country['display']})

# %%
country_names_df = pd.DataFrame.from_dict(country_names)

# %%
country_names_df.set_index(['Country Code'], inplace=True)

# %%
suicide_rates = suicide_rates.join(country_names_df, on=['Country Code'], how='inner')

# %%
suicide_rates = suicide_rates[['Country Name', 'Combined Suicide Rate', 'Male Suicide Rate', 'Female Suicide Rate']]

# %%
suicide_rates
# Out:
#                                     Country Name  Combined Suicide Rate  \
# Country Code
# AFG                                  Afghanistan                6.40000
# AGO                                       Angola                8.90000
# ALB                                      Albania                5.60000
# ARE                         United Arab Emirates                2.70000
# ARG                                    Argentina                9.10000
# ARM                                      Armenia                5.70000
# ATG                          Antigua and Barbuda                4.30386
# AUS                                    Australia               11.70000
# AUT                                      Austria               11.40000
# AZE                                   Azerbaijan                2.60000
# BDI                                      Burundi               15.00000
# BEL                                      Belgium               15.70000
# BEN                                        Benin               15.70000
# BFA                                 Burkina Faso               14.80000
# BGD                                   Bangladesh                6.10000
# BGR                                     Bulgaria                7.90000
# BHR                                      Bahrain                5.70000
# BHS                                      Bahamas                1.60000
# BIH                       Bosnia and Herzegovina                6.40000
# BLR                                      Belarus               21.40000
# BLZ                                       Belize                5.90000
# BOL             Bolivia (Plurinational State of)               12.90000
# BRA                                       Brazil                6.10000
# BRB                                     Barbados                0.40000
# BRN                            Brunei Darussalam                4.50000
# BTN                                       Bhutan               11.60000
# BWA                                     Botswana               11.50000
# CAF                     Central African Republic               11.60000
# CAN                                       Canada               10.40000
# CHE                                  Switzerland               11.30000
# ...                                          ...                    ...
# SVN                                     Slovenia               13.30000
# SWE                                       Sweden               11.70000
# SWZ                                     Eswatini               16.70000
# SYC                                   Seychelles                8.30000
# SYR                         Syrian Arab Republic                2.40000
# TCD                                         Chad               15.50000
# TGO                                         Togo               16.60000
# THA                                     Thailand               12.90000
# TJK                                   Tajikistan                3.30000
# TKM                                 Turkmenistan                7.20000
# TLS                                  Timor-Leste                6.40000
# TON                                        Tonga                4.00000
# TTO                          Trinidad and Tobago               12.90000
# TUN                                      Tunisia                3.20000
# TUR                                       Turkey                7.20000
# TZA                  United Republic of Tanzania                9.60000
# UGA                                       Uganda               20.00000
# UKR                                      Ukraine               18.50000
# URY                                      Uruguay               16.50000
# USA                     United States of America               13.70000
# UZB                                   Uzbekistan                7.40000
# VCT             Saint Vincent and the Grenadines                2.40000
# VEN           Venezuela (Bolivarian Republic of)                3.80000
# VNM                                     Viet Nam                7.00000
# VUT                                      Vanuatu                5.40000
# WSM                                        Samoa                5.40000
# YEM                                        Yemen                9.25494
# ZAF                                 South Africa               12.80000
# ZMB                                       Zambia               11.30000
# ZWE                                     Zimbabwe               19.10000
#
#               Male Suicide Rate  Female Suicide Rate
# Country Code
# AFG                        10.6                  2.1
# AGO                        14.0                  4.6
# ALB                         7.0                  4.3
# ARE                         3.5                  0.8
# ARG                        15.0                  3.5
# ARM                        10.1                  2.0
# ATG                         0.0                  0.9
# AUS                        17.4                  6.0
# AUT                        17.5                  5.7
# AZE                         4.3                  1.0
# BDI                        23.1                  7.7
# BEL                        22.2                  9.4
# BEN                        22.6                  9.6
# BFA                        22.4                  9.1
# BGD                         5.5                  6.7
# BGR                        13.1                  3.2
# BHR                         7.9                  2.1
# BHS                         2.8                  0.5
# BIH                        10.6                  2.5
# BLR                        39.3                  6.2
# BLZ                         9.9                  2.0
# BOL                        16.9                  8.9
# BRA                         9.7                  2.8
# BRB                         0.8                  0.3
# BRN                         6.2                  2.8
# BTN                        13.8                  8.9
# BWA                        18.3                  5.7
# CAF                        18.0                  6.0
# CAN                        15.1                  5.8
# CHE                        15.8                  6.9
# ...                         ...                  ...
# SVN                        22.4                  4.5
# SWE                        15.8                  7.4
# SWZ                        25.4                  9.6
# SYC                        15.0                  2.1
# SYR                         3.8                  1.1
# TCD                        17.1                 13.8
# TGO                        22.7                 10.9
# THA                        21.4                  4.8
# TJK                         5.0                  1.7
# TKM                        11.0                  3.7
# TLS                         9.0                  3.7
# TON                         5.2                  2.9
# TTO                        21.9                  4.3
# TUN                         4.4                  2.2
# TUR                        11.3                  3.2
# TZA                        14.3                  5.4
# UGA                        21.2                 18.7
# UKR                        34.5                  4.7
# URY                        26.8                  7.1
# USA                        21.1                  6.4
# UZB                        10.3                  4.6
# VCT                         3.9                  0.9
# VEN                         6.6                  1.2
# VNM                        10.8                  3.4
# VUT                         8.1                  2.7
# WSM                         8.7                  2.2
# YEM                        13.4                  6.2
# ZAF                        21.7                  5.1
# ZMB                        17.5                  6.2
# ZWE                        29.1                 11.1
#
# [183 rows x 4 columns]
