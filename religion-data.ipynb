# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
r = requests.get('https://rationalwiki.org/wiki/Importance_of_religion_by_country')
c = r.content
soup = BeautifulSoup(c)
# Out:
# /Users/briansrebrenik/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/briansrebrenik/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
data = soup.findAll('table', {'class': 'wikitable'})

# %%
data = data[0].findAll('td')

# %%
countries_list = []
religion_list = []
for i in range(len(data)):
   if i % 2 == 0:
       country = abc[i].text
       countries_list.append(country)
   else:
       religions = abc[i].text.split()
       religion = religions[0]
       religion_list.append(religion)
religion_table = [dict(Country = item[0], Religion = item[1]) for item in list(zip(countries_list, religion_list))]
religion_table

religion_df = pd.DataFrame(religion_table)
religion_df.Religion.value_counts()
# Out:
# '78%\n'

# %%
data[7].text
# Out:
# '18%'

# %%
list(range(1, len(data), 3))
# Out:
# [1,
#  4,
#  7,
#  10,
#  13,
#  16,
#  19,
#  22,
#  25,
#  28,
#  31,
#  34,
#  37,
#  40,
#  43,
#  46,
#  49,
#  52,
#  55,
#  58,
#  61,
#  64,
#  67,
#  70,
#  73,
#  76,
#  79,
#  82,
#  85,
#  88,
#  91,
#  94,
#  97,
#  100,
#  103,
#  106,
#  109,
#  112,
#  115,
#  118,
#  121,
#  124,
#  127,
#  130,
#  133,
#  136,
#  139,
#  142,
#  145,
#  148,
#  151,
#  154,
#  157,
#  160,
#  163,
#  166,
#  169,
#  172,
#  175,
#  178,
#  181,
#  184,
#  187,
#  190,
#  193,
#  196,
#  199,
#  202,
#  205,
#  208,
#  211,
#  214,
#  217,
#  220,
#  223,
#  226,
#  229,
#  232,
#  235,
#  238,
#  241,
#  244,
#  247,
#  250,
#  253,
#  256,
#  259,
#  262,
#  265,
#  268,
#  271,
#  274,
#  277,
#  280,
#  283,
#  286,
#  289,
#  292,
#  295,
#  298,
#  301,
#  304,
#  307,
#  310,
#  313,
#  316,
#  319,
#  322,
#  325,
#  328,
#  331,
#  334,
#  337,
#  340,
#  343,
#  346,
#  349,
#  352,
#  355,
#  358,
#  361,
#  364,
#  367,
#  370,
#  373,
#  376,
#  379,
#  382,
#  385,
#  388,
#  391,
#  394,
#  397,
#  400,
#  403,
#  406,
#  409,
#  412,
#  415,
#  418,
#  421,
#  424,
#  427,
#  430,
#  433,
#  436]

# %%
religous_stats = []
for i in range(len(data)):
    if i == 0 or i % 3 == 0:
        country = data[i].text.strip()
    elif i in list(range(1, len(data), 3)):
        percentage_religious = float(data[i].text.replace("%", ""))
        religous_stats.append({'Country Name': country, "% Religious": percentage_religious})

# %%
religous_stats
# Out:
# [{'Country Name': 'Estonia', '% Religious': 16.0},
#  {'Country Name': 'Sweden', '% Religious': 16.5},
#  {'Country Name': 'Denmark', '% Religious': 18.0},
#  {'Country Name': 'Czech Republic', '% Religious': 20.5},
#  {'Country Name': 'Norway', '% Religious': 20.5},
#  {'Country Name': 'Hong Kong', '% Religious': 23.0},
#  {'Country Name': 'Japan', '% Religious': 23.5},
#  {'Country Name': 'United Kingdom', '% Religious': 26.5},
#  {'Country Name': 'Finland', '% Religious': 28.0},
#  {'Country Name': 'France', '% Religious': 29.5},
#  {'Country Name': 'Vietnam', '% Religious': 29.5},
#  {'Country Name': 'Australia', '% Religious': 32.0},
#  {'Country Name': 'The Netherlands', '% Religious': 33.0},
#  {'Country Name': 'New Zealand', '% Religious': 33.0},
#  {'Country Name': 'Belarus', '% Religious': 33.0},
#  {'Country Name': 'Cuba', '% Religious': 33.5},
#  {'Country Name': 'Russia', '% Religious': 33.0},
#  {'Country Name': 'Albania', '% Religious': 32.5},
#  {'Country Name': 'South Korea', '% Religious': 32.5},
#  {'Country Name': 'Bulgaria', '% Religious': 33.5},
#  {'Country Name': 'Latvia', '% Religious': 39.0},
#  {'Country Name': 'Belgium', '% Religious': 33.0},
#  {'Country Name': 'Hungary', '% Religious': 39.0},
#  {'Country Name': 'Slovenia', '% Religious': 47.0},
#  {'Country Name': 'Azerbaijan', '% Religious': 49.5},
#  {'Country Name': 'Spain', '% Religious': 49.5},
#  {'Country Name': 'Taiwan', '% Religious': 45.0},
#  {'Country Name': 'Germany', '% Religious': 40.5},
#  {'Country Name': 'Uruguay', '% Religious': 40.5},
#  {'Country Name': 'Switzerland', '% Religious': 41.5},
#  {'Country Name': 'Canada', '% Religious': 42.0},
#  {'Country Name': 'Ukraine', '% Religious': 45.5},
#  {'Country Name': 'Lithuania', '% Religious': 41.5},
#  {'Country Name': 'Slovakia', '% Religious': 46.5},
#  {'Country Name': 'Israel', '% Religious': 49.5},
#  {'Country Name': 'Singapore', '% Religious': 70.0},
#  {'Country Name': 'Montenegro', '% Religious': 45.5},
#  {'Country Name': 'Serbia', '% Religious': 50.5},
#  {'Country Name': 'Kazakhstan', '% Religious': 43.0},
#  {'Country Name': 'Austria', '% Religious': 55.0},
#  {'Country Name': 'Ireland', '% Religious': 53.5},
#  {'Country Name': 'Uzbekistan', '% Religious': 51.0},
#  {'Country Name': 'Argentina', '% Religious': 66.0},
#  {'Country Name': 'Chile', '% Religious': 69.5},
#  {'Country Name': 'Belize', '% Religious': 61.5},
#  {'Country Name': 'United States of America', '% Religious': 65.0},
#  {'Country Name': 'Kygyzstan', '% Religious': 72.5},
#  {'Country Name': 'Moldova', '% Religious': 71.5},
#  {'Country Name': 'Venezuela', '% Religious': 79.0},
#  {'Country Name': 'Croatia', '% Religious': 66.5},
#  {'Country Name': 'Greece', '% Religious': 71.5},
#  {'Country Name': 'Armenia', '% Religious': 72.5},
#  {'Country Name': 'Bosnia and Herzegovina', '% Religious': 66.0},
#  {'Country Name': 'Jamaica', '% Religious': 70.0},
#  {'Country Name': 'Mexico', '% Religious': 72.0},
#  {'Country Name': 'Portugal', '% Religious': 71.5},
#  {'Country Name': 'Italy', '% Religious': 71.5},
#  {'Country Name': 'Kosovo', '% Religious': 63.5},
#  {'Country Name': 'Cyprus', '% Religious': 75.0},
#  {'Country Name': 'Poland', '% Religious': 74.5},
#  {'Country Name': 'Botswana', '% Religious': 77.0},
#  {'Country Name': 'Georgia', '% Religious': 80.0},
#  {'Country Name': 'Haiti', '% Religious': 75.0},
#  {'Country Name': 'Tajikistan', '% Religious': 84.5},
#  {'Country Name': 'Macedonia', '% Religious': 78.5},
#  {'Country Name': 'Trinidad and Tobago', '% Religious': 92.0},
#  {'Country Name': 'Romania', '% Religious': 84.0},
#  {'Country Name': 'Zimbabwe', '% Religious': 87.5},
#  {'Country Name': 'Dominican Rebpublic', '% Religious': 86.0},
#  {'Country Name': 'Ecuador', '% Religious': 82.0},
#  {'Country Name': 'India', '% Religious': 79.0},
#  {'Country Name': 'Iraq', '% Religious': 86.0},
#  {'Country Name': 'Nicaragua', '% Religious': 84.0},
#  {'Country Name': 'Iran', '% Religious': 82.5},
#  {'Country Name': 'Costa Rica', '% Religious': 79.0},
#  {'Country Name': 'El Salvador', '% Religious': 83.0},
#  {'Country Name': 'Kuwait', '% Religious': 92.5},
#  {'Country Name': 'Malaysia', '% Religious': 95.5},
#  {'Country Name': 'Peru', '% Religious': 83.5},
#  {'Country Name': 'Lebanon', '% Religious': 89.5},
#  {'Country Name': 'Puerto Rico', '% Religious': 84.5},
#  {'Country Name': 'Bolivia', '% Religious': 88.5},
#  {'Country Name': 'Brazil', '% Religious': 86.5},
#  {'Country Name': 'Burkina Faso', '% Religious': 87.5},
#  {'Country Name': 'Colombia', '% Religious': 82.5},
#  {'Country Name': 'South Africa', '% Religious': 84.5},
#  {'Country Name': 'Algeria', '% Religious': 93.0},
#  {'Country Name': 'Cambodia', '% Religious': 96.0},
#  {'Country Name': 'Guatemala', '% Religious': 88.0},
#  {'Country Name': 'Honduras', '% Religious': 84.0},
#  {'Country Name': 'Panama', '% Religious': 88.0},
#  {'Country Name': 'Philippines', '% Religious': 95.5},
#  {'Country Name': 'Togo', '% Religious': 80.0},
#  {'Country Name': 'Ethiopia', '% Religious': 91.0},
#  {'Country Name': 'Rwanda', '% Religious': 95.0},
#  {'Country Name': 'Mozambique', '% Religious': 86.0},
#  {'Country Name': 'Palestinian Territories', '% Religious': 93.0},
#  {'Country Name': 'Paraguay', '% Religious': 91.5},
#  {'Country Name': 'Turkey', '% Religious': 89.5},
#  {'Country Name': 'Burundi', '% Religious': 97.5},
#  {'Country Name': 'Namibia', '% Religious': 91.5},
#  {'Country Name': 'Tunisia', '% Religious': 93.0},
#  {'Country Name': 'Uganda', '% Religious': 93.0},
#  {'Country Name': 'Angola', '% Religious': 88.0},
#  {'Country Name': 'Chad', '% Religious': 94.0},
#  {'Country Name': 'Ghana', '% Religious': 94.5},
#  {'Country Name': 'Madagascar', '% Religious': 93.0},
#  {'Country Name': 'Nepal', '% Religious': 93.0},
#  {'Country Name': 'Benin', '% Religious': 92.5},
#  {'Country Name': 'Cameroon', '% Religious': 95.5},
#  {'Country Name': 'Central African Republic', '% Religious': 94.0},
#  {'Country Name': 'Liberia', '% Religious': 94.0},
#  {'Country Name': 'Mali', '% Religious': 94.5},
#  {'Country Name': 'Mauritania', '% Religious': 98.0},
#  {'Country Name': 'Comoros', '% Religious': 96.0},
#  {'Country Name': 'Nigeria', '% Religious': 95.5},
#  {'Country Name': 'Jordan', '% Religious': 96.5},
#  {'Country Name': 'Kenya', '% Religious': 94.0},
#  {'Country Name': 'Sudan', '% Religious': 94.0},
#  {'Country Name': 'Thailand', '% Religious': 94.0},
#  {'Country Name': 'Yemen', '% Religious': 96.0},
#  {'Country Name': 'Afghanistan', '% Religious': 97.0},
#  {'Country Name': 'Guinea', '% Religious': 97.0},
#  {'Country Name': 'Laos', '% Religious': 96.5},
#  {'Country Name': 'Myanmar', '% Religious': 96.5},
#  {'Country Name': 'Niger', '% Religious': 100.0},
#  {'Country Name': 'Pakistan', '% Religious': 96.5},
#  {'Country Name': 'Saudi Arabia', '% Religious': 94.5},
#  {'Country Name': 'Zambia', '% Religious': 97.0},
#  {'Country Name': "Côte d'Ivoire", '% Religious': 88.0},
#  {'Country Name': 'Democratic Republic of the Congo', '% Religious': 98.5},
#  {'Country Name': 'Djibouti', '% Religious': 98.0},
#  {'Country Name': 'Malawi', '% Religious': 98.5},
#  {'Country Name': 'Morocco', '% Religious': 98.5},
#  {'Country Name': 'Senegal', '% Religious': 96.5},
#  {'Country Name': 'Sierra Leone', '% Religious': 98.0},
#  {'Country Name': 'Tanzania', '% Religious': 96.5},
#  {'Country Name': 'United Arab Emirates', '% Religious': 91.0},
#  {'Country Name': 'Qatar', '% Religious': 94.5},
#  {'Country Name': 'Bahrain', '% Religious': 95.5},
#  {'Country Name': 'Bangladesh', '% Religious': 100.0},
#  {'Country Name': 'Indonesia', '% Religious': 99.0},
#  {'Country Name': 'Sri Lanka', '% Religious': 98.5},
#  {'Country Name': 'Egypt', '% Religious': 98.0},
#  {'Country Name': 'Republic of the Congo', '% Religious': 94.5},
#  {'Country Name': 'Somalia', '% Religious': 98.5}]

# %%
religious_df = pd.DataFrame.from_dict(religous_stats)

# %%
religious_df.set_index(['Country Name'], inplace=True)

# %%
religious_df
# Out:
#                                   % Religious
# Country Name
# Estonia                                  16.0
# Sweden                                   16.5
# Denmark                                  18.0
# Czech Republic                           20.5
# Norway                                   20.5
# Hong Kong                                23.0
# Japan                                    23.5
# United Kingdom                           26.5
# Finland                                  28.0
# France                                   29.5
# Vietnam                                  29.5
# Australia                                32.0
# The Netherlands                          33.0
# New Zealand                              33.0
# Belarus                                  33.0
# Cuba                                     33.5
# Russia                                   33.0
# Albania                                  32.5
# South Korea                              32.5
# Bulgaria                                 33.5
# Latvia                                   39.0
# Belgium                                  33.0
# Hungary                                  39.0
# Slovenia                                 47.0
# Azerbaijan                               49.5
# Spain                                    49.5
# Taiwan                                   45.0
# Germany                                  40.5
# Uruguay                                  40.5
# Switzerland                              41.5
# ...                                       ...
# Jordan                                   96.5
# Kenya                                    94.0
# Sudan                                    94.0
# Thailand                                 94.0
# Yemen                                    96.0
# Afghanistan                              97.0
# Guinea                                   97.0
# Laos                                     96.5
# Myanmar                                  96.5
# Niger                                   100.0
# Pakistan                                 96.5
# Saudi Arabia                             94.5
# Zambia                                   97.0
# Côte d'Ivoire                            88.0
# Democratic Republic of the Congo         98.5
# Djibouti                                 98.0
# Malawi                                   98.5
# Morocco                                  98.5
# Senegal                                  96.5
# Sierra Leone                             98.0
# Tanzania                                 96.5
# United Arab Emirates                     91.0
# Qatar                                    94.5
# Bahrain                                  95.5
# Bangladesh                              100.0
# Indonesia                                99.0
# Sri Lanka                                98.5
# Egypt                                    98.0
# Republic of the Congo                    94.5
# Somalia                                  98.5
#
# [146 rows x 1 columns]
