# %%
import requests
import json

# %%
noaa_token = 'IKcIsYWSNDjAknPHhKjPeOlxothIJpBs'

# %%
headers = {'token': 'IKcIsYWSNDjAknPHhKjPeOlxothIJpBs'}

# %%
r = requests.get("https://www.ncdc.noaa.gov/cdo-web/api/v2/locations?locationcategoryid=CNTRY&begindate=2016-01-01&enddate=2016-12-31&limit=201", headers=headers)

# %%
data = r.json()

# %%
data
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 201, 'limit': 201}},
#  'results': [{'mindate': '2005-01-01',
#    'maxdate': '2018-12-01',
#    'name': 'Aruba',
#    'datacoverage': 0.99,
#    'id': 'FIPS:AA'},
#   {'mindate': '1949-01-01',
#    'maxdate': '1970-02-13',
#    'name': 'Antigua & Barbuda',
#    'datacoverage': 1,
#    'id': 'FIPS:AC'},
#   {'mindate': '1944-03-01',
#    'maxdate': '2018-11-30',
#    'name': 'United Arab Emirates',
#    'datacoverage': 1,
#    'id': 'FIPS:AE'},
#   {'mindate': '1898-09-01',
#    'maxdate': '2018-11-30',
#    'name': 'Afghanistan',
#    'datacoverage': 1,
#    'id': 'FIPS:AF'},
#   {'mindate': '1852-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Algeria',
#    'datacoverage': 1,
#    'id': 'FIPS:AG'},
#   {'mindate': '1881-07-01',
#    'maxdate': '2018-11-30',
#    'name': 'Azerbaijan',
#    'datacoverage': 1,
#    'id': 'FIPS:AJ'},
#   {'mindate': '1940-04-01',
#    'maxdate': '2018-11-30',
#    'name': 'Albania',
#    'datacoverage': 0.9925,
#    'id': 'FIPS:AL'},
#   {'mindate': '1885-06-01',
#    'maxdate': '2018-11-30',
#    'name': 'Armenia',
#    'datacoverage': 1,
#    'id': 'FIPS:AM'},
#   {'mindate': '1955-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Angola',
#    'datacoverage': 1,
#    'id': 'FIPS:AO'},
#   {'mindate': '1908-09-01',
#    'maxdate': '2018-11-30',
#    'name': 'Argentina',
#    'datacoverage': 1,
#    'id': 'FIPS:AR'},
#   {'mindate': '1832-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Australia',
#    'datacoverage': 1,
#    'id': 'FIPS:AS'},
#   {'mindate': '1855-02-01',
#    'maxdate': '2018-11-30',
#    'name': 'Austria',
#    'datacoverage': 1,
#    'id': 'FIPS:AU'},
#   {'mindate': '1956-09-01',
#    'maxdate': '2018-11-30',
#    'name': 'Antarctica',
#    'datacoverage': 1,
#    'id': 'FIPS:AY'},
#   {'mindate': '1944-03-01',
#    'maxdate': '2018-11-30',
#    'name': 'Bahrain',
#    'datacoverage': 0.9819,
#    'id': 'FIPS:BA'},
#   {'mindate': '1905-08-01',
#    'maxdate': '2018-11-30',
#    'name': 'Botswana',
#    'datacoverage': 1,
#    'id': 'FIPS:BC'},
#   {'mindate': '1941-12-01',
#    'maxdate': '2018-12-01',
#    'name': 'Bermuda',
#    'datacoverage': 1,
#    'id': 'FIPS:BD'},
#   {'mindate': '1833-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Belgium',
#    'datacoverage': 0.9993,
#    'id': 'FIPS:BE'},
#   {'mindate': '1951-01-01',
#    'maxdate': '2018-12-03',
#    'name': 'The Bahamas',
#    'datacoverage': 1,
#    'id': 'FIPS:BF'},
#   {'mindate': '1901-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Bangladesh',
#    'datacoverage': 1,
#    'id': 'FIPS:BG'},
#   {'mindate': '1960-11-01',
#    'maxdate': '2018-11-30',
#    'name': 'Belize',
#    'datacoverage': 0.7263,
#    'id': 'FIPS:BH'},
#   {'mindate': '1897-10-01',
#    'maxdate': '2018-11-30',
#    'name': 'Bosnia & Herzegovina',
#    'datacoverage': 1,
#    'id': 'FIPS:BK'},
#   {'mindate': '1942-06-01',
#    'maxdate': '2018-11-30',
#    'name': 'Bolivia',
#    'datacoverage': 1,
#    'id': 'FIPS:BL'},
#   {'mindate': '1944-07-13',
#    'maxdate': '2018-11-30',
#    'name': 'Myanmar',
#    'datacoverage': 1,
#    'id': 'FIPS:BM'},
#   {'mindate': '1941-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Benin',
#    'datacoverage': 1,
#    'id': 'FIPS:BN'},
#   {'mindate': '1875-07-01',
#    'maxdate': '2018-11-30',
#    'name': 'Belarus',
#    'datacoverage': 1,
#    'id': 'FIPS:BO'},
#   {'mindate': '1943-03-16',
#    'maxdate': '1949-10-31',
#    'name': 'Solomon Is.',
#    'datacoverage': 1,
#    'id': 'FIPS:BP'},
#   {'mindate': '1901-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Brazil',
#    'datacoverage': 1,
#    'id': 'FIPS:BR'},
#   {'mindate': '1901-01-01',
#    'maxdate': '1957-12-31',
#    'name': 'Bhutan',
#    'datacoverage': 0.9927,
#    'id': 'FIPS:BT'},
#   {'mindate': '1952-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Bulgaria',
#    'datacoverage': 0.9819,
#    'id': 'FIPS:BU'},
#   {'mindate': '1981-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Brunei',
#    'datacoverage': 1,
#    'id': 'FIPS:BX'},
#   {'mindate': '1950-01-01',
#    'maxdate': '1989-12-31',
#    'name': 'Burundi',
#    'datacoverage': 1,
#    'id': 'FIPS:BY'},
#   {'mindate': '1840-03-01',
#    'maxdate': '2018-12-03',
#    'name': 'Canada',
#    'datacoverage': 1,
#    'id': 'FIPS:CA'},
#   {'mindate': '1950-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Cambodia',
#    'datacoverage': 1,
#    'id': 'FIPS:CB'},
#   {'mindate': '1950-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Chad',
#    'datacoverage': 1,
#    'id': 'FIPS:CD'},
#   {'mindate': '1869-02-01',
#    'maxdate': '2018-11-30',
#    'name': 'Sri Lanka',
#    'datacoverage': 1,
#    'id': 'FIPS:CE'},
#   {'mindate': '1947-03-01',
#    'maxdate': '2018-11-30',
#    'name': 'Congo',
#    'datacoverage': 0.9819,
#    'id': 'FIPS:CF'},
#   {'mindate': '1973-02-01',
#    'maxdate': '2018-11-30',
#    'name': 'Congo, DRC',
#    'datacoverage': 1,
#    'id': 'FIPS:CG'},
#   {'mindate': '1881-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'China',
#    'datacoverage': 1,
#    'id': 'FIPS:CH'},
#   {'mindate': '1946-11-13',
#    'maxdate': '2018-11-30',
#    'name': 'Chile',
#    'datacoverage': 1,
#    'id': 'FIPS:CI'},
#   {'mindate': '1966-02-01',
#    'maxdate': '2018-12-01',
#    'name': 'Cayman Is.',
#    'datacoverage': 1,
#    'id': 'FIPS:CJ'},
#   {'mindate': '1948-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Cameroon',
#    'datacoverage': 1,
#    'id': 'FIPS:CM'},
#   {'mindate': '1941-03-02',
#    'maxdate': '2018-11-30',
#    'name': 'Colombia',
#    'datacoverage': 1,
#    'id': 'FIPS:CO'},
#   {'mindate': '1955-07-04',
#    'maxdate': '2018-11-30',
#    'name': 'Costa Rica',
#    'datacoverage': 1,
#    'id': 'FIPS:CS'},
#   {'mindate': '1950-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Central African Republic',
#    'datacoverage': 1,
#    'id': 'FIPS:CT'},
#   {'mindate': '1942-07-01',
#    'maxdate': '2018-12-03',
#    'name': 'Cuba',
#    'datacoverage': 1,
#    'id': 'FIPS:CU'},
#   {'mindate': '1973-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Cape Verde',
#    'datacoverage': 0.9819,
#    'id': 'FIPS:CV'},
#   {'mindate': '1973-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Cook Is.',
#    'datacoverage': 1,
#    'id': 'FIPS:CW'},
#   {'mindate': '1881-08-01',
#    'maxdate': '2018-11-30',
#    'name': 'Cyprus',
#    'datacoverage': 1,
#    'id': 'FIPS:CY'},
#   {'mindate': '1872-11-01',
#    'maxdate': '2018-11-30',
#    'name': 'Denmark',
#    'datacoverage': 1,
#    'id': 'FIPS:DA'},
#   {'mindate': '1971-07-01',
#    'maxdate': '2018-12-01',
#    'name': 'Dominica',
#    'datacoverage': 1,
#    'id': 'FIPS:DO'},
#   {'mindate': '2010-01-01',
#    'maxdate': '2010-12-31',
#    'name': 'Jarvis I.',
#    'datacoverage': 1,
#    'id': 'FIPS:DQ'},
#   {'mindate': '1965-05-01',
#    'maxdate': '2018-11-30',
#    'name': 'Dominican Republic',
#    'datacoverage': 1,
#    'id': 'FIPS:DR'},
#   {'mindate': '1945-04-01',
#    'maxdate': '2018-11-30',
#    'name': 'Ecuador',
#    'datacoverage': 1,
#    'id': 'FIPS:EC'},
#   {'mindate': '1884-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Egypt',
#    'datacoverage': 1,
#    'id': 'FIPS:EG'},
#   {'mindate': '1861-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Ireland',
#    'datacoverage': 1,
#    'id': 'FIPS:EI'},
#   {'mindate': '1996-05-01',
#    'maxdate': '2018-11-30',
#    'name': 'Equatorial Guinea',
#    'datacoverage': 1,
#    'id': 'FIPS:EK'},
#   {'mindate': '1865-12-01',
#    'maxdate': '2018-11-30',
#    'name': 'Estonia',
#    'datacoverage': 1,
#    'id': 'FIPS:EN'},
#   {'mindate': '1943-01-01',
#    'maxdate': '2014-05-15',
#    'name': 'Eritrea',
#    'datacoverage': 0.9963,
#    'id': 'FIPS:ER'},
#   {'mindate': '1956-01-03',
#    'maxdate': '2018-11-30',
#    'name': 'El Salvador',
#    'datacoverage': 1,
#    'id': 'FIPS:ES'},
#   {'mindate': '1951-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Ethiopia',
#    'datacoverage': 1,
#    'id': 'FIPS:ET'},
#   {'mindate': '1775-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Czech Republic',
#    'datacoverage': 1,
#    'id': 'FIPS:EZ'},
#   {'mindate': '1908-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Finland',
#    'datacoverage': 1,
#    'id': 'FIPS:FI'},
#   {'mindate': '1942-04-13',
#    'maxdate': '2018-11-30',
#    'name': 'Fiji',
#    'datacoverage': 0.9943,
#    'id': 'FIPS:FJ'},
#   {'mindate': '1985-07-09',
#    'maxdate': '2018-11-30',
#    'name': 'Falkland Is.',
#    'datacoverage': 0.998,
#    'id': 'FIPS:FK'},
#   {'mindate': '1946-01-01',
#    'maxdate': '2018-12-01',
#    'name': 'Micronesia',
#    'datacoverage': 1,
#    'id': 'FIPS:FM'},
#   {'mindate': '1973-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Faroe Is.',
#    'datacoverage': 1,
#    'id': 'FIPS:FO'},
#   {'mindate': '1877-01-01',
#    'maxdate': '2018-12-01',
#    'name': 'France',
#    'datacoverage': 1,
#    'id': 'FIPS:FR'},
#   {'mindate': '1973-01-16',
#    'maxdate': '2018-11-30',
#    'name': 'French Southern & Antarctic Lands',
#    'datacoverage': 0.9986,
#    'id': 'FIPS:FS'},
#   {'mindate': '1973-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'The Gambia',
#    'datacoverage': 1,
#    'id': 'FIPS:GA'},
#   {'mindate': '1950-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Gabon',
#    'datacoverage': 1,
#    'id': 'FIPS:GB'},
#   {'mindate': '1881-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Georgia',
#    'datacoverage': 1,
#    'id': 'FIPS:GG'},
#   {'mindate': '1942-09-07',
#    'maxdate': '2018-11-30',
#    'name': 'Ghana',
#    'datacoverage': 1,
#    'id': 'FIPS:GH'},
#   {'mindate': '1958-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Gibraltar',
#    'datacoverage': 0.9991,
#    'id': 'FIPS:GI'},
#   {'mindate': '1959-12-31',
#    'maxdate': '2016-12-31',
#    'name': 'Guernsey',
#    'datacoverage': 0.9985,
#    'id': 'FIPS:GK'},
#   {'mindate': '1873-06-01',
#    'maxdate': '2018-11-30',
#    'name': 'Greenland',
#    'datacoverage': 1,
#    'id': 'FIPS:GL'},
#   {'mindate': '1781-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Germany',
#    'datacoverage': 1,
#    'id': 'FIPS:GM'},
#   {'mindate': '1955-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Greece',
#    'datacoverage': 1,
#    'id': 'FIPS:GR'},
#   {'mindate': '1979-01-01',
#    'maxdate': '1993-09-30',
#    'name': 'Guatemala',
#    'datacoverage': 0.9888,
#    'id': 'FIPS:GT'},
#   {'mindate': '1940-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Guinea',
#    'datacoverage': 1,
#    'id': 'FIPS:GV'},
#   {'mindate': '1941-08-25',
#    'maxdate': '2018-11-30',
#    'name': 'Guyana',
#    'datacoverage': 1,
#    'id': 'FIPS:GY'},
#   {'mindate': '1908-11-01',
#    'maxdate': '1948-04-29',
#    'name': 'Gaza Strip',
#    'datacoverage': 1,
#    'id': 'FIPS:GZ'},
#   {'mindate': '1998-03-01',
#    'maxdate': '2012-12-19',
#    'name': 'Heard I. & McDonald Is.',
#    'datacoverage': 1,
#    'id': 'FIPS:HM'},
#   {'mindate': '1945-05-01',
#    'maxdate': '2018-11-30',
#    'name': 'Honduras',
#    'datacoverage': 1,
#    'id': 'FIPS:HO'},
#   {'mindate': '1857-12-01',
#    'maxdate': '2018-11-30',
#    'name': 'Croatia',
#    'datacoverage': 1,
#    'id': 'FIPS:HR'},
#   {'mindate': '1901-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Hungary',
#    'datacoverage': 1,
#    'id': 'FIPS:HU'},
#   {'mindate': '1941-09-01',
#    'maxdate': '2018-12-01',
#    'name': 'Iceland',
#    'datacoverage': 1,
#    'id': 'FIPS:IC'},
#   {'mindate': '1942-11-21',
#    'maxdate': '2018-11-30',
#    'name': 'Indonesia',
#    'datacoverage': 1,
#    'id': 'FIPS:ID'},
#   {'mindate': '1959-12-31',
#    'maxdate': '2016-12-31',
#    'name': 'Isle of Man',
#    'datacoverage': 1,
#    'id': 'FIPS:IM'},
#   {'mindate': '1901-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'India',
#    'datacoverage': 1,
#    'id': 'FIPS:IN'},
#   {'mindate': '1971-07-01',
#    'maxdate': '2018-12-01',
#    'name': 'British Indian Ocean Territory',
#    'datacoverage': 1,
#    'id': 'FIPS:IO'},
#   {'mindate': '1936-02-01',
#    'maxdate': '2018-11-30',
#    'name': 'Iran',
#    'datacoverage': 1,
#    'id': 'FIPS:IR'},
#   {'mindate': '1921-04-01',
#    'maxdate': '2018-11-30',
#    'name': 'Israel',
#    'datacoverage': 1,
#    'id': 'FIPS:IS'},
#   {'mindate': '1763-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Italy',
#    'datacoverage': 1,
#    'id': 'FIPS:IT'},
#   {'mindate': '1940-01-01',
#    'maxdate': '2018-11-30',
#    'name': "Cote d'Ivoire",
#    'datacoverage': 1,
#    'id': 'FIPS:IV'},
#   {'mindate': '1949-11-01',
#    'maxdate': '2018-11-30',
#    'name': 'Iraq',
#    'datacoverage': 1,
#    'id': 'FIPS:IZ'},
#   {'mindate': '1931-01-01',
#    'maxdate': '2018-12-03',
#    'name': 'Japan',
#    'datacoverage': 1,
#    'id': 'FIPS:JA'},
#   {'mindate': '1959-12-31',
#    'maxdate': '2016-12-31',
#    'name': 'Jersey',
#    'datacoverage': 1,
#    'id': 'FIPS:JE'},
#   {'mindate': '1941-12-22',
#    'maxdate': '2018-11-30',
#    'name': 'Jamaica',
#    'datacoverage': 1,
#    'id': 'FIPS:JM'},
#   {'mindate': '1953-12-01',
#    'maxdate': '2018-11-30',
#    'name': 'Jordan',
#    'datacoverage': 1,
#    'id': 'FIPS:JO'},
#   {'mindate': '1935-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Kenya',
#    'datacoverage': 1,
#    'id': 'FIPS:KE'},
#   {'mindate': '1881-09-01',
#    'maxdate': '2018-11-30',
#    'name': 'Kyrgyzstan',
#    'datacoverage': 1,
#    'id': 'FIPS:KG'},
#   {'mindate': '1950-10-24',
#    'maxdate': '2018-12-03',
#    'name': 'North Korea',
#    'datacoverage': 1,
#    'id': 'FIPS:KN'},
#   {'mindate': '1948-06-01',
#    'maxdate': '1979-06-30',
#    'name': 'Kiribati',
#    'datacoverage': 1,
#    'id': 'FIPS:KR'},
#   {'mindate': '1926-01-01',
#    'maxdate': '2018-12-03',
#    'name': 'South Korea',
#    'datacoverage': 1,
#    'id': 'FIPS:KS'},
#   {'mindate': '1972-09-01',
#    'maxdate': '2018-11-30',
#    'name': 'Christmas I.',
#    'datacoverage': 0.9819,
#    'id': 'FIPS:KT'},
#   {'mindate': '1955-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Kuwait',
#    'datacoverage': 1,
#    'id': 'FIPS:KU'},
#   {'mindate': '1881-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Kazakhstan',
#    'datacoverage': 1,
#    'id': 'FIPS:KZ'},
#   {'mindate': '1950-01-08',
#    'maxdate': '2018-11-30',
#    'name': 'Laos',
#    'datacoverage': 1,
#    'id': 'FIPS:LA'},
#   {'mindate': '1912-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Lebanon',
#    'datacoverage': 1,
#    'id': 'FIPS:LE'},
#   {'mindate': '1881-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Latvia',
#    'datacoverage': 1,
#    'id': 'FIPS:LG'},
#   {'mindate': '1881-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Lithuania',
#    'datacoverage': 1,
#    'id': 'FIPS:LH'},
#   {'mindate': '1942-07-06',
#    'maxdate': '2018-11-30',
#    'name': 'Liberia',
#    'datacoverage': 1,
#    'id': 'FIPS:LI'},
#   {'mindate': '1901-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Slovakia',
#    'datacoverage': 1,
#    'id': 'FIPS:LO'},
#   {'mindate': '1886-09-01',
#    'maxdate': '1993-12-31',
#    'name': 'Lesotho',
#    'datacoverage': 0.9015,
#    'id': 'FIPS:LT'},
#   {'mindate': '1947-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Luxembourg',
#    'datacoverage': 1,
#    'id': 'FIPS:LU'},
#   {'mindate': '1916-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Libya',
#    'datacoverage': 1,
#    'id': 'FIPS:LY'},
#   {'mindate': '1973-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Madagascar',
#    'datacoverage': 1,
#    'id': 'FIPS:MA'},
#   {'mindate': '1886-11-01',
#    'maxdate': '2018-11-30',
#    'name': 'Moldova',
#    'datacoverage': 1,
#    'id': 'FIPS:MD'},
#   {'mindate': '1956-08-01',
#    'maxdate': '2018-11-30',
#    'name': 'Mongolia',
#    'datacoverage': 1,
#    'id': 'FIPS:MG'},
#   {'mindate': '1898-10-01',
#    'maxdate': '2018-11-30',
#    'name': 'Malawi',
#    'datacoverage': 1,
#    'id': 'FIPS:MI'},
#   {'mindate': '1973-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Montenegro',
#    'datacoverage': 1,
#    'id': 'FIPS:MJ'},
#   {'mindate': '1948-12-01',
#    'maxdate': '2018-11-30',
#    'name': 'Macedonia',
#    'datacoverage': 1,
#    'id': 'FIPS:MK'},
#   {'mindate': '1957-07-01',
#    'maxdate': '2018-11-30',
#    'name': 'Mali',
#    'datacoverage': 1,
#    'id': 'FIPS:ML'},
#   {'mindate': '1910-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Morocco',
#    'datacoverage': 1,
#    'id': 'FIPS:MO'},
#   {'mindate': '1951-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Mauritius',
#    'datacoverage': 1,
#    'id': 'FIPS:MP'},
#   {'mindate': '1940-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Mauritania',
#    'datacoverage': 1,
#    'id': 'FIPS:MR'},
#   {'mindate': '1956-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Malta',
#    'datacoverage': 0.971,
#    'id': 'FIPS:MT'},
#   {'mindate': '1943-04-13',
#    'maxdate': '2018-11-30',
#    'name': 'Oman',
#    'datacoverage': 1,
#    'id': 'FIPS:MU'},
#   {'mindate': '1902-06-01',
#    'maxdate': '2018-12-03',
#    'name': 'Mexico',
#    'datacoverage': 1,
#    'id': 'FIPS:MX'},
#   {'mindate': '1949-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Malaysia',
#    'datacoverage': 1,
#    'id': 'FIPS:MY'},
#   {'mindate': '1925-02-01',
#    'maxdate': '2018-11-30',
#    'name': 'Mozambique',
#    'datacoverage': 1,
#    'id': 'FIPS:MZ'},
#   {'mindate': '2001-09-01',
#    'maxdate': '2018-04-20',
#    'name': 'Niue',
#    'datacoverage': 0.91,
#    'id': 'FIPS:NE'},
#   {'mindate': '1947-12-31',
#    'maxdate': '2018-11-30',
#    'name': 'Norfolk I.',
#    'datacoverage': 1,
#    'id': 'FIPS:NF'},
#   {'mindate': '1906-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Niger',
#    'datacoverage': 1,
#    'id': 'FIPS:NG'},
#   {'mindate': '1973-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Vanuatu',
#    'datacoverage': 1,
#    'id': 'FIPS:NH'},
#   {'mindate': '1943-05-01',
#    'maxdate': '2018-11-30',
#    'name': 'Nigeria',
#    'datacoverage': 0.9819,
#    'id': 'FIPS:NI'},
#   {'mindate': '1846-12-01',
#    'maxdate': '2018-12-01',
#    'name': 'Netherlands',
#    'datacoverage': 1,
#    'id': 'FIPS:NL'},
#   {'mindate': '1973-04-04',
#    'maxdate': '2018-12-01',
#    'name': 'Sint Maarten',
#    'datacoverage': 1,
#    'id': 'FIPS:NN'},
#   {'mindate': '1876-02-20',
#    'maxdate': '2018-11-30',
#    'name': 'Norway',
#    'datacoverage': 1,
#    'id': 'FIPS:NO'},
#   {'mindate': '1903-02-01',
#    'maxdate': '2018-11-30',
#    'name': 'Nepal',
#    'datacoverage': 1,
#    'id': 'FIPS:NP'},
#   {'mindate': '1942-09-01',
#    'maxdate': '2018-11-30',
#    'name': 'Suriname',
#    'datacoverage': 0.9819,
#    'id': 'FIPS:NS'},
#   {'mindate': '1942-10-01',
#    'maxdate': '2018-11-30',
#    'name': 'Nicaragua',
#    'datacoverage': 1,
#    'id': 'FIPS:NU'},
#   {'mindate': '1940-03-01',
#    'maxdate': '2018-12-01',
#    'name': 'New Zealand',
#    'datacoverage': 1,
#    'id': 'FIPS:NZ'},
#   {'mindate': '1957-07-01',
#    'maxdate': '2018-11-29',
#    'name': 'South Sudan',
#    'datacoverage': 0.9999,
#    'id': 'FIPS:OD'},
#   {'mindate': '1949-01-02',
#    'maxdate': '2018-11-30',
#    'name': 'Paraguay',
#    'datacoverage': 1,
#    'id': 'FIPS:PA'},
#   {'mindate': '1972-01-01',
#    'maxdate': '2004-10-31',
#    'name': 'Pitcairn Is.',
#    'datacoverage': 0.9619,
#    'id': 'FIPS:PC'},
#   {'mindate': '1942-11-01',
#    'maxdate': '2018-11-30',
#    'name': 'Peru',
#    'datacoverage': 1,
#    'id': 'FIPS:PE'},
#   {'mindate': '1901-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Pakistan',
#    'datacoverage': 1,
#    'id': 'FIPS:PK'},
#   {'mindate': '1931-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Poland',
#    'datacoverage': 1,
#    'id': 'FIPS:PL'},
#   {'mindate': '1949-01-01',
#    'maxdate': '1993-12-31',
#    'name': 'Panama',
#    'datacoverage': 1,
#    'id': 'FIPS:PM'},
#   {'mindate': '1900-12-01',
#    'maxdate': '2018-11-30',
#    'name': 'Portugal',
#    'datacoverage': 1,
#    'id': 'FIPS:PO'},
#   {'mindate': '1970-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Papua New Guinea',
#    'datacoverage': 1,
#    'id': 'FIPS:PP'},
#   {'mindate': '1945-05-01',
#    'maxdate': '2018-12-01',
#    'name': 'Palau',
#    'datacoverage': 1,
#    'id': 'FIPS:PS'},
#   {'mindate': '1973-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Guinea-Bissau',
#    'datacoverage': 1,
#    'id': 'FIPS:PU'},
#   {'mindate': '1983-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Qatar',
#    'datacoverage': 0.9925,
#    'id': 'FIPS:QA'},
#   {'mindate': '1935-12-01',
#    'maxdate': '2018-11-30',
#    'name': 'Serbia',
#    'datacoverage': 1,
#    'id': 'FIPS:RB'},
#   {'mindate': '1973-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Reunion',
#    'datacoverage': 1,
#    'id': 'FIPS:RE'},
#   {'mindate': '1945-05-01',
#    'maxdate': '2018-12-01',
#    'name': 'Marshall Is.',
#    'datacoverage': 1,
#    'id': 'FIPS:RM'},
#   {'mindate': '1880-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Romania',
#    'datacoverage': 1,
#    'id': 'FIPS:RO'},
#   {'mindate': '1944-10-22',
#    'maxdate': '2018-12-01',
#    'name': 'Philippines',
#    'datacoverage': 1,
#    'id': 'FIPS:RP'},
#   {'mindate': '1874-10-01',
#    'maxdate': '2018-12-03',
#    'name': 'Russia',
#    'datacoverage': 1,
#    'id': 'FIPS:RS'},
#   {'mindate': '1973-06-01',
#    'maxdate': '2018-11-30',
#    'name': 'Rwanda',
#    'datacoverage': 0.6945,
#    'id': 'FIPS:RW'},
#   {'mindate': '1946-02-14',
#    'maxdate': '2018-11-30',
#    'name': 'Saudi Arabia',
#    'datacoverage': 1,
#    'id': 'FIPS:SA'},
#   {'mindate': '1850-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'South Africa',
#    'datacoverage': 1,
#    'id': 'FIPS:SF'},
#   {'mindate': '1857-03-01',
#    'maxdate': '2018-11-30',
#    'name': 'Senegal',
#    'datacoverage': 1,
#    'id': 'FIPS:SG'},
#   {'mindate': '1957-09-01',
#    'maxdate': '2001-12-31',
#    'name': 'St. Helena',
#    'datacoverage': 1,
#    'id': 'FIPS:SH'},
#   {'mindate': '1899-12-01',
#    'maxdate': '2018-11-30',
#    'name': 'Slovenia',
#    'datacoverage': 1,
#    'id': 'FIPS:SI'},
#   {'mindate': '1973-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Sierra Leone',
#    'datacoverage': 1,
#    'id': 'FIPS:SL'},
#   {'mindate': '1962-05-01',
#    'maxdate': '2018-11-30',
#    'name': 'Singapore',
#    'datacoverage': 0.9973,
#    'id': 'FIPS:SN'},
#   {'mindate': '1896-11-01',
#    'maxdate': '2018-12-01',
#    'name': 'Spain',
#    'datacoverage': 1,
#    'id': 'FIPS:SP'},
#   {'mindate': '1948-12-01',
#    'maxdate': '2018-12-01',
#    'name': 'St. Lucia',
#    'datacoverage': 1,
#    'id': 'FIPS:ST'},
#   {'mindate': '1942-11-01',
#    'maxdate': '2018-11-30',
#    'name': 'Sudan',
#    'datacoverage': 1,
#    'id': 'FIPS:SU'},
#   {'mindate': '1860-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Sweden',
#    'datacoverage': 1,
#    'id': 'FIPS:SW'},
#   {'mindate': '1914-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Syria',
#    'datacoverage': 1,
#    'id': 'FIPS:SY'},
#   {'mindate': '1882-09-01',
#    'maxdate': '2018-11-30',
#    'name': 'Switzerland',
#    'datacoverage': 1,
#    'id': 'FIPS:SZ'},
#   {'mindate': '1945-03-01',
#    'maxdate': '2018-12-01',
#    'name': 'Trinidad & Tobago',
#    'datacoverage': 1,
#    'id': 'FIPS:TD'},
#   {'mindate': '1943-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Thailand',
#    'datacoverage': 1,
#    'id': 'FIPS:TH'},
#   {'mindate': '1895-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Tajikistan',
#    'datacoverage': 1,
#    'id': 'FIPS:TI'},
#   {'mindate': '1954-11-01',
#    'maxdate': '1970-12-31',
#    'name': 'Turks & Caicos Is.',
#    'datacoverage': 0.9948,
#    'id': 'FIPS:TK'},
#   {'mindate': '1973-01-01',
#    'maxdate': '2018-12-01',
#    'name': 'Tonga',
#    'datacoverage': 0.89,
#    'id': 'FIPS:TN'},
#   {'mindate': '1945-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Togo',
#    'datacoverage': 1,
#    'id': 'FIPS:TO'},
#   {'mindate': '1886-03-01',
#    'maxdate': '2018-11-30',
#    'name': 'Tunisia',
#    'datacoverage': 1,
#    'id': 'FIPS:TS'},
#   {'mindate': '1929-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Turkey',
#    'datacoverage': 1,
#    'id': 'FIPS:TU'},
#   {'mindate': '1883-08-01',
#    'maxdate': '2018-11-30',
#    'name': 'Turkmenistan',
#    'datacoverage': 1,
#    'id': 'FIPS:TX'},
#   {'mindate': '1950-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Tanzania',
#    'datacoverage': 1,
#    'id': 'FIPS:TZ'},
#   {'mindate': '1942-09-01',
#    'maxdate': '2017-09-13',
#    'name': 'Curacao',
#    'datacoverage': 1,
#    'id': 'FIPS:UC'},
#   {'mindate': '1926-01-01',
#    'maxdate': '1986-12-31',
#    'name': 'Uganda',
#    'datacoverage': 0.9951,
#    'id': 'FIPS:UG'},
#   {'mindate': '1838-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'United Kingdom',
#    'datacoverage': 1,
#    'id': 'FIPS:UK'},
#   {'mindate': '1879-02-01',
#    'maxdate': '2018-11-30',
#    'name': 'Ukraine',
#    'datacoverage': 1,
#    'id': 'FIPS:UP'},
#   {'mindate': '1831-02-01',
#    'maxdate': '2018-12-03',
#    'name': 'United States',
#    'datacoverage': 1,
#    'id': 'FIPS:US'},
#   {'mindate': '1940-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Burkina Faso',
#    'datacoverage': 1,
#    'id': 'FIPS:UV'},
#   {'mindate': '1931-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Uruguay',
#    'datacoverage': 1,
#    'id': 'FIPS:UY'},
#   {'mindate': '1881-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Uzbekistan',
#    'datacoverage': 1,
#    'id': 'FIPS:UZ'},
#   {'mindate': '2005-01-01',
#    'maxdate': '2018-08-15',
#    'name': 'St. Vincent & the Grenadines',
#    'datacoverage': 0.47,
#    'id': 'FIPS:VC'},
#   {'mindate': '1950-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Venezuela',
#    'datacoverage': 1,
#    'id': 'FIPS:VE'},
#   {'mindate': '1997-07-07',
#    'maxdate': '2017-09-26',
#    'name': 'British Virgin Is.',
#    'datacoverage': 0.95,
#    'id': 'FIPS:VI'},
#   {'mindate': '1951-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Vietnam',
#    'datacoverage': 1,
#    'id': 'FIPS:VM'},
#   {'mindate': '1913-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Namibia',
#    'datacoverage': 1,
#    'id': 'FIPS:WA'},
#   {'mindate': '1903-07-01',
#    'maxdate': '2018-11-30',
#    'name': 'Swaziland',
#    'datacoverage': 1,
#    'id': 'FIPS:WZ'},
#   {'mindate': '1950-01-01',
#    'maxdate': '2018-11-30',
#    'name': 'Zambia',
#    'datacoverage': 1,
#    'id': 'FIPS:ZA'},
#   {'mindate': '1951-07-01',
#    'maxdate': '2018-11-30',
#    'name': 'Zimbabwe',
#    'datacoverage': 1,
#    'id': 'FIPS:ZI'}]}

# %%
country_ids = []
for country in data['results']:
    country_ids.append({country['name']: country['id']})

# %%
country_ids[:2]
# Out:
# [{'Aruba': 'FIPS:AA'}, {'Antigua & Barbuda': 'FIPS:AC'}]

# %%
parameters = {'locationid'}

# %%
r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/datacategories?locationid=FIPS:AR', headers=headers)

# %%
data = r.json()

# %%
data
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 4, 'limit': 25}},
#  'results': [{'name': 'Computed', 'id': 'COMP'},
#   {'name': 'Miscellany', 'id': 'MISC'},
#   {'name': 'Precipitation', 'id': 'PRCP'},
#   {'name': 'Air Temperature', 'id': 'TEMP'}]}

# %%
r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GSOY&locationid=FIPS:AR&startdate=2016-01-01&enddate=2016-12-31&limit=270', headers=headers)

# %%
data = r.json()

# %%
data
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 219, 'limit': 270}},
#  'results': [{'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S',
#    'value': 139},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S,0717,',
#    'value': -9.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S,0422',
#    'value': -0.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S,0423',
#    'value': -2.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S,0427',
#    'value': -4.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF3',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S,0619',
#    'value': -8.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF4',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S,0715',
#    'value': -8.9},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S,1105',
#    'value': -0.9},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S,0915',
#    'value': -2.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF7',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S,0908',
#    'value': -4.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF8',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S,0831',
#    'value': -8.3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:AR000087007',
#    'attributes': 'S',
#    'value': 2.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:AR000087257',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:AR000087257',
#    'attributes': 'S',
#    'value': 1},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:AR000087257',
#    'attributes': 'S,0611,',
#    'value': -0.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:AR000087257',
#    'attributes': 'S,0611',
#    'value': -0.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:AR000087257',
#    'attributes': 'S',
#    'value': 13.18},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:AR000087534',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:AR000087534',
#    'attributes': 'S',
#    'value': 8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:AR000087534',
#    'attributes': 'S,0902,',
#    'value': -2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:AR000087534',
#    'attributes': 'S,0622',
#    'value': -1.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:AR000087534',
#    'attributes': 'S,0907',
#    'value': -1.1},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:AR000087534',
#    'attributes': 'S',
#    'value': 10.93},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:AR000087623',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:AR000087623',
#    'attributes': 'S',
#    'value': 32},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:AR000087623',
#    'attributes': 'S,0907,+',
#    'value': -3.1},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:AR000087623',
#    'attributes': 'S,0427',
#    'value': -0.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:AR000087623',
#    'attributes': 'S,0430',
#    'value': -2.3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:AR000087623',
#    'attributes': 'S,0923',
#    'value': -0.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:AR000087623',
#    'attributes': 'S,0907',
#    'value': -3.1},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:AR000087623',
#    'attributes': 'S',
#    'value': 8.88},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S',
#    'value': 99},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S,0701,',
#    'value': -9.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S,0401',
#    'value': -1.3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S,0408',
#    'value': -2.3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S,0418',
#    'value': -5.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF3',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S,0610',
#    'value': -6.9},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF4',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S,0701',
#    'value': -9.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S,1117',
#    'value': -0.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S,1010',
#    'value': -3.1},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF7',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S,0904',
#    'value': -5.9},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF8',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S,0820',
#    'value': -7.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:AR000087803',
#    'attributes': 'S',
#    'value': 3.46},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:AR000087828',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:AR000087828',
#    'attributes': 'S',
#    'value': 53},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:AR000087828',
#    'attributes': 'S,0702,',
#    'value': -7.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:AR000087828',
#    'attributes': 'S,0427',
#    'value': -2.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:AR000087828',
#    'attributes': 'S,0427',
#    'value': -2.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:AR000087828',
#    'attributes': 'S,0619',
#    'value': -4.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF3',
#    'station': 'GHCND:AR000087828',
#    'attributes': 'S,0702',
#    'value': -7.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:AR000087828',
#    'attributes': 'S,0923',
#    'value': -2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:AR000087828',
#    'attributes': 'S',
#    'value': 7.36},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:AR000875850',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:AR000875850',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:AR000875850',
#    'attributes': 'S,0717,',
#    'value': 1.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:AR000875850',
#    'attributes': 'S',
#    'value': 13.43},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:AR000877500',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:AR000877500',
#    'attributes': 'S',
#    'value': 32},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:AR000877500',
#    'attributes': 'S,0902,+',
#    'value': -5.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:AR000877500',
#    'attributes': 'S,0430',
#    'value': -0.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:AR000877500',
#    'attributes': 'S,0620',
#    'value': -3.1},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:AR000877500',
#    'attributes': 'S,0717',
#    'value': -5.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:AR000877500',
#    'attributes': 'S,0924',
#    'value': -3.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:AR000877500',
#    'attributes': 'S,0924',
#    'value': -3.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF7',
#    'station': 'GHCND:AR000877500',
#    'attributes': 'S,0902',
#    'value': -5.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:AR000877500',
#    'attributes': 'S',
#    'value': 8.76},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087016',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087016',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087016',
#    'attributes': 'S,0822,',
#    'value': 4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087016',
#    'attributes': 'S',
#    'value': 16.58},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087022',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087022',
#    'attributes': 'S',
#    'value': 1},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087022',
#    'attributes': 'S,0822,',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087022',
#    'attributes': 'S,0822',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087022',
#    'attributes': 'S',
#    'value': 16.26},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087148',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087148',
#    'attributes': 'S',
#    'value': 16},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087148',
#    'attributes': 'S,0622,',
#    'value': -3.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087148',
#    'attributes': 'S,0607',
#    'value': -1},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087148',
#    'attributes': 'S,0612',
#    'value': -2.7},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087148',
#    'attributes': 'S,0907',
#    'value': -0.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087148',
#    'attributes': 'S',
#    'value': 14.3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087320',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087320',
#    'attributes': 'S',
#    'value': 4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087320',
#    'attributes': 'S,0906,',
#    'value': -2.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087320',
#    'attributes': 'S,0612',
#    'value': -0.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087320',
#    'attributes': 'S,0906',
#    'value': -2.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:ARM00087320',
#    'attributes': 'S,0906',
#    'value': -2.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087320',
#    'attributes': 'S',
#    'value': 13.16},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087328',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087328',
#    'attributes': 'S',
#    'value': 6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087328',
#    'attributes': 'S,0716,',
#    'value': -2.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087328',
#    'attributes': 'S,0427',
#    'value': -2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087328',
#    'attributes': 'S,0716',
#    'value': -2.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087328',
#    'attributes': 'S,0906',
#    'value': -0.3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087328',
#    'attributes': 'S',
#    'value': 11.67},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087349',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087349',
#    'attributes': 'S',
#    'value': 17},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087349',
#    'attributes': 'S,0622,',
#    'value': -2.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087349',
#    'attributes': 'S,0611',
#    'value': -1.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087349',
#    'attributes': 'S,0622',
#    'value': -2.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087349',
#    'attributes': 'S,0907',
#    'value': -1.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087349',
#    'attributes': 'S',
#    'value': 11.15},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087395',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087395',
#    'attributes': 'S',
#    'value': 3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087395',
#    'attributes': 'S,0612,',
#    'value': -2.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087395',
#    'attributes': 'S,0609',
#    'value': -0.1},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087395',
#    'attributes': 'S,0612',
#    'value': -2.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087395',
#    'attributes': 'S',
#    'value': 13.13},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087416',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087416',
#    'attributes': 'S',
#    'value': 5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087416',
#    'attributes': 'S,0717,+',
#    'value': -1.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087416',
#    'attributes': 'S,0611',
#    'value': -1.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087416',
#    'attributes': 'S',
#    'value': 10.84},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087467',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087467',
#    'attributes': 'S',
#    'value': 11},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087467',
#    'attributes': 'S,0907,',
#    'value': -2.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087467',
#    'attributes': 'S,0611',
#    'value': -0.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087467',
#    'attributes': 'S,0908',
#    'value': -0.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:ARM00087467',
#    'attributes': 'S,0907',
#    'value': -2.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087467',
#    'attributes': 'S',
#    'value': 10.66},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087506',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087506',
#    'attributes': 'S',
#    'value': 86},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087506',
#    'attributes': 'S,0905,+',
#    'value': -6.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087506',
#    'attributes': 'S,0419',
#    'value': -1.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087506',
#    'attributes': 'S,0425',
#    'value': -2.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:ARM00087506',
#    'attributes': 'S,0611',
#    'value': -5.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087506',
#    'attributes': 'S,0924',
#    'value': -1.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:ARM00087506',
#    'attributes': 'S,0907',
#    'value': -2.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF7',
#    'station': 'GHCND:ARM00087506',
#    'attributes': 'S,0906',
#    'value': -6.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087506',
#    'attributes': 'S',
#    'value': 5.23},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087532',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087532',
#    'attributes': 'S',
#    'value': 26},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087532',
#    'attributes': 'S,0610,',
#    'value': -4.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087532',
#    'attributes': 'S,0427',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087532',
#    'attributes': 'S,0610',
#    'value': -4.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:ARM00087532',
#    'attributes': 'S,0610',
#    'value': -4.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087532',
#    'attributes': 'S,0923',
#    'value': -1.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:ARM00087532',
#    'attributes': 'S,0906',
#    'value': -3.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087532',
#    'attributes': 'S',
#    'value': 9.91},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087641',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087641',
#    'attributes': 'S',
#    'value': 45},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087641',
#    'attributes': 'S,0620,',
#    'value': -5.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087641',
#    'attributes': 'S,0428',
#    'value': -2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087641',
#    'attributes': 'S,0605',
#    'value': -3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:ARM00087641',
#    'attributes': 'S,0620',
#    'value': -5.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087641',
#    'attributes': 'S,1028',
#    'value': -1.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:ARM00087641',
#    'attributes': 'S,0904',
#    'value': -4.7},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF7',
#    'station': 'GHCND:ARM00087641',
#    'attributes': 'S,0904',
#    'value': -4.7},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087641',
#    'attributes': 'S',
#    'value': 7.51},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087645',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087645',
#    'attributes': 'S',
#    'value': 51},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087645',
#    'attributes': 'S,0620,',
#    'value': -6.3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087645',
#    'attributes': 'S,0422',
#    'value': -1.3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087645',
#    'attributes': 'S,0605',
#    'value': -2.9},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:ARM00087645',
#    'attributes': 'S,0620',
#    'value': -6.3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087645',
#    'attributes': 'S,1122',
#    'value': -1},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:ARM00087645',
#    'attributes': 'S,0925',
#    'value': -3.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087645',
#    'attributes': 'S',
#    'value': 6.83},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S',
#    'value': 116},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S,0724,',
#    'value': -14.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S,0324',
#    'value': -1.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S,0408',
#    'value': -2.9},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S,0418',
#    'value': -7.9},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF3',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S,0418',
#    'value': -7.9},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF4',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S,0630',
#    'value': -10.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S,1117',
#    'value': -3.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S,1117',
#    'value': -3.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF7',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S,1008',
#    'value': -4.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF8',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S,0923',
#    'value': -8.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF9',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S,0905',
#    'value': -10.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087774',
#    'attributes': 'S',
#    'value': 2.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087784',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087784',
#    'attributes': 'S',
#    'value': 44},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087784',
#    'attributes': 'S,0702,',
#    'value': -6.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087784',
#    'attributes': 'S,0427',
#    'value': -2.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087784',
#    'attributes': 'S,0427',
#    'value': -2.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:ARM00087784',
#    'attributes': 'S,0630',
#    'value': -4.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087784',
#    'attributes': 'S,0924',
#    'value': -1.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:ARM00087784',
#    'attributes': 'S,0903',
#    'value': -3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087784',
#    'attributes': 'S',
#    'value': 8.24},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087791',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087791',
#    'attributes': 'S',
#    'value': 43},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087791',
#    'attributes': 'S,0904,+',
#    'value': -5.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087791',
#    'attributes': 'S,0418',
#    'value': -1.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087791',
#    'attributes': 'S,0619',
#    'value': -2.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:ARM00087791',
#    'attributes': 'S,0702',
#    'value': -5.5},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087791',
#    'attributes': 'S,1020',
#    'value': -0.3},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:ARM00087791',
#    'attributes': 'S,0905',
#    'value': -4.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF7',
#    'station': 'GHCND:ARM00087791',
#    'attributes': 'S,0905',
#    'value': -4.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087791',
#    'attributes': 'S',
#    'value': 7.69},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S',
#    'value': 155},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S,0726,',
#    'value': -17},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S,0309',
#    'value': -1.6},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S,0408',
#    'value': -3.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S,0410',
#    'value': -4.8},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF3',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S,0424',
#    'value': -7},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF4',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S,0430',
#    'value': -9.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S,1213',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S,1017',
#    'value': -4.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF7',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S,1017',
#    'value': -4.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF8',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S,0820',
#    'value': -10.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF9',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S,0820',
#    'value': -10.2},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087904',
#    'attributes': 'S',
#    'value': 1.31},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT00',
#    'station': 'GHCND:ARM00087909',
#    'attributes': 'S',
#    'value': 0},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'DT32',
#    'station': 'GHCND:ARM00087909',
#    'attributes': 'S',
#    'value': 75},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'EMNT',
#    'station': 'GHCND:ARM00087909',
#    'attributes': 'S,0731,',
#    'value': -6.9},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF0',
#    'station': 'GHCND:ARM00087909',
#    'attributes': 'S,0408',
#    'value': -0.1},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF1',
#    'station': 'GHCND:ARM00087909',
#    'attributes': 'S,0429',
#    'value': -3.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF2',
#    'station': 'GHCND:ARM00087909',
#    'attributes': 'S,0506',
#    'value': -4.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF3',
#    'station': 'GHCND:ARM00087909',
#    'attributes': 'S,0731',
#    'value': -6.9},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF5',
#    'station': 'GHCND:ARM00087909',
#    'attributes': 'S,1018',
#    'value': -1.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF6',
#    'station': 'GHCND:ARM00087909',
#    'attributes': 'S,1015',
#    'value': -2.4},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'FZF7',
#    'station': 'GHCND:ARM00087909',
#    'attributes': 'S,0820',
#    'value': -4.9},
#   {'date': '2016-01-01T00:00:00',
#    'datatype': 'TMIN',
#    'station': 'GHCND:ARM00087909',
#    'attributes': 'S',
#    'value': 4.21}]}
