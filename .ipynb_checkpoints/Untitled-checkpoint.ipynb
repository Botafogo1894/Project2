# %%
gdp_url = "https://www.cia.gov/library/publications/the-world-factbook/rankorder/rawdata_2004.txt"
unemp_url = "https://www.cia.gov/library/publications/the-world-factbook/rankorder/rawdata_2129.txt"
econ_url = "https://data.theglobaleconomy.com/data_export_api.php?tp=1&ind=338,184,353,52,10,154,334,333,361,120&cnt=AF,AL,DZ,AD,AO,AG,AR,AM,AW,AU,AT,AZ,BS,BH,BD,BB,BY,BE,BZ,BJ,BM,BT,BO,BA,BW,BR,BN,BG,BF,MM,BI,KH,CM,CA,CV,CF,TD,CL,CN,CO,KM,CR,HR,CU,CY,CZ,CD,DK,DJ,DM,DO,EC,EG,SV,GQ,ER,EE,ET,FO,FJ,FI,FR,GA,GM,GE,DE,GH,GI,GR,GD,GT,GN,GW,GY,HT,VA,HN,HK,HU,IS,IN,ID,IR,IQ,IE,IL,IT,CI,JM,JP,JO,KZ,KE,KI,KW,KG,LA,LV,LB,LS,LR,LY,LI,LT,LU,MO,MK,MG,MW,MY,MV,ML,MT,MR,MU,MX,FM,MD,MC,MN,ME,MS,MA,MZ,NA,NP,NL,NC,NZ,NI,NE,NG,NF,KP,NO,OM,PK,PW,PS,PA,PG,PY,PE,PH,PL,PT,PR,QA,CG,RO,RU,RW,LC,VC,WS,SM,ST,SA,SN,RS,SC,SL,SG,SK,SI,SB,SO,ZA,KR,ES,LK,SD,SR,SZ,SE,CH,SY,TW,TJ,TZ,TH,TG,TO,TT,TN,TR,TM,TV,UG,UA,AE,GB,UY,US,UZ,VU,VE,VN,YE,ZM,ZW&prd=2014:2018&uid=52418&uidc=2c0f8f9fb939db747eb52f0b97a60b5e"
import urllib  # the lib that handles the url stuff
import json
import pandas as pd
import numpy as np
from xml.dom import minidom
from urllib.request import urlopen


GDP = pd.read_fwf('gdp_perca.txt', header = None, names = ['country', 'GDP']).astype(str)
Unemp = pd.read_fwf('unemp.txt', header = None, names = ['Unem_rate'])
mental = pd.read_csv('mental_disorder_substance_use.csv')
healthcare = pd.read_excel('NHA.xlsx')

      
index_list = [item[1] for item in Unemp.index]
Unemp.index = index_list
Unemp.head()

gdp = GDP.set_index('country')
health = healthcare[["Countries", '2016']]
nha = health.drop([0], axis = 0)

# %%
mental1 = mental[mental.Year == 2016]

# %%
mental1.dropna(axis = 0, inplace = True)
mental1.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#              Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 26      Afghanistan  AFG  2016           0.159494              0.760363
# 53          Albania  ALB  2016           0.231592              0.667222
# 80          Algeria  DZA  2016           0.199488              0.868839
# 107  American Samoa  ASM  2016           0.338391              0.480390
# 161         Andorra  AND  2016           0.274369              1.146873
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 26               0.088103               5.023055                1.196912
# 53               0.113824               3.557997                0.655556
# 80               0.181441               5.249815                0.880553
# 107              0.123188               3.582901                0.756006
# 161              0.496292               5.422001                0.985602
#
#      Depression (%)  Alcohol use disorders (%)
# 26         4.404727                   0.612712
# 53         2.450883                   1.669982
# 80         3.946200                   0.605362
# 107        3.252115                   0.866426
# 161        4.000260                   1.155499

# %%
men_copy = mental1.set_index('Entity')

# %%
Unemp.head()
# Out:
#                          Unem_rate
# Cocos (Keeling) Islands        0.1
# Cambodia                       0.3
# Qatar                          0.6
# Thailand                       0.7
# Gibraltar                      1.0

# %%
merged = men_copy.join(Unemp)

# %%
merged.drop('Year', axis = 1, inplace = True)

# %%
merged.head()
# Out:
#                Code  Schizophrenia (%)  Bipolar disorder (%)  \
# Entity
# Afghanistan     AFG           0.159494              0.760363
# Albania         ALB           0.231592              0.667222
# Algeria         DZA           0.199488              0.868839
# American Samoa  ASM           0.338391              0.480390
# Andorra         AND           0.274369              1.146873
#
#                 Eating disorders (%)  Anxiety disorders (%)  \
# Entity
# Afghanistan                 0.088103               5.023055
# Albania                     0.113824               3.557997
# Algeria                     0.181441               5.249815
# American Samoa              0.123188               3.582901
# Andorra                     0.496292               5.422001
#
#                 Drug use disorders (%)  Depression (%)  \
# Entity
# Afghanistan                   1.196912        4.404727
# Albania                       0.655556        2.450883
# Algeria                       0.880553        3.946200
# American Samoa                0.756006        3.252115
# Andorra                       0.985602        4.000260
#
#                 Alcohol use disorders (%)  Unem_rate
# Entity
# Afghanistan                      0.612712       23.9
# Albania                          1.669982       14.0
# Algeria                          0.605362       11.7
# American Samoa                   0.866426       29.8
# Andorra                          1.155499        3.7

# %%
import seaborn as sns

# %%
sns.heatmap(merged.corr(), center = 0)

# %%
merged = merged.join(gdp)

# %%
merged.head()
# Out:
#                Code  Schizophrenia (%)  Bipolar disorder (%)  \
# Entity
# Afghanistan     AFG           0.159494              0.760363
# Albania         ALB           0.231592              0.667222
# Algeria         DZA           0.199488              0.868839
# American Samoa  ASM           0.338391              0.480390
# Andorra         AND           0.274369              1.146873
#
#                 Eating disorders (%)  Anxiety disorders (%)  \
# Entity
# Afghanistan                 0.088103               5.023055
# Albania                     0.113824               3.557997
# Algeria                     0.181441               5.249815
# American Samoa              0.123188               3.582901
# Andorra                     0.496292               5.422001
#
#                 Drug use disorders (%)  Depression (%)  \
# Entity
# Afghanistan                   1.196912        4.404727
# Albania                       0.655556        2.450883
# Algeria                       0.880553        3.946200
# American Samoa                0.756006        3.252115
# Andorra                       0.985602        4.000260
#
#                 Alcohol use disorders (%)  Unem_rate      GDP
# Entity
# Afghanistan                      0.612712       23.9   $2,000
# Albania                          1.669982       14.0  $12,500
# Algeria                          0.605362       11.7  $15,200
# American Samoa                   0.866426       29.8  $11,200
# Andorra                          1.155499        3.7  $49,900

# %%
merged.dropna(inplace = True)

# %%
merged.tail()
# Out:
#           Code  Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
# Entity
# Venezuela  VEN           0.213391              0.789515              0.176767
# Vietnam    VNM           0.304671              0.562950              0.088674
# Yemen      YEM           0.174584              0.795032              0.114414
# Zambia     ZMB           0.187785              0.602420              0.092035
# Zimbabwe   ZWE           0.178645              0.611995              0.077739
#
#            Anxiety disorders (%)  Drug use disorders (%)  Depression (%)  \
# Entity
# Venezuela               2.931126                0.483021        3.089228
# Vietnam                 2.810441                0.799416        3.223907
# Yemen                   5.092210                0.821910        4.350973
# Zambia                  3.350081                0.468239        4.163807
# Zimbabwe                3.388782                0.652979        3.599630
#
#            Alcohol use disorders (%)  Unem_rate      GDP
# Entity
# Venezuela                   1.395381       26.4  $12,100
# Vietnam                     1.569662        2.2   $6,900
# Yemen                       0.583067       27.0   $1,300
# Zambia                      1.675675       15.0   $4,000
# Zimbabwe                    1.667406       11.3   $2,300

# %%
gdps = [item.split(",") for item in merged.GDP]

def clean_gdp(data):
    empty = []
    for item in data:
        first = item[0].split("$")[1]
        second = item[1]
        total = first+second
        empty.append(total)
    return empty

# %%
merged.GDP = clean_gdp(gdps)

# %%
merged.sort_values(by = "Entity", ascending = False)
merged[merged.Code == "RUS"]
# Out:
#        Code  Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
# Entity
# Russia  RUS           0.213259              0.638644              0.141571
#
#         Anxiety disorders (%)  Drug use disorders (%)  Depression (%)  \
# Entity
# Russia                2.96687                1.248145        4.063449
#
#         Alcohol use disorders (%)  Unem_rate    GDP
# Entity
# Russia                   4.684679        5.5  27800

# %%
nha.head()
# Out:
#                   Countries     2016
# 1  United States of America  9869.74
# 2               Switzerland  9835.96
# 3                    Norway   7477.9
# 4                Luxembourg  6271.44
# 5                    Sweden  5710.59

# %%
health = nha.set_index('Countries')
health.rename(columns = {'2016': 'health_spend_perca'}, inplace = True)
health.head()
# Out:
#                          health_spend_perca
# Countries
# United States of America            9869.74
# Switzerland                         9835.96
# Norway                               7477.9
# Luxembourg                          6271.44
# Sweden                              5710.59

# %%
new = merged.join(health)
new.loc["Russia", 'health_spend_perca'] = 1414.12
new[new.index == "Russia"]
new.loc["United States", 'health_spend_perca'] = 9869.74

# %%
new.sort_values(by ='health_spend_perca', ascending=False)
# Out:
#                Code  Schizophrenia (%)  Bipolar disorder (%)  \
# Entity
# United States   USA           0.336158              0.797768
# Switzerland     CHE           0.269762              1.120075
# Norway          NOR           0.278298              0.909592
# Luxembourg      LUX           0.272749              1.114745
# Sweden          SWE           0.300906              1.030447
# Denmark         DNK           0.265556              0.981735
# Iceland         ISL           0.267483              0.945582
# Australia       AUS           0.373657              1.476689
# Ireland         IRL           0.309268              0.809788
# Netherlands     NLD           0.391409              0.906036
# Germany         DEU           0.242870              0.812681
# Austria         AUT           0.267903              1.125465
# Canada          CAN           0.332430              0.866500
# France          FRA           0.262184              1.130635
# Japan           JPN           0.313584              0.709573
# Belgium         BEL           0.270838              1.135000
# Finland         FIN           0.273948              1.038547
# United Kingdom  GBR           0.273478              1.118088
# Andorra         AND           0.274369              1.146873
# New Zealand     NZL           0.346846              1.308596
# Israel          ISR           0.249005              0.963438
# Italy           ITA           0.245941              0.953980
# Singapore       SGP           0.289308              0.746159
# Spain           ESP           0.295102              1.010307
# Malta           MLT           0.268191              1.135880
# Slovenia        SVN           0.241746              0.689789
# Qatar           QAT           0.222930              0.849364
# Portugal        PRT           0.261613              1.118807
# Cyprus          CYP           0.261844              1.125330
# Greece          GRC           0.264182              1.129552
# ...             ...                ...                   ...
# Haiti           HTI           0.170757              0.813098
# Uganda          UGA           0.182129              0.611229
# Guinea          GIN           0.188304              0.627017
# Bangladesh      BGD           0.248877              0.535906
# Benin           BEN           0.193936              0.633435
# Eritrea         ERI           0.183560              0.629700
# Mali            MLI           0.192824              0.628391
# Malawi          MWI           0.175185              0.606262
# Ethiopia        ETH           0.184913              0.622198
# Haiti                            1.691082       40.6    1800
# Uganda                           1.254208        9.4    2400
# Guinea                           1.147742        2.8    2000
# Bangladesh                       1.476278        4.0    4200
# Benin                            1.216588        1.0    2300
# Eritrea                          1.530175        8.6    1600
# Mali                             1.137373        8.1    2200
# Malawi                           1.540006       20.4    1200
# Ethiopia                         2.135063       17.5    2200
# Madagascar                       1.470272        2.1    1600
# Niger                            1.132870        2.6    1200
# Mozambique                       1.501155       24.5    1200
# American Samoa                   0.866426       29.8   11200
# Bermuda                          1.524187        7.0   99400
# Bolivia                          1.506140        4.0    7500
# Brunei                           0.790964        6.9   78200
# Cote d'Ivoire                    1.238494        9.4    3900
# Greenland                        3.049052        9.1   41800
# Guam                             0.971169        4.5   35600
# Laos                             0.830444        1.5    7400
# Libya                            0.598776       30.0   10000
# Macedonia                        1.706657       23.4   14900
# Moldova                          3.478930        4.1    5700
# Puerto Rico                      1.723150       11.5   37300
# Syria                            0.536728       50.0    2900
# Taiwan                           1.115998        3.8   50300
# Tanzania                         1.551957       10.3    3200
# Venezuela                        1.395381       26.4   12100
# Vietnam                          1.569662        2.2    6900
# Yemen                            0.583067       27.0    1300
#
#                health_spend_perca
# Entity
# United States             9869.74
# Switzerland               9835.96
# Norway                     7477.9
# Luxembourg                6271.44
# Sweden                    5710.59
# Denmark                   5565.59
# Iceland                   5063.61
# Australia                 5002.36
# Ireland                   4758.59
# Netherlands               4742.03
# Germany                   4714.26
# Austria                   4688.28
# Canada                    4458.21
# France                    4263.36
# Japan                     4233.03
# Belgium                   4149.39
# Finland                   4117.26
# United Kingdom            3958.02
# Andorra                   3834.73
# New Zealand               3745.22
# Israel                    2837.14
# Italy                     2738.71
# Singapore                 2462.39
# Spain                     2389.89
# Malta                     2327.78
# Slovenia                  1834.16
# Qatar                     1827.06
# Portugal                  1800.86
# Cyprus                    1634.43
# Greece                    1510.67
# ...                           ...
# Haiti                     37.7231
# Uganda                     37.607
# Guinea                    37.4593
# Bangladesh                 34.218
# Benin                     30.4015
# Eritrea                   29.8912
# Mali                      29.7866
# Malawi                    29.5874
# Ethiopia                  27.5237
# Madagascar                24.1191
# Niger                     22.6833
# Mozambique                19.2075
# American Samoa                NaN
# Bermuda                       NaN
# Bolivia                       NaN
# Brunei                        NaN
# Cote d'Ivoire                 NaN
# Greenland                     NaN
# Guam                          NaN
# Laos                          NaN
# Libya                         NaN
# Macedonia                     NaN
# Moldova                       NaN
# Puerto Rico                   NaN
# Syria                         NaN
# Taiwan                        NaN
# Tanzania                      NaN
# Venezuela                     NaN
# Vietnam                       NaN
# Yemen                         NaN
#
# [169 rows x 11 columns]

# %%
final = new.dropna()

# %%
int(final.GDP[1])
# Out:
# 12500

# %%
test = [int(item) for item in final.GDP]

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, Afghanistan to Zimbabwe
# Data columns (total 11 columns):
# Code                         151 non-null object
# Schizophrenia (%)            151 non-null float64
# Bipolar disorder (%)         151 non-null float64
# Eating disorders (%)         151 non-null float64
# Anxiety disorders (%)        151 non-null float64
# Drug use disorders (%)       151 non-null float64
# Depression (%)               151 non-null float64
# Alcohol use disorders (%)    151 non-null float64
# Unem_rate                    151 non-null float64
# GDP                          151 non-null object
# health_spend_perca           151 non-null object
# dtypes: float64(8), object(3)
# memory usage: 19.2+ KB

# %%
pd.plotting.scatter_matrix(final, figsize = [12, 12])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1a7fa908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a9ff940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aa2ac50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aa53f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aa83400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aa83438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aadd160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ab037f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ab2ce80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ab5c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ab84be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1abb72b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1abdd940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ac08fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ac386a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ac5ed30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ac90400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1acb7a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ace7160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ad0e7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ad39e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ad68550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ad8ebe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1adc32b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ade8940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ae11fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ae436a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ae6ad30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ae9a400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aec4a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aef4160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1af197f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1af42e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1af73550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1af9abe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1afcc2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aff4940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b01dfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b04d6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b075d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b0a6400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b0cda90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b0ff160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b1267f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b14de80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b17f550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b1a8be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b1d92b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b201940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b22bfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b25a6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b282d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b2b5400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b2dea90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b310160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b3367f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b360e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b391550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b3b8be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b3ec2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b414940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b43efd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b46d6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b497d30>]],
#       dtype=object)

# %%
abs(final.corr()) > 0.75
# Out:
#                            Schizophrenia (%)  Bipolar disorder (%)  \
# Schizophrenia (%)                       True                 False
# Bipolar disorder (%)                   False                  True
# Eating disorders (%)                   False                  True
# Anxiety disorders (%)                  False                  True
# Drug use disorders (%)                 False                 False
# Depression (%)                         False                 False
# Alcohol use disorders (%)              False                 False
# Unem_rate                              False                 False
#
#                            Eating disorders (%)  Anxiety disorders (%)  \
# Schizophrenia (%)                         False                  False
# Bipolar disorder (%)                       True                   True
# Eating disorders (%)                       True                  False
# Anxiety disorders (%)                     False                   True
# Drug use disorders (%)                    False                  False
# Depression (%)                            False                  False
# Alcohol use disorders (%)                 False                  False
# Unem_rate                                 False                  False
#
#                            Drug use disorders (%)  Depression (%)  \
# Schizophrenia (%)                           False           False
# Bipolar disorder (%)                        False           False
# Eating disorders (%)                        False           False
# Anxiety disorders (%)                       False           False
# Drug use disorders (%)                       True           False
# Depression (%)                              False            True
# Alcohol use disorders (%)                   False           False
# Unem_rate                                   False           False
#
#                            Alcohol use disorders (%)  Unem_rate
# Schizophrenia (%)                              False      False
# Bipolar disorder (%)                           False      False
# Eating disorders (%)                           False      False
# Anxiety disorders (%)                          False      False
# Drug use disorders (%)                         False      False
# Depression (%)                                 False      False
# Alcohol use disorders (%)                       True      False
# Unem_rate                                      False       True

# %%
#Dropping multicorelated variable = Bipolar Disorder
final.drop("Bipolar disorder (%)", axis = 1, inplace = True)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
final.head()
# Out:
#             Code  Schizophrenia (%)  Eating disorders (%)  \
# Entity
# Afghanistan  AFG           0.159494              0.088103
# Albania      ALB           0.231592              0.113824
# Algeria      DZA           0.199488              0.181441
# Andorra      AND           0.274369              0.496292
# Angola       AGO           0.198776              0.113965
#
#              Anxiety disorders (%)  Drug use disorders (%)  Depression (%)  \
# Entity
# Afghanistan               5.023055                1.196912        4.404727
# Albania                   3.557997                0.655556        2.450883
# Algeria                   5.249815                0.880553        3.946200
# Andorra                   5.422001                0.985602        4.000260
# Angola                    3.272275                0.467204        4.715467
#
#              Alcohol use disorders (%)  Unem_rate    GDP health_spend_perca
# Entity
# Afghanistan                   0.612712       23.9   2000            57.2488
# Albania                       1.669982       14.0  12500            271.543
# Algeria                       0.605362       11.7  15200            260.413
# Andorra                       1.155499        3.7  49900            3834.73
# Angola                        1.456741        6.6   6800            95.2208
