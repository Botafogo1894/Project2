# %% [markdown]
# ##### Importing suicide statistics from WHO API

# %%
import requests
import json
import pandas as pd
r = requests.get('http://apps.who.int/gho/athena/api/GHO/MH_12/.json?filter=Year:2016')
data = r.json()

# %% [markdown]
# ##### Converting JSON data to Python List

# %%
list_of_data = []
for fact in data['fact']:
    for category in fact['Dim']:
        if category['category'] == 'COUNTRY':
            country_code = category['code']
        elif category['category'] == "SEX":
            sex = category['code']
    suicide_rate = fact['value']['numeric']
    list_of_data.append({'Country Code': country_code, 'Sex': sex, "Suicide Rate": suicide_rate})

country_codes = []
for country in list_of_data:
    country_codes.append(country['Country Code'])

country_codes = set(country_codes)

data_dictionary = []
for country in country_codes:
    data_dictionary.append({'Country Code': country, 'Male Suicide Rate':'', 'Female Suicide Rate':'', 'Combined Suicide Rate':''})

# %% [markdown]
# ##### creating Python list with dictionary for each country

# %%
for data in list_of_data:
    for country in data_dictionary:
        if data['Country Code'] == country['Country Code']:
            if data['Sex'] == 'MLE':
                country['Male Suicide Rate'] = data['Suicide Rate']
            elif data['Sex'] == "FMLE":
                country['Female Suicide Rate'] = data['Suicide Rate']
            elif data['Sex'] == 'BTSX':
                country['Combined Suicide Rate'] = data['Suicide Rate']

# %% [markdown]
# ###### Converting to Pandas DataFrame

# %%
suicide_rates = pd.DataFrame.from_dict(data_dictionary,)
suicide_rates.set_index(['Country Code'], inplace=True)
suicide_rates.sort_index(inplace=True)

# %%
suicide_rates[122:155]
# Out:
#               Combined Suicide Rate  Female Suicide Rate  Male Suicide Rate
# Country Code
# NLD                             9.6                  6.4               12.9
# NOR                            10.1                  6.5               13.6
# NPL                             9.6                  8.0               11.4
# NZL                            11.6                  6.2               17.3
# OMN                             3.5                  0.9                4.8
# PAK                             3.1                  3.1                3.0
# PAN                             4.4                  1.2                7.6
# PER                             5.1                  2.7                7.6
# PHL                             3.7                  2.3                5.2
# PNG                             7.0                  3.8               10.2
# POL                            13.4                  3.4               23.9
# PRK                            10.6                  8.0               14.8
# PRT                             8.6                  3.8               14.3
# PRY                             9.3                  6.2               12.3
# QAT                             5.8                  1.1                7.3
# ROU                             8.0                  2.4               13.9
# RUS                            26.5                  7.5               48.3
# RWA                            11.0                  6.0               16.9
# SAU                             3.4                  1.7                4.6
# SDN                             9.5                  4.6               14.5
# SEN                            11.8                  5.2               20.3
# SGP                             7.9                  4.9               11.1
# SLB                             5.9                  3.2                8.5
# SLE                            16.1                 14.2               18.2
# SLV                            13.5                  4.3               24.8
# SOM                             8.3                  5.4               11.5
# SRB                            10.9                  5.2               17.3
# SSD                             6.1                  4.1                8.3
# STP                             3.1                  2.1                4.2
# SUR                            23.2                 10.9               36.1
# SVK                            10.1                  2.6               18.4
# SVN                            13.3                  4.5               22.4
# SWE                            11.7                  7.4               15.8

# %%
r = requests.get('http://apps.who.int/gho/athena/api/GHO/MH_12/.json?filter=Year:2016')
data = r.json()
country_names = []
for country in data['dimension'][4]['code']:
    country_names.append({'Country Code': country['label'], 'Country Name': country['display']})

country_names_df = pd.DataFrame.from_dict(country_names)
country_names_df.set_index('Country Code', inplace=True)

country_names_df.loc[country_names_df.index == "MLT"]

# clean Up Country Names
country_names_df.loc[country_names_df['Country Name'] == "Democratic People's Republic of Korea"] = "North Korea"
country_names_df.loc[country_names_df['Country Name'] == "The former Yugoslav republic of Macedonia"] = "Macedonia"
country_names_df.loc[country_names_df['Country Name'] == "Republic of Moldova"] = "Moldova"
country_names_df.loc[country_names_df['Country Name'] == "Iran (Islamic Republic of)"] = "Iran"
country_names_df.loc[country_names_df['Country Name'] == "Russian Federation"] = "Russia"
country_names_df.loc[country_names_df['Country Name'] == "United Kingdom of Great Britain and Northern Ireland"] = "United Kingdom"
country_names_df.loc[country_names_df['Country Name'] == "Venezuela (Bolivarian Republic of)"] = "Venezuela"
country_names_df.loc[country_names_df['Country Name'] == "United States of America"] = "United States"

country_names_df.tail(15)

suicide_rates = suicide_rates.join(country_names_df)
# suicide_rates

# %% [markdown]
# ###### Adding country names

# %%
suicide_rates = suicide_rates[['Country Name', 'Combined Suicide Rate', 'Male Suicide Rate', 'Female Suicide Rate']]
suicide_rates[95:135]
# Out:
#                   Country Name  Combined Suicide Rate  Male Suicide Rate  \
# Country Code
# LBY                      Libya                    5.5                8.7
# LCA                Saint Lucia                    7.3               12.7
# LKA                  Sri Lanka                   14.2               23.3
# LSO                    Lesotho                   28.9               22.7
# LTU                  Lithuania                   25.7               47.5
# LUX                 Luxembourg                   10.4               15.0
# LVA                     Latvia                   17.2               31.0
# MAR                    Morocco                    3.1                2.5
# MDA                    Moldova                   13.4               24.1
# MDG                 Madagascar                    6.9               10.5
# MDV                   Maldives                    2.7                3.6
# MEX                     Mexico                    5.2                8.2
# MKD                  Macedonia                    6.2                9.7
# MLI                       Mali                    8.9               13.5
# MLT                      Malta                    6.5               10.3
# MMR                    Myanmar                    8.1                6.3
# MNE                 Montenegro                    7.9               12.6
# MNG                   Mongolia                   13.3               23.3
# MOZ                 Mozambique                    8.4               14.0
# MRT                 Mauritania                    7.5               12.1
# MUS                  Mauritius                    7.3               12.5
# MWI                     Malawi                    7.8               13.7
# MYS                   Malaysia                    6.2                8.7
# NAM                    Namibia                   11.5               19.4
# NER                      Niger                    9.0               11.5
# NGA                    Nigeria                   17.3               17.5
# NIC                  Nicaragua                   11.9               19.2
# NLD                Netherlands                    9.6               12.9
# NOR                     Norway                   10.1               13.6
# NPL                      Nepal                    9.6               11.4
# NZL                New Zealand                   11.6               17.3
# OMN                       Oman                    3.5                4.8
# PAK                   Pakistan                    3.1                3.0
# PAN                     Panama                    4.4                7.6
# PER                       Peru                    5.1                7.6
# PHL                Philippines                    3.7                5.2
# PNG           Papua New Guinea                    7.0               10.2
# POL                     Poland                   13.4               23.9
# PRK                North Korea                   10.6               14.8
# PRT                   Portugal                    8.6               14.3
#
#               Female Suicide Rate
# Country Code
# LBY                           2.3
# LCA                           2.1
# LKA                           6.2
# LSO                          32.6
# LTU                           6.7
# LUX                           5.8
# LVA                           5.1
# MAR                           3.6
# MDA                           3.8
# MDG                           3.6
# MDV                           1.6
# MEX                           2.3
# MKD                           3.0
# MLI                           4.7
# MLT                           2.8
# MMR                           9.8
# MNE                           3.6
# MNG                           3.8
# MOZ                           4.1
# MRT                           3.6
# MUS                           2.2
# MWI                           3.2
# MYS                           3.6
# NAM                           4.9
# NER                           6.7
# NGA                          17.1
# NIC                           5.0
# NLD                           6.4
# NOR                           6.5
# NPL                           8.0
# NZL                           6.2
# OMN                           0.9
# PAK                           3.1
# PAN                           1.2
# PER                           2.7
# PHL                           2.3
# PNG                           3.8
# POL                           3.4
# PRK                           8.0
# PRT                           3.8

# %%
suicide_rates.shape
# Out:
# (183, 4)

# %% [markdown]
# ##### importing percentage of population living in cities data from WHO API

# %%
r = requests.get('http://apps.who.int/gho/athena/api/GHO/AIR_3/?format=json')
data = r.json()

# %% [markdown]
# ###### Converting JSON data to Python list

# %%
data_dictionary = []
for country in data['fact']:
    for category in country['Dim']:
        if category['category'] == "COUNTRY":
            countrycode = category['code']
    data_dictionary.append({"Country Code": countrycode, "% Living in Cities > 100k": country['value']['numeric']})

# %%
data_dictionary
# Out:
# [{'Country Code': 'AFG', '% Living in Cities > 100k': 15.56},
#  {'Country Code': 'ALB', '% Living in Cities > 100k': 9.34},
#  {'Country Code': 'DZA', '% Living in Cities > 100k': 24.73},
#  {'Country Code': 'AND', '% Living in Cities > 100k': 38.7},
#  {'Country Code': 'AGO', '% Living in Cities > 100k': 19.97},
#  {'Country Code': 'ATG', '% Living in Cities > 100k': 33.07},
#  {'Country Code': 'ARG', '% Living in Cities > 100k': 74.17},
#  {'Country Code': 'ARM', '% Living in Cities > 100k': 53.58},
#  {'Country Code': 'AUS', '% Living in Cities > 100k': 71.69},
#  {'Country Code': 'AUT', '% Living in Cities > 100k': 37.26},
#  {'Country Code': 'AZE', '% Living in Cities > 100k': 23.27},
#  {'Country Code': 'BHS', '% Living in Cities > 100k': 72.28},
#  {'Country Code': 'BHR', '% Living in Cities > 100k': 25.88},
#  {'Country Code': 'BGD', '% Living in Cities > 100k': 8.88},
#  {'Country Code': 'BRB', '% Living in Cities > 100k': 3.94},
#  {'Country Code': 'BLR', '% Living in Cities > 100k': 48.56},
#  {'Country Code': 'BEL', '% Living in Cities > 100k': 34.03},
#  {'Country Code': 'BLZ', '% Living in Cities > 100k': 25.02},
#  {'Country Code': 'BEN', '% Living in Cities > 100k': 19.24},
#  {'Country Code': 'BTN', '% Living in Cities > 100k': 2.62},
#  {'Country Code': 'BOL', '% Living in Cities > 100k': 44.85},
#  {'Country Code': 'BIH', '% Living in Cities > 100k': 37.27},
#  {'Country Code': 'BWA', '% Living in Cities > 100k': 12.73},
#  {'Country Code': 'BRA', '% Living in Cities > 100k': 45.43},
#  {'Country Code': 'BRN', '% Living in Cities > 100k': 29.64},
#  {'Country Code': 'BGR', '% Living in Cities > 100k': 37.05},
#  {'Country Code': 'BFA', '% Living in Cities > 100k': 14.11},
#  {'Country Code': 'BDI', '% Living in Cities > 100k': 7.04},
#  {'Country Code': 'KHM', '% Living in Cities > 100k': 8.41},
#  {'Country Code': 'CMR', '% Living in Cities > 100k': 27.33},
#  {'Country Code': 'CAN', '% Living in Cities > 100k': 79.19},
#  {'Country Code': 'CPV', '% Living in Cities > 100k': 4.99},
#  {'Country Code': 'CAF', '% Living in Cities > 100k': 20.01},
#  {'Country Code': 'TCD', '% Living in Cities > 100k': 18.81},
#  {'Country Code': 'CHL', '% Living in Cities > 100k': 56.6},
#  {'Country Code': 'CHN', '% Living in Cities > 100k': 37.18},
#  {'Country Code': 'COL', '% Living in Cities > 100k': 41.38},
#  {'Country Code': 'COM', '% Living in Cities > 100k': 6.72},
#  {'Country Code': 'COG', '% Living in Cities > 100k': 53.94},
#  {'Country Code': 'CRI', '% Living in Cities > 100k': 46.49},
#  {'Country Code': 'CIV', '% Living in Cities > 100k': 25.83},
#  {'Country Code': 'HRV', '% Living in Cities > 100k': 32.21},
#  {'Country Code': 'CUB', '% Living in Cities > 100k': 39.35},
#  {'Country Code': 'CYP', '% Living in Cities > 100k': 48.04},
#  {'Country Code': 'CZE', '% Living in Cities > 100k': 24.18},
#  {'Country Code': 'PRK', '% Living in Cities > 100k': 31.0},
#  {'Country Code': 'COD', '% Living in Cities > 100k': 22.05},
#  {'Country Code': 'DNK', '% Living in Cities > 100k': 37.64},
#  {'Country Code': 'DJI', '% Living in Cities > 100k': 75.89},
#  {'Country Code': 'DMA', '% Living in Cities > 100k': 22.06},
#  {'Country Code': 'DOM', '% Living in Cities > 100k': 43.27},
#  {'Country Code': 'ECU', '% Living in Cities > 100k': 48.11},
#  {'Country Code': 'EGY', '% Living in Cities > 100k': 31.56},
#  {'Country Code': 'SLV', '% Living in Cities > 100k': 27.46},
#  {'Country Code': 'GNQ', '% Living in Cities > 100k': 25.26},
#  {'Country Code': 'ERI', '% Living in Cities > 100k': 16.43},
#  {'Country Code': 'EST', '% Living in Cities > 100k': 36.79},
#  {'Country Code': 'ETH', '% Living in Cities > 100k': 7.17},
#  {'Country Code': 'FJI', '% Living in Cities > 100k': 25.43},
#  {'Country Code': 'FIN', '% Living in Cities > 100k': 41.51},
#  {'Country Code': 'FRA', '% Living in Cities > 100k': 42.12},
#  {'Country Code': 'GAB', '% Living in Cities > 100k': 44.61},
#  {'Country Code': 'GMB', '% Living in Cities > 100k': 19.1},
#  {'Country Code': 'GEO', '% Living in Cities > 100k': 39.91},
#  {'Country Code': 'DEU', '% Living in Cities > 100k': 32.31},
#  {'Country Code': 'GHA', '% Living in Cities > 100k': 19.54},
#  {'Country Code': 'GRC', '% Living in Cities > 100k': 45.98},
#  {'Country Code': 'GTM', '% Living in Cities > 100k': 23.17},
#  {'Country Code': 'GIN', '% Living in Cities > 100k': 22.22},
#  {'Country Code': 'GNB', '% Living in Cities > 100k': 20.0},
#  {'Country Code': 'GUY', '% Living in Cities > 100k': 28.23},
#  {'Country Code': 'HTI', '% Living in Cities > 100k': 30.85},
#  {'Country Code': 'HND', '% Living in Cities > 100k': 31.18},
#  {'Country Code': 'HUN', '% Living in Cities > 100k': 31.69},
#  {'Country Code': 'ISL', '% Living in Cities > 100k': 58.67},
#  {'Country Code': 'IND', '% Living in Cities > 100k': 18.7},
#  {'Country Code': 'IDN', '% Living in Cities > 100k': 22.14},
#  {'Country Code': 'IRN', '% Living in Cities > 100k': 42.09},
#  {'Country Code': 'IRQ', '% Living in Cities > 100k': 58.38},
#  {'Country Code': 'IRL', '% Living in Cities > 100k': 31.72},
#  {'Country Code': 'ISR', '% Living in Cities > 100k': 79.72},
#  {'Country Code': 'ITA', '% Living in Cities > 100k': 26.62},
#  {'Country Code': 'JAM', '% Living in Cities > 100k': 26.76},
#  {'Country Code': 'JPN', '% Living in Cities > 100k': 63.69},
#  {'Country Code': 'JOR', '% Living in Cities > 100k': 49.0},
#  {'Country Code': 'KAZ', '% Living in Cities > 100k': 43.01},
#  {'Country Code': 'KEN', '% Living in Cities > 100k': 15.76},
#  {'Country Code': 'KWT', '% Living in Cities > 100k': 73.53},
#  {'Country Code': 'KGZ', '% Living in Cities > 100k': 16.14},
#  {'Country Code': 'LAO', '% Living in Cities > 100k': 3.76},
#  {'Country Code': 'LVA', '% Living in Cities > 100k': 41.78},
#  {'Country Code': 'LBN', '% Living in Cities > 100k': 73.76},
#  {'Country Code': 'LSO', '% Living in Cities > 100k': 9.84},
#  {'Country Code': 'LBR', '% Living in Cities > 100k': 16.73},
#  {'Country Code': 'LBY', '% Living in Cities > 100k': 84.84},
#  {'Country Code': 'LTU', '% Living in Cities > 100k': 41.89},
#  {'Country Code': 'LUX', '% Living in Cities > 100k': 18.92},
#  {'Country Code': 'MDG', '% Living in Cities > 100k': 14.63},
#  {'Country Code': 'MWI', '% Living in Cities > 100k': 9.82},
#  {'Country Code': 'MYS', '% Living in Cities > 100k': 27.83},
#  {'Country Code': 'MDV', '% Living in Cities > 100k': 26.55},
#  {'Country Code': 'MLI', '% Living in Cities > 100k': 11.41},
#  {'Country Code': 'MRT', '% Living in Cities > 100k': 33.66},
#  {'Country Code': 'MUS', '% Living in Cities > 100k': 12.09},
#  {'Country Code': 'MEX', '% Living in Cities > 100k': 56.25},
#  {'Country Code': 'MNG', '% Living in Cities > 100k': 28.75},
#  {'Country Code': 'MAR', '% Living in Cities > 100k': 37.19},
#  {'Country Code': 'MOZ', '% Living in Cities > 100k': 25.38},
#  {'Country Code': 'MMR', '% Living in Cities > 100k': 13.86},
#  {'Country Code': 'NAM', '% Living in Cities > 100k': 11.54},
#  {'Country Code': 'NPL', '% Living in Cities > 100k': 4.03},
#  {'Country Code': 'NLD', '% Living in Cities > 100k': 52.46},
#  {'Country Code': 'NZL', '% Living in Cities > 100k': 70.31},
#  {'Country Code': 'NIC', '% Living in Cities > 100k': 25.82},
#  {'Country Code': 'NER', '% Living in Cities > 100k': 10.12},
#  {'Country Code': 'NGA', '% Living in Cities > 100k': 27.43},
#  {'Country Code': 'NOR', '% Living in Cities > 100k': 33.44},
#  {'Country Code': 'OMN', '% Living in Cities > 100k': 36.28},
#  {'Country Code': 'PAK', '% Living in Cities > 100k': 27.47},
#  {'Country Code': 'PAN', '% Living in Cities > 100k': 29.47},
#  {'Country Code': 'PNG', '% Living in Cities > 100k': 5.6},
#  {'Country Code': 'PRY', '% Living in Cities > 100k': 24.69},
#  {'Country Code': 'PER', '% Living in Cities > 100k': 52.5},
#  {'Country Code': 'PHL', '% Living in Cities > 100k': 40.96},
#  {'Country Code': 'POL', '% Living in Cities > 100k': 31.54},
#  {'Country Code': 'PRT', '% Living in Cities > 100k': 55.51},
#  {'Country Code': 'QAT', '% Living in Cities > 100k': 64.8},
#  {'Country Code': 'KOR', '% Living in Cities > 100k': 73.65},
#  {'Country Code': 'MDA', '% Living in Cities > 100k': 26.91},
#  {'Country Code': 'ROU', '% Living in Cities > 100k': 32.52},
#  {'Country Code': 'RUS', '% Living in Cities > 100k': 47.87},
#  {'Country Code': 'RWA', '% Living in Cities > 100k': 6.46},
#  {'Country Code': 'KNA', '% Living in Cities > 100k': 28.66},
#  {'Country Code': 'VCT', '% Living in Cities > 100k': 18.59},
#  {'Country Code': 'STP', '% Living in Cities > 100k': 27.04},
#  {'Country Code': 'SAU', '% Living in Cities > 100k': 40.3},
#  {'Country Code': 'SEN', '% Living in Cities > 100k': 28.65},
#  {'Country Code': 'SLE', '% Living in Cities > 100k': 20.03},
#  {'Country Code': 'SGP', '% Living in Cities > 100k': 78.73},
#  {'Country Code': 'SVK', '% Living in Cities > 100k': 17.12},
#  {'Country Code': 'SVN', '% Living in Cities > 100k': 21.16},
#  {'Country Code': 'SOM', '% Living in Cities > 100k': 20.06},
#  {'Country Code': 'ZAF', '% Living in Cities > 100k': 42.82},
#  {'Country Code': 'ESP', '% Living in Cities > 100k': 41.57},
#  {'Country Code': 'LKA', '% Living in Cities > 100k': 8.35},
#  {'Country Code': 'SDN', '% Living in Cities > 100k': 17.49},
#  {'Country Code': 'SUR', '% Living in Cities > 100k': 55.03},
#  {'Country Code': 'SWZ', '% Living in Cities > 100k': 7.38},
#  {'Country Code': 'SWE', '% Living in Cities > 100k': 29.85},
#  {'Country Code': 'CHE', '% Living in Cities > 100k': 42.3},
#  {'Country Code': 'SYR', '% Living in Cities > 100k': 37.51},
#  {'Country Code': 'TJK', '% Living in Cities > 100k': 11.0},
#  {'Country Code': 'THA', '% Living in Cities > 100k': 16.14},
#  {'Country Code': 'MKD', '% Living in Cities > 100k': 28.53},
#  {'Country Code': 'TGO', '% Living in Cities > 100k': 16.14},
#  {'Country Code': 'TTO', '% Living in Cities > 100k': 4.13},
#  {'Country Code': 'TUN', '% Living in Cities > 100k': 29.97},
#  {'Country Code': 'TUR', '% Living in Cities > 100k': 60.51},
#  {'Country Code': 'TKM', '% Living in Cities > 100k': 18.5},
#  {'Country Code': 'UGA', '% Living in Cities > 100k': 5.01},
#  {'Country Code': 'UKR', '% Living in Cities > 100k': 41.55},
#  {'Country Code': 'ARE', '% Living in Cities > 100k': 70.03},
#  {'Country Code': 'GBR', '% Living in Cities > 100k': 52.9},
#  {'Country Code': 'TZA', '% Living in Cities > 100k': 20.54},
#  {'Country Code': 'USA', '% Living in Cities > 100k': 72.4},
#  {'Country Code': 'URY', '% Living in Cities > 100k': 44.4},
#  {'Country Code': 'UZB', '% Living in Cities > 100k': 20.54},
#  {'Country Code': 'VUT', '% Living in Cities > 100k': 14.17},
#  {'Country Code': 'VEN', '% Living in Cities > 100k': 61.58},
#  {'Country Code': 'VNM', '% Living in Cities > 100k': 20.59},
#  {'Country Code': 'YEM', '% Living in Cities > 100k': 15.1},
#  {'Country Code': 'ZMB', '% Living in Cities > 100k': 29.35},
#  {'Country Code': 'ZWE', '% Living in Cities > 100k': 25.85}]

# %% [markdown]
# ###### Converting info to Pandas DataFrame

# %%
percent_living_in_cities = pd.DataFrame(data_dictionary)
percent_living_in_cities.set_index(['Country Code'], inplace=True)

# %% [markdown]
# ###### Combining with suicide stats DataFrame and Changing NaN values to Median

# %%
suicide_rates = suicide_rates.join(percent_living_in_cities, on=['Country Code'], how='left')

# %%
suicide_rates['% Living in Cities > 100k'].fillna(suicide_rates['% Living in Cities > 100k'].median(), inplace=True)
suicide_rates.isna().sum()
# Out:
# Country Name                 0
# Combined Suicide Rate        0
# Male Suicide Rate            0
# Female Suicide Rate          0
# % Living in Cities > 100k    0
# dtype: int64

# %% [markdown]
# ###### Scraping Internet Data from CIA World Fact Book using BeautifulSoup

# %%
from bs4 import BeautifulSoup
r = requests.get('https://www.cia.gov/library/publications/the-world-factbook/fields/204.html#AF')
c = r.content
soup = BeautifulSoup(c)
# Out:
# /Users/briansrebrenik/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/briansrebrenik/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
data = soup.findAll('tr')[1:]

# %% [markdown]
# ##### Scraping country names and internet connectivity info

# %%
data_dictionary = []
for country in data:
    try:
        country_name = country.findAll('td', {'class': 'country'})[0].text
        country_name_formatted = country_name.replace('\n', "")
        internet_percentage = country.findAll('span', {'class': 'subfield-number'})[1].text
        internet_percentage_formatted = float(internet_percentage.replace("%", ""))
        data_dictionary.append({'country': country_name_formatted, "percentage of population with internet access": internet_percentage_formatted})
    except:
        pass

# %% [markdown]
# ##### Converting to Pandas DataFrame

# %%
internet_stats_df = pd.DataFrame.from_dict(data_dictionary)

# %%
internet_stats_df.columns= ['Country Name', "% of Population with Internet Access"]
internet_stats_df.set_index(['Country Name'], inplace=True)

# %%
internet_stats_df.shape
internet_stats_df[178:192]
# Out:
#                        % of Population with Internet Access
# Country Name
# San Marino                                             52.6
# Sao Tome and Principe                                  25.8
# Saudi Arabia                                           73.8
# Senegal                                                25.7
# Serbia                                                 67.1
# Seychelles                                             56.5
# Sierra Leone                                           11.8
# Singapore                                              81.0
# Slovakia                                               80.5
# Slovenia                                               75.5
# Solomon Islands                                        11.0
# Somalia                                                 1.9
# South Africa                                           54.0
# Spain                                                  80.6

# %% [markdown]
# ##### Combining with other data collected

# %%
suicide_rates = suicide_rates.join(internet_stats_df, on=['Country Name'], how='inner')

# %%
suicide_rates.sort_values(by = "Country Name", ascending = False)
suicide_rates.shape
# Out:
# (167, 6)

# %% [markdown]
# ###### Scraping Religous stats

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
r = requests.get('https://rationalwiki.org/wiki/Importance_of_religion_by_country')
c = r.content
soup = BeautifulSoup(c)
# Out:
# /Users/briansrebrenik/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/briansrebrenik/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
data = soup.findAll('table', {'class': 'wikitable'})
data = data[0].findAll('td')

# %%
religous_stats = []
for i in range(len(data)):
    if i == 0 or i % 3 == 0:
        country = data[i].text.strip()
    elif i in list(range(1, len(data), 3)):
        percentage_religious = float(data[i].text.replace("%", ""))
        religous_stats.append({'Country Name': country, "% Religious": percentage_religious})

# %%
religious_df = pd.DataFrame.from_dict(religous_stats)
religious_df.set_index(['Country Name'], inplace=True)
suicide_rates.set_index(['Country Name'], inplace=True)

# %%
suicide_rates.head()
religious_df.head()
# Out:
#                 % Religious
# Country Name
# Estonia                16.0
# Sweden                 16.5
# Denmark                18.0
# Czech Republic         20.5
# Norway                 20.5

# %% [markdown]
# ###### Combine with rest of data

# %%
suicide_rates = suicide_rates.join(religious_df)

# %%
suicide_rates.sort_values(by = "Country Name", ascending = False)
suicide_rates.head()
# Out:
#                       Combined Suicide Rate  Male Suicide Rate  \
# Country Name
# Afghanistan                             6.4               10.6
# Angola                                  8.9               14.0
# Albania                                 5.6                7.0
# United Arab Emirates                    2.7                3.5
# Argentina                               9.1               15.0
#
#                       Female Suicide Rate  % Living in Cities > 100k  \
# Country Name
# Afghanistan                           2.1                      15.56
# Angola                                4.6                      19.97
# Albania                               4.3                       9.34
# United Arab Emirates                  0.8                      70.03
# Argentina                             3.5                      74.17
#
#                       % of Population with Internet Access  % Religious
# Country Name
# Afghanistan                                           10.6         97.0
# Angola                                                13.0         88.0
# Albania                                               66.4         32.5
# United Arab Emirates                                  90.6         91.0
# Argentina                                             70.2         66.0

# %% [markdown]
# ##### Getting Economic and Health Data

# %%
gdp_url = "https://www.cia.gov/library/publications/the-world-factbook/rankorder/rawdata_2004.txt"
unemp_url = "https://www.cia.gov/library/publications/the-world-factbook/rankorder/rawdata_2129.txt"

import urllib  # the lib that handles the url stuff
import json
import pandas as pd
import numpy as np
from xml.dom import minidom
from urllib.request import urlopen
import matplotlib.pyplot as plt
# %matplotlib inline


GDP = pd.read_fwf('gdp_perca.txt', header = None, names = ['country', 'GDP']).astype(str)
Unemp = pd.read_fwf('unemp.txt', header = None, names = ['Unem_rate'])
mental = pd.read_csv('mental_disorder_substance_use.csv')
healthcare = pd.read_excel('NHA.xlsx')

      
index_list = [item[1] for item in Unemp.index]
Unemp.index = index_list
Unemp.head()

gdp = GDP.set_index('country')
health = healthcare[["Countries", '2016']]
nha = health.drop([0], axis = 0)

# %% [markdown]
# ##### Cleaning data and putting it in Data Frame

# %%
mental1 = mental[mental.Year == 2016]
mental1.dropna(axis = 0, inplace = True)
men_copy = mental1.set_index('Entity')
# Out:
# /Users/briansrebrenik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ##### Mergin Tables and cleaning new data

# %%
merged = men_copy.join(Unemp)
merged.drop('Year', axis = 1, inplace = True)
merged = merged.join(gdp)
merged.dropna(inplace = True)

#GDP per capita
gdps = [item.split(",") for item in merged.GDP]

def clean_gdp(data):
    empty = []
    for item in data:
        first = item[0].split("$")[1]
        second = item[1]
        total = int(first+second)
        empty.append(total)
    return empty

merged.GDP = clean_gdp(gdps)
merged.sort_values(by = "Entity", ascending = False)
merged[merged.Code == "RUS"]

#Health spending per capita
health = nha.set_index('Countries')
health.rename(columns = {'2016': 'health_spend_perca'}, inplace = True)


new = merged.join(health)
new.loc["Russia", 'health_spend_perca'] = 1414.12
new[new.index == "Russia"]
new.loc["United States", 'health_spend_perca'] = 9869.74
len(new)
final = new.dropna()

# %%
suicide_rates.head()
# Out:
#                       Combined Suicide Rate  Male Suicide Rate  \
# Country Name
# Afghanistan                             6.4               10.6
# Angola                                  8.9               14.0
# Albania                                 5.6                7.0
# United Arab Emirates                    2.7                3.5
# Argentina                               9.1               15.0
#
#                       Female Suicide Rate  % Living in Cities > 100k  \
# Country Name
# Afghanistan                           2.1                      15.56
# Angola                                4.6                      19.97
# Albania                               4.3                       9.34
# United Arab Emirates                  0.8                      70.03
# Argentina                             3.5                      74.17
#
#                       % of Population with Internet Access  % Religious
# Country Name
# Afghanistan                                           10.6         97.0
# Angola                                                13.0         88.0
# Albania                                               66.4         32.5
# United Arab Emirates                                  90.6         91.0
# Argentina                                             70.2         66.0

# %% [markdown]
# ##### Mergin FInal Two Tables

# %%
final_table = final.join(suicide_rates)
final_table.head()
final_table.dropna(subset = ['Combined Suicide Rate'], inplace = True)
final_table['% Religious'].fillna(50, inplace = True)
final_table.head()
# Out:
#                     Code  Schizophrenia (%)  Bipolar disorder (%)  \
# Entity
# Afghanistan          AFG           0.159494              0.760363
# Albania              ALB           0.231592              0.667222
# Algeria              DZA           0.199488              0.868839
# Angola               AGO           0.198776              0.623446
# Antigua and Barbuda  ATG           0.210017              0.930308
#
#                      Eating disorders (%)  Anxiety disorders (%)  \
# Entity
# Afghanistan                      0.088103               5.023055
# Albania                          0.113824               3.557997
# Algeria                          0.181441               5.249815
# Angola                           0.113965               3.272275
# Antigua and Barbuda              0.210369               4.316763
#
#                      Drug use disorders (%)  Depression (%)  \
# Entity
# Afghanistan                        1.196912        4.404727
# Albania                            0.655556        2.450883
# Algeria                            0.880553        3.946200
# Angola                             0.467204        4.715467
# Antigua and Barbuda                0.719728        3.128054
#
#                      Alcohol use disorders (%)  Unem_rate    GDP  \
# Entity
# Afghanistan                           0.612712       23.9   2000
# Albania                               1.669982       14.0  12500
# Algeria                               0.605362       11.7  15200
# Angola                                1.456741        6.6   6800
# Antigua and Barbuda                   1.947655       11.0  26300
#
#                     health_spend_perca  Combined Suicide Rate  \
# Entity
# Afghanistan                    57.2488                6.40000
# Albania                        271.543                5.60000
# Algeria                        260.413                3.30000
# Angola                         95.2208                8.90000
# Antigua and Barbuda            623.115                4.30386
#
#                      Male Suicide Rate  Female Suicide Rate  \
# Entity
# Afghanistan                       10.6                  2.1
# Albania                            7.0                  4.3
# Algeria                            4.9                  1.8
# Angola                            14.0                  4.6
# Antigua and Barbuda                0.0                  0.9
#
#                      % Living in Cities > 100k  \
# Entity
# Afghanistan                              15.56
# Albania                                   9.34
# Algeria                                  24.73
# Angola                                   19.97
# Antigua and Barbuda                      33.07
#
#                      % of Population with Internet Access  % Religious
# Entity
# Afghanistan                                          10.6         97.0
# Albania                                              66.4         32.5
# Algeria                                              42.9         93.0
# Angola                                               13.0         88.0
# Antigua and Barbuda                                  65.2         50.0

# %%
final_table.loc[final_table["% Religious"] > 33, "Religious"] = "Medium"
final_table.loc[final_table["% Religious"] >= 66, "Religious"] = "High"
final_table.loc[final_table["% Religious"] <= 33, "Religious"] = "Low"

# %%
final_table.head()
# Out:
#                     Code  Schizophrenia (%)  Bipolar disorder (%)  \
# Entity
# Afghanistan          AFG           0.159494              0.760363
# Albania              ALB           0.231592              0.667222
# Algeria              DZA           0.199488              0.868839
# Angola               AGO           0.198776              0.623446
# Antigua and Barbuda  ATG           0.210017              0.930308
#
#                      Eating disorders (%)  Anxiety disorders (%)  \
# Entity
# Afghanistan                      0.088103               5.023055
# Albania                          0.113824               3.557997
# Algeria                          0.181441               5.249815
# Angola                           0.113965               3.272275
# Antigua and Barbuda              0.210369               4.316763
#
#                      Drug use disorders (%)  Depression (%)  \
# Entity
# Afghanistan                        1.196912        4.404727
# Albania                            0.655556        2.450883
# Algeria                            0.880553        3.946200
# Angola                             0.467204        4.715467
# Antigua and Barbuda                0.719728        3.128054
#
#                      Alcohol use disorders (%)  Unem_rate    GDP  \
# Entity
# Afghanistan                           0.612712       23.9   2000
# Albania                               1.669982       14.0  12500
# Algeria                               0.605362       11.7  15200
# Angola                                1.456741        6.6   6800
# Antigua and Barbuda                   1.947655       11.0  26300
#
#                     health_spend_perca  Combined Suicide Rate  \
# Entity
# Afghanistan                    57.2488                6.40000
# Albania                        271.543                5.60000
# Algeria                        260.413                3.30000
# Angola                         95.2208                8.90000
# Antigua and Barbuda            623.115                4.30386
#
#                      Male Suicide Rate  Female Suicide Rate  \
# Entity
# Afghanistan                       10.6                  2.1
# Albania                            7.0                  4.3
# Algeria                            4.9                  1.8
# Angola                            14.0                  4.6
# Antigua and Barbuda                0.0                  0.9
#
#                      % Living in Cities > 100k  \
# Entity
# Afghanistan                              15.56
# Albania                                   9.34
# Algeria                                  24.73
# Angola                                   19.97
# Antigua and Barbuda                      33.07
#
#                      % of Population with Internet Access  % Religious  \
# Entity
# Afghanistan                                          10.6         97.0
# Albania                                              66.4         32.5
# Algeria                                              42.9         93.0
# Angola                                               13.0         88.0
# Antigua and Barbuda                                  65.2         50.0
#
#                     Religious
# Entity
# Afghanistan              High
# Albania                   Low
# Algeria                  High
# Angola                   High
# Antigua and Barbuda    Medium

# %% [markdown]
# ##### Checking for Multicolinearity and removing excess features

# %%
abs(final_table.corr()) > 0.75
# Out:
#                                       Schizophrenia (%)  Bipolar disorder (%)  \
# Schizophrenia (%)                                  True                 False
# Bipolar disorder (%)                              False                  True
# Eating disorders (%)                              False                  True
# Anxiety disorders (%)                             False                  True
# Drug use disorders (%)                            False                 False
# Depression (%)                                    False                 False
# Alcohol use disorders (%)                         False                 False
# Unem_rate                                         False                 False
# GDP                                               False                 False
# Combined Suicide Rate                             False                 False
# Male Suicide Rate                                 False                 False
# Female Suicide Rate                               False                 False
# % Living in Cities > 100k                         False                 False
# % of Population with Internet Access              False                 False
# % Religious                                       False                 False
#
#                                       Eating disorders (%)  \
# Schizophrenia (%)                                    False
# Bipolar disorder (%)                                  True
# Eating disorders (%)                                  True
# Anxiety disorders (%)                                False
# Drug use disorders (%)                               False
# Depression (%)                                       False
# Alcohol use disorders (%)                            False
# Unem_rate                                            False
# GDP                                                   True
# Combined Suicide Rate                                False
# Male Suicide Rate                                    False
# Female Suicide Rate                                  False
# % Living in Cities > 100k                            False
# % of Population with Internet Access                 False
# % Religious                                          False
#
#                                       Anxiety disorders (%)  \
# Schizophrenia (%)                                     False
# Bipolar disorder (%)                                   True
# Eating disorders (%)                                  False
# Anxiety disorders (%)                                  True
# Drug use disorders (%)                                False
# Depression (%)                                        False
# Alcohol use disorders (%)                             False
# Unem_rate                                             False
# GDP                                                   False
# Combined Suicide Rate                                 False
# Male Suicide Rate                                     False
# Female Suicide Rate                                   False
# % Living in Cities > 100k                             False
# % of Population with Internet Access                  False
# % Religious                                           False
#
#                                       Drug use disorders (%)  Depression (%)  \
# Schizophrenia (%)                                      False           False
# Bipolar disorder (%)                                   False           False
# Eating disorders (%)                                   False           False
# Anxiety disorders (%)                                  False           False
# Drug use disorders (%)                                  True           False
# Depression (%)                                         False            True
# Alcohol use disorders (%)                              False           False
# Unem_rate                                              False           False
# GDP                                                    False           False
# Combined Suicide Rate                                  False           False
# Male Suicide Rate                                      False           False
# Female Suicide Rate                                    False           False
# % Living in Cities > 100k                              False           False
# % of Population with Internet Access                   False           False
# % Religious                                            False           False
#
#                                       Alcohol use disorders (%)  Unem_rate  \
# Schizophrenia (%)                                         False      False
# Bipolar disorder (%)                                      False      False
# Eating disorders (%)                                      False      False
# Anxiety disorders (%)                                     False      False
# Drug use disorders (%)                                    False      False
# Depression (%)                                            False      False
# Alcohol use disorders (%)                                  True      False
# Unem_rate                                                 False       True
# GDP                                                       False      False
# Combined Suicide Rate                                     False      False
# Male Suicide Rate                                         False      False
# Female Suicide Rate                                       False      False
# % Living in Cities > 100k                                 False      False
# % of Population with Internet Access                      False      False
# % Religious                                               False      False
#
#                                         GDP  Combined Suicide Rate  \
# Schizophrenia (%)                     False                  False
# Bipolar disorder (%)                  False                  False
# Eating disorders (%)                   True                  False
# Anxiety disorders (%)                 False                  False
# Drug use disorders (%)                False                  False
# Depression (%)                        False                  False
# Alcohol use disorders (%)             False                  False
# Unem_rate                             False                  False
# GDP                                    True                  False
# Combined Suicide Rate                 False                   True
# Male Suicide Rate                     False                   True
# Female Suicide Rate                   False                   True
# % Living in Cities > 100k             False                  False
# % of Population with Internet Access   True                  False
# % Religious                           False                  False
#
#                                       Male Suicide Rate  Female Suicide Rate  \
# Schizophrenia (%)                                 False                False
# Bipolar disorder (%)                              False                False
# Eating disorders (%)                              False                False
# Anxiety disorders (%)                             False                False
# Drug use disorders (%)                            False                False
# Depression (%)                                    False                False
# Alcohol use disorders (%)                         False                False
# Unem_rate                                         False                False
# GDP                                               False                False
# Combined Suicide Rate                              True                 True
# Male Suicide Rate                                  True                False
# Female Suicide Rate                               False                 True
# % Living in Cities > 100k                         False                False
# % of Population with Internet Access              False                False
# % Religious                                       False                False
#
#                                       % Living in Cities > 100k  \
# Schizophrenia (%)                                         False
# Bipolar disorder (%)                                      False
# Eating disorders (%)                                      False
# Anxiety disorders (%)                                     False
# Drug use disorders (%)                                    False
# Depression (%)                                            False
# Alcohol use disorders (%)                                 False
# Unem_rate                                                 False
# GDP                                                       False
# Combined Suicide Rate                                     False
# Male Suicide Rate                                         False
# Female Suicide Rate                                       False
# % Living in Cities > 100k                                  True
# % of Population with Internet Access                      False
# % Religious                                               False
#
#                                       % of Population with Internet Access  \
# Schizophrenia (%)                                                    False
# Bipolar disorder (%)                                                 False
# Eating disorders (%)                                                 False
# Anxiety disorders (%)                                                False
# Drug use disorders (%)                                               False
# Depression (%)                                                       False
# Alcohol use disorders (%)                                            False
# Unem_rate                                                            False
# GDP                                                                   True
# Combined Suicide Rate                                                False
# Male Suicide Rate                                                    False
# Female Suicide Rate                                                  False
# % Living in Cities > 100k                                            False
# % of Population with Internet Access                                  True
# % Religious                                                          False
#
#                                       % Religious
# Schizophrenia (%)                           False
# Bipolar disorder (%)                        False
# Eating disorders (%)                        False
# Anxiety disorders (%)                       False
# Drug use disorders (%)                      False
# Depression (%)                              False
# Alcohol use disorders (%)                   False
# Unem_rate                                   False
# GDP                                         False
# Combined Suicide Rate                       False
# Male Suicide Rate                           False
# Female Suicide Rate                         False
# % Living in Cities > 100k                   False
# % of Population with Internet Access        False
# % Religious                                  True

# %%
import seaborn as sns
sns.heatmap(final_table.corr(), center = 0)

# %% [markdown]
# ##### Drop "Bipoar Disorder" since it has corelation with 3 other variables.

# %%
final_table.drop("Bipolar disorder (%)", axis = 1, inplace = True)

# %% [markdown]
# ##### Clean up Some Column Names with too many signs and letters

# %%
final_table.rename(columns = {'Schizophrenia (%)': 'Schizophrenia'}, inplace = True)
final_table.rename(columns = {'Eating disorders (%)': 'Eating disorders'}, inplace = True)
final_table.rename(columns = {'Anxiety disorders (%)': 'Anxiety'}, inplace = True)
final_table.rename(columns = {'Drug use disorders (%)': 'Drug use'}, inplace = True)
final_table.rename(columns = {'Depression (%)': 'Depression'}, inplace = True)
final_table.rename(columns = {'Alcohol use disorders (%)': 'Alcohol use'}, inplace = True)

# %%
final_table
# Out:
#                        Code  Schizophrenia  Eating disorders   Anxiety  \
# Entity
# Afghanistan             AFG       0.159494          0.088103  5.023055
# Albania                 ALB       0.231592          0.113824  3.557997
# Algeria                 DZA       0.199488          0.181441  5.249815
# Angola                  AGO       0.198776          0.113965  3.272275
# Antigua and Barbuda     ATG       0.210017          0.210369  4.316763
# Argentina               ARG       0.206245          0.256648  6.368157
# Armenia                 ARM       0.221530          0.102840  2.762138
# Australia               AUS       0.373657          0.399329  6.607629
# Austria                 AUT       0.267903          0.531239  5.436622
# Azerbaijan              AZE       0.222934          0.124382  2.709179
# Bahrain                 BHR       0.208877          0.224310  4.813715
# Bangladesh              BGD       0.248877          0.086825  4.050596
# Barbados                BRB       0.231797          0.188412  4.317797
# Belarus                 BLR       0.214092          0.128906  2.975138
# Belgium                 BEL       0.270838          0.449202  5.358790
# Belize                  BLZ       0.197980          0.152740  4.251719
# Benin                   BEN       0.193936          0.075697  2.984719
# Bhutan                  BTN       0.260368          0.110452  3.766302
# Bosnia and Herzegovina  BIH       0.229122          0.107311  3.517572
# Botswana                BWA       0.205610          0.146186  3.602351
# Brazil                  BRA       0.211822          0.175387  6.139371
# Bulgaria                BGR       0.230454          0.127218  3.583943
# Burkina Faso            BFA       0.187297          0.070816  2.979538
# Cambodia                KHM       0.256246          0.074855  3.619646
# Cameroon                CMR       0.193407          0.085383  2.981661
# Canada                  CAN       0.332430          0.312063  5.549322
# Chile                   CHL       0.207539          0.256556  6.298440
# China                   CHN       0.451516          0.110938  3.195014
# Colombia                COL       0.211211          0.190575  2.575168
# Comoros                 COM       0.191525          0.069723  3.343035
# ...                     ...            ...               ...       ...
# Seychelles              SYC       0.292149          0.137201  3.555511
# Sierra Leone            SLE       0.189806          0.071189  2.977348
# Singapore               SGP       0.289308          0.344712  3.882426
# Slovakia                SVK       0.238319          0.149718  3.584652
# Slovenia                SVN       0.241746          0.154983  3.583973
# South Africa            ZAF       0.204531          0.135467  3.822722
# Spain                   ESP       0.295102          0.531810  5.602684
# Sri Lanka               LKA       0.289891          0.109666  3.687049
# Sudan                   SDN       0.175956          0.120337  5.091275
# Suriname                SUR       0.191568          0.182996  4.235133
# Sweden                  SWE       0.300906          0.440876  5.394455
# Switzerland             CHE       0.269762          0.461646  5.393056
# Tajikistan              TJK       0.204282          0.070605  2.657115
# Thailand                THA       0.289404          0.121607  3.648231
# Togo                    TGO       0.187566          0.068750  2.986726
# Tonga                   TON       0.312506          0.083923  3.531923
# Trinidad and Tobago     TTO       0.178289          0.228991  4.269200
# Tunisia                 TUN       0.199457          0.169400  5.273351
# Turkey                  TUR       0.203444          0.263491  4.553063
# Turkmenistan            TKM       0.219432          0.123068  2.726863
# Uganda                  UGA       0.182129          0.074651  3.221900
# Ukraine                 UKR       0.207141          0.103994  2.977524
# United Arab Emirates    ARE       0.215753          0.212661  4.420720
# United Kingdom          GBR       0.273478          0.406572  5.008141
# United States           USA       0.336158          0.369417  6.081070
# Uruguay                 URY       0.208505          0.254502  6.431614
# Uzbekistan              UZB       0.209652          0.091154  2.691824
# Vanuatu                 VUT       0.290606          0.070606  3.435329
# Zambia                  ZMB       0.187785          0.092035  3.350081
# Zimbabwe                ZWE       0.178645          0.077739  3.388782
#
#                         Drug use  Depression  Alcohol use  Unem_rate    GDP  \
# Entity
# Afghanistan             1.196912    4.404727     0.612712       23.9   2000
# Albania                 0.655556    2.450883     1.669982       14.0  12500
# Algeria                 0.880553    3.946200     0.605362       11.7  15200
# Angola                  0.467204    4.715467     1.456741        6.6   6800
# Antigua and Barbuda     0.719728    3.128054     1.947655       11.0  26300
# Argentina               1.322192    3.839975     1.796492        8.1  20900
# Armenia                 0.705029    3.068547     1.660420       18.9   9500
# Australia               2.406347    4.949714     1.397416        5.6  50300
# Austria                 1.001242    3.482648     1.827873        5.5  49900
# Azerbaijan              0.734581    2.854446     2.521425        6.0  17500
# Bahrain                 0.939098    4.159016     0.676549        3.8  48500
# Bangladesh              0.555565    4.439595     1.476278        4.0   4200
# Barbados                0.747603    3.324264     1.495446       10.5  18700
# Belarus                 0.976719    4.396417     4.126128        1.0  18900
# Belgium                 0.924855    4.469740     1.359563        7.3  46600
# Belize                  0.773577    3.398175     1.714838       10.1   8300
# Benin                   0.454059    4.163982     1.216588        1.0   2300
# Bhutan                  0.593925    3.720666     2.435247        3.2   8700
# Bosnia and Herzegovina  0.648991    2.564634     2.877315       20.5  12700
# Botswana                0.720993    4.402208     1.657688       20.0  17800
# Brazil                  0.976055    3.724393     2.754555       11.8  15600
# Bulgaria                0.721514    2.794418     1.665605        6.2  21700
# Burkina Faso            0.402001    4.213618     1.218398       77.0   1900
# Cambodia                0.745344    3.381689     0.848614        0.3   4000
# Cameroon                0.493422    4.319253     1.309680        4.3   3700
# Canada                  2.206116    3.998307     1.588419        6.5  48300
# Chile                   1.101855    4.219770     2.359608        7.0  24500
# China                   0.867693    3.680339     1.090205        3.9  16700
# Colombia                0.635882    2.378241     1.736956       10.5  14500
# Comoros                 0.463101    3.723400     1.459323        6.5   1600
# ...                          ...         ...          ...        ...    ...
# Seychelles              0.946771    3.074741     0.826445        4.1  28900
# Sierra Leone            0.445272    4.175993     1.184161        9.1   1600
# Singapore               1.050719    3.707904     0.479380        2.2  93900
# Slovakia                0.719156    2.647707     2.273115        8.1  33000
# Slovenia                0.819709    3.201502     2.068468        6.6  34400
# South Africa            0.660525    4.155648     1.508589       27.6  13500
# Spain                   1.362867    3.792970     0.907822       17.1  38300
# Sri Lanka               0.752341    3.641974     0.797424        4.5  12800
# Sudan                   0.814619    4.102929     0.596162       19.6   4600
# Suriname                0.677717    4.770261     1.664526        9.1  14600
# Sweden                  0.869224    4.966165     1.597182        6.6  51500
# Switzerland             1.093848    3.873037     1.302338        3.0  61400
# Tajikistan              0.707705    2.846063     1.875610        2.4   3200
# Thailand                0.905808    3.382812     0.835700        0.7  17900
# Togo                    0.461290    4.190313     1.199030        6.9   1700
# Tonga                   0.721567    3.200897     0.851819        1.1   5600
# Trinidad and Tobago     0.728085    3.926059     1.599344        4.5  31400
# Tunisia                 0.872277    4.211188     0.594131       15.9  11800
# Turkey                  0.831571    3.888138     0.893527       11.2  26900
# Turkmenistan            0.701932    3.134172     2.030835       11.0  18100
# Uganda                  0.468800    5.616770     1.254208        9.4   2400
# Ukraine                 0.902183    4.515834     4.199587        9.5   8700
# United Arab Emirates    1.062674    3.128079     0.688411        1.6  67700
# United Kingdom          1.479885    4.343298     1.419088        4.4  44100
# United States           3.314164    5.171768     2.153914        4.4  59500
# Uruguay                 1.055214    3.859131     1.006075        7.3  22400
# Uzbekistan              0.665748    3.176225     1.653140        4.9   6900
# Vanuatu                 0.696777    3.409264     0.880641        1.7   2700
# Zambia                  0.468239    4.163807     1.675675       15.0   4000
# Zimbabwe                0.652979    3.599630     1.667406       11.3   2300
#
#                        health_spend_perca  Combined Suicide Rate  \
# Entity
# Afghanistan                       57.2488                6.40000
# Albania                           271.543                5.60000
# Algeria                           260.413                3.30000
# Angola                            95.2208                8.90000
# Antigua and Barbuda               623.115                4.30386
# Argentina                         955.201                9.10000
# Armenia                           358.842                5.70000
# Australia                         5002.36               11.70000
# Austria                           4688.28               11.40000
# Azerbaijan                        268.156                2.60000
# Bahrain                           1099.36                5.70000
# Bangladesh                         34.218                6.10000
# Barbados                          1163.84                0.40000
# Belarus                           317.994               21.40000
# Belgium                           4149.39               15.70000
# Belize                            303.605                5.90000
# Benin                             30.4015               15.70000
# Bhutan                            91.3353               11.60000
# Bosnia and Herzegovina            443.784                6.40000
# Botswana                          379.923               11.50000
# Brazil                            1015.93                6.10000
# Bulgaria                          612.479                7.90000
# Burkina Faso                       40.941               14.80000
# Cambodia                          77.6737                5.90000
# Cameroon                          64.4673               19.50000
# Canada                            4458.21               10.40000
# Chile                             1190.55                9.70000
# China                             398.332                8.00000
# Colombia                          340.365                7.00000
# Comoros                           59.0004               11.10000
# ...                                   ...                    ...
# Seychelles                        596.923                8.30000
# Sierra Leone                      86.3082               16.10000
# Singapore                         2462.39                7.90000
# Slovakia                          1178.74               10.10000
# Slovenia                          1834.16               13.30000
# South Africa                      428.176               12.80000
# Spain                             2389.89                6.10000
# Sri Lanka                         153.097               14.20000
# Sudan                             152.022                9.50000
# Suriname                          356.051               23.20000
# Sweden                            5710.59               11.70000
# Switzerland                       9835.96               11.30000
# Tajikistan                         55.697                3.30000
# Thailand                          221.918               12.90000
# Togo                              38.7714               16.60000
# Tonga                             279.893                4.00000
# Trinidad and Tobago               1063.83               12.90000
# Tunisia                           256.502                3.20000
# Turkey                            468.647                7.20000
# Turkmenistan                      422.849                7.20000
# Uganda                             37.607               20.00000
# Ukraine                           141.826               18.50000
# United Arab Emirates              1323.12                2.70000
# United Kingdom                    3958.02                7.60000
# United States                     9869.74               13.70000
# Uruguay                            1379.1               16.50000
# Uzbekistan                        135.111                7.40000
# Vanuatu                           109.814                5.40000
# Zambia                            56.5442                8.44795
# Zimbabwe                          93.9422               19.10000
#
#                         Male Suicide Rate  Female Suicide Rate  \
# Entity
# Afghanistan                          10.6                  2.1
# Albania                               7.0                  4.3
# Algeria                               4.9                  1.8
# Angola                               14.0                  4.6
# Antigua and Barbuda                   0.0                  0.9
# Argentina                            15.0                  3.5
# Armenia                              10.1                  2.0
# Australia                            17.4                  6.0
# Austria                              17.5                  5.7
# Azerbaijan                            4.3                  1.0
# Bahrain                               7.9                  2.1
# Bangladesh                            5.5                  6.7
# Barbados                              0.8                  0.3
# Belarus                              39.3                  6.2
# Belgium                              22.2                  9.4
# Belize                                9.9                  2.0
# Benin                                22.6                  9.6
# Bhutan                               13.8                  8.9
# Bosnia and Herzegovina               10.6                  2.5
# Botswana                             18.3                  5.7
# Brazil                                9.7                  2.8
# Bulgaria                             13.1                  3.2
# Burkina Faso                         22.4                  9.1
# Cambodia                              9.0                  3.2
# Cameroon                             26.9                 12.5
# Canada                               15.1                  5.8
# Chile                                16.0                  3.8
# China                                 7.9                  8.3
# Colombia                             11.5                  2.8
# Comoros                              17.6                  5.4
# ...                                   ...                  ...
# Seychelles                           15.0                  2.1
# Sierra Leone                         18.2                 14.2
# Singapore                            11.1                  4.9
# Slovakia                             18.4                  2.6
# Slovenia                             22.4                  4.5
# South Africa                         21.7                  5.1
# Spain                                 9.3                  3.1
# Sri Lanka                            23.3                  6.2
# Sudan                                14.5                  4.6
# Suriname                             36.1                 10.9
# Sweden                               15.8                  7.4
# Switzerland                          15.8                  6.9
# Tajikistan                            5.0                  1.7
# Thailand                             21.4                  4.8
# Togo                                 22.7                 10.9
# Tonga                                 5.2                  2.9
# Trinidad and Tobago                  21.9                  4.3
# Tunisia                               4.4                  2.2
# Turkey                               11.3                  3.2
# Turkmenistan                         11.0                  3.7
# Uganda                               21.2                 18.7
# Ukraine                              34.5                  4.7
# United Arab Emirates                  3.5                  0.8
# United Kingdom                       11.9                  3.5
# United States                        21.1                  6.4
# Uruguay                              26.8                  7.1
# Uzbekistan                           10.3                  4.6
# Vanuatu                               8.1                  2.7
# Zambia                               17.5                  6.2
# Zimbabwe                             29.1                 11.1
#
#                         % Living in Cities > 100k  \
# Entity
# Afghanistan                                 15.56
# Albania                                      9.34
# Algeria                                     24.73
# Angola                                      19.97
# Antigua and Barbuda                         33.07
# Argentina                                   74.17
# Armenia                                     53.58
# Australia                                   71.69
# Austria                                     37.26
# Azerbaijan                                  23.27
# Bahrain                                     25.88
# Bangladesh                                   8.88
# Barbados                                     3.94
# Belarus                                     48.56
# Belgium                                     34.03
# Belize                                      25.02
# Benin                                       19.24
# Bhutan                                       2.62
# Bosnia and Herzegovina                      37.27
# Botswana                                    12.73
# Brazil                                      45.43
# Bulgaria                                    37.05
# Burkina Faso                                14.11
# Cambodia                                     8.41
# Cameroon                                    27.33
# Canada                                      79.19
# Chile                                       56.60
# China                                       37.18
# Colombia                                    41.38
# Comoros                                      6.72
# ...                                           ...
# Seychelles                                  28.70
# Sierra Leone                                20.03
# Singapore                                   78.73
# Slovakia                                    17.12
# Slovenia                                    21.16
# South Africa                                42.82
# Spain                                       41.57
# Sri Lanka                                    8.35
# Sudan                                       17.49
# Suriname                                    55.03
# Sweden                                      29.85
# Switzerland                                 42.30
# Tajikistan                                  11.00
# Thailand                                    16.14
# Togo                                        16.14
# Tonga                                       28.70
# Trinidad and Tobago                          4.13
# Tunisia                                     29.97
# Turkey                                      60.51
# Turkmenistan                                18.50
# Uganda                                       5.01
# Ukraine                                     41.55
# United Arab Emirates                        70.03
# United Kingdom                              52.90
# United States                               72.40
# Uruguay                                     44.40
# Uzbekistan                                  20.54
# Vanuatu                                     14.17
# Zambia                                      29.35
# Zimbabwe                                    25.85
#
#                         % of Population with Internet Access  % Religious  \
# Entity
# Afghanistan                                             10.6         97.0
# Albania                                                 66.4         32.5
# Algeria                                                 42.9         93.0
# Angola                                                  13.0         88.0
# Antigua and Barbuda                                     65.2         50.0
# Argentina                                               70.2         66.0
# Armenia                                                 62.0         72.5
# Australia                                               88.2         32.0
# Austria                                                 84.3         55.0
# Azerbaijan                                              78.2         49.5
# Bahrain                                                 98.0         95.5
# Bangladesh                                              18.2        100.0
# Barbados                                                79.5         50.0
# Belarus                                                 71.1         33.0
# Belgium                                                 86.5         33.0
# Belize                                                  44.6         61.5
# Benin                                                   12.0         92.5
# Bhutan                                                  41.8         50.0
# Bosnia and Herzegovina                                  69.3         66.0
# Botswana                                                39.4         77.0
# Brazil                                                  59.7         86.5
# Bulgaria                                                59.8         33.5
# Burkina Faso                                            14.0         87.5
# Cambodia                                                25.6         96.0
# Cameroon                                                25.0         95.5
# Canada                                                  89.8         42.0
# Chile                                                   66.0         69.5
# China                                                   53.2         50.0
# Colombia                                                58.1         82.5
# Comoros                                                  7.9         96.0
# ...                                                      ...          ...
# Seychelles                                              56.5         50.0
# Sierra Leone                                            11.8         98.0
# Singapore                                               81.0         70.0
# Slovakia                                                80.5         46.5
# Slovenia                                                75.5         47.0
# South Africa                                            54.0         84.5
# Spain                                                   80.6         49.5
# Sri Lanka                                               32.1         98.5
# Sudan                                                   28.0         94.0
# Suriname                                                45.4         50.0
# Sweden                                                  91.5         16.5
# Switzerland                                             89.4         41.5
# Tajikistan                                              20.5         84.5
# Thailand                                                47.5         94.0
# Togo                                                    11.3         80.0
# Tonga                                                   40.0         50.0
# Trinidad and Tobago                                     69.2         92.0
# Tunisia                                                 50.9         93.0
# Turkey                                                  58.3         89.5
# Turkmenistan                                            18.0         50.0
# Uganda                                                  45.9         93.0
# Ukraine                                                 52.5         45.5
# United Arab Emirates                                    90.6         91.0
# United Kingdom                                          94.8         26.5
# United States                                           76.2         50.0
# Uruguay                                                 66.4         40.5
# Uzbekistan                                              46.8         51.0
# Vanuatu                                                 24.0         50.0
# Zambia                                                  25.5         97.0
# Zimbabwe                                                23.1         87.5
#
#                        Religious
# Entity
# Afghanistan                 High
# Albania                      Low
# Algeria                     High
# Angola                      High
# Antigua and Barbuda       Medium
# Argentina                   High
# Armenia                     High
# Australia                    Low
# Austria                   Medium
# Azerbaijan                Medium
# Bahrain                     High
# Bangladesh                  High
# Barbados                  Medium
# Belarus                      Low
# Belgium                      Low
# Belize                    Medium
# Benin                       High
# Bhutan                    Medium
# Bosnia and Herzegovina      High
# Botswana                    High
# Brazil                      High
# Bulgaria                  Medium
# Burkina Faso                High
# Cambodia                    High
# Cameroon                    High
# Canada                    Medium
# Chile                       High
# China                     Medium
# Colombia                    High
# Comoros                     High
# ...                          ...
# Seychelles                Medium
# Sierra Leone                High
# Singapore                   High
# Slovakia                  Medium
# Slovenia                  Medium
# South Africa                High
# Spain                     Medium
# Sri Lanka                   High
# Sudan                       High
# Suriname                  Medium
# Sweden                       Low
# Switzerland               Medium
# Tajikistan                  High
# Thailand                    High
# Togo                        High
# Tonga                     Medium
# Trinidad and Tobago         High
# Tunisia                     High
# Turkey                      High
# Turkmenistan              Medium
# Uganda                      High
# Ukraine                   Medium
# United Arab Emirates        High
# United Kingdom               Low
# United States             Medium
# Uruguay                   Medium
# Uzbekistan                Medium
# Vanuatu                   Medium
# Zambia                      High
# Zimbabwe                    High
#
# [148 rows x 17 columns]
